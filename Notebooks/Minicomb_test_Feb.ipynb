# %% [markdown]
# ## GUI test

# %%
import tkinter as tk 
from tkinter import ttk
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import threading
import time
from collections import deque

from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# 导入真实的 Agilent_86142B 驱动
from KeckLFC.Hardware.Agilent_86142B import Agilent_86142B

# ------------------------------------------------------------
# Dummy Lfc service for testing without ICE
# ------------------------------------------------------------
class DummyLfcService:
    def __init__(self):
        # 模拟关键词的初始值
        self.mkl = {
            "PRITEL": "0",                 # 0 = normal
            "EDFA_23": "0",                # 0 = normal
            "EDFA_27": "0",                # 0 = normal
            "RF_AMPLIFIER": "0",           # 0 = normal
            "RF_OSCILLATOR": "0",          # 0 = normal
            "PENDULUM": "0",               # 0 = normal
            "TEMP_MONITOR": "0",           # 0 = normal
            "REPETITION_RATE": "16"        # 单位 GHz，示例为 16GHz
        }
        # 维护当前状态
        self.status = "off"

    def __getitem__(self, key):
        return self.mkl.get(key, "0")

    def __setitem__(self, key, value):
        self.mkl[key] = value

    def check_status(self):
        """
        返回当前 LFC 的状态：off/on/standby/full comb。
        """
        return self.status

    def do_lfc_off(self):
        self.status = "OFF"

    def do_lfc_on(self):
        self.status = "ON"

    def do_lfc_standby(self):
        self.status = "STANDBY"

    def do_lfc_full_comb(self):
        self.status = "FULL COMB"

# ------------------------------------------------------------
# LfcMonitorGUI 类
# ------------------------------------------------------------
class LfcMonitorGUI:
    def __init__(self, root, lfc_service):
        self.root = root
        self.lfc = lfc_service
        self.pending_action = None
        self.first_update_done = False
        # 日志队列，最多保留10条
        self.log_queue = deque(maxlen=10)
        # 密码验证状态
        self.is_authenticated = False
        # 状态检查运行标志
        self.is_status_checking = False

        root.title("LFC STATUS and CONTROL (Demo)")
        root.geometry("1280x900")
        root.protocol("WM_DELETE_WINDOW", self.on_close)

        # 整体布局
        frame = ttk.Frame(root, padding=10)
        frame.grid(row=0, column=0, sticky="nsew")
        root.columnconfigure(0, weight=1)
        root.rowconfigure(0, weight=1)
        frame.columnconfigure(2, weight=1)

        # -------- 左侧：控制按钮 --------
        btn_frame = ttk.LabelFrame(frame, text="Device control", padding=8)
        btn_frame.grid(row=0, column=0, sticky="nw", padx=(0,10))
        self.control_buttons = []
        btn_texts = ["LFC ON", "LFC STANDBY", "LFC FULL COMB"]
        actions = ["LFC_ON", "LFC_STANDBY", "LFC_FULL_COMB"]
        for i, action in enumerate(actions):
            btn = ttk.Button(
                btn_frame,
                text=btn_texts[i],
                command=lambda act=action: self.request_action(act),
                state="disabled"
            )
            btn.grid(row=i, column=0, pady=(0,5), sticky="ew")
            self.control_buttons.append(btn)
        for i in range(3, 8):
            ttk.Button(btn_frame, text="", state="disabled").grid(
                row=i, column=0, pady=(0,5), sticky="ew"
            )

        # -------- 中央：状态监测 --------
        status_frame = ttk.LabelFrame(frame, text="Status monitor", padding=8)
        status_frame.grid(row=0, column=1, sticky="nsew")
        status_frame.columnconfigure(1, weight=1)

        # 当前状态
        ttk.Label(status_frame, text="Current Status：").grid(
            row=0, column=0, sticky="w", pady=(0,10)
        )
        self.current_status_label = ttk.Label(status_frame, text="--")
        self.current_status_label.grid(row=0, column=1, sticky="w", pady=(0,10))
        
        # 状态检查运行提示（放在Current Status下面）
        self.status_check_label = tk.Label(status_frame, text="", fg="red")
        self.status_check_label.grid(row=1, column=0, columnspan=2, sticky="w", pady=(0,10))

        # 指示灯
        self.status_items = [
            ("PRITEL", "Pritel"),
            ("EDFA_23", "EDFA 23"),
            ("EDFA_27", "EDFA 27"),
            ("RF_AMPLIFIER", "RF amplifier"),
            ("RF_OSCILLATOR", "RF oscillator"),
            ("PENDULUM", "pendulum"),
            ("TEMP_MONITOR", "Temp monitor"),
        ]
        self.indicator_ids = {}
        for idx, (kw, label_text) in enumerate(self.status_items, start=2):  # 从第3行开始（row=2）
            ttk.Label(status_frame, text=label_text + "：").grid(
                row=idx, column=0, sticky="w", pady=5
            )
            c = tk.Canvas(status_frame, width=20, height=20, highlightthickness=0)
            oval = c.create_oval(2, 2, 18, 18, fill="gray")
            c.grid(row=idx, column=1, sticky="w", padx=5)
            self.indicator_ids[kw] = (c, oval)

        # Repetition Rate
        idx = len(self.status_items) + 2  # 调整索引，因为状态检查标签占了一行
        ttk.Label(status_frame, text="Repetition Rate (GHz)：").grid(
            row=idx, column=0, sticky="w", pady=10
        )
        self.rr_label = ttk.Label(status_frame, text="-- GHz")
        self.rr_label.grid(row=idx, column=1, sticky="w", padx=5, pady=10)

        # Last Update
        idx += 1
        ttk.Label(status_frame, text="Last Update：").grid(
            row=idx, column=0, sticky="w", pady=5
        )
        self.last_update_label = tk.Label(
            status_frame, text="--:--:--", fg="red"
        )
        self.last_update_label.grid(
            row=idx, column=1, sticky="w", padx=5, pady=5
        )

        # MiniComb Trace
        idx += 1
        ttk.Label(status_frame, text="MiniComb Trace：").grid(
            row=idx, column=0, sticky="nw", pady=5
        )
        self.trace_frame = ttk.Frame(status_frame)
        self.trace_frame.grid(
            row=idx, column=1, sticky="nsew", padx=5, pady=5
        )
        status_frame.rowconfigure(idx, weight=1)
        status_frame.columnconfigure(1, weight=1)

        # -------- 右侧：确认区 & 日志 --------
        confirm_frame = ttk.LabelFrame(frame, text="Confirm & Log", padding=8)
        confirm_frame.grid(row=0, column=2, sticky="ne", padx=(10,0))

        # 确认文本
        self.confirm_label = ttk.Label(confirm_frame, text="")
        self.confirm_label.grid(row=0, column=0, columnspan=2, pady=(0,5))

        # Yes / No 按钮
        style = ttk.Style()
        style.configure("Green.TButton", foreground="green")
        style.configure("Red.TButton", foreground="red")
        self.yes_button = ttk.Button(
            confirm_frame, text="Yes", command=self.execute_action, style="Green.TButton"
        )
        self.yes_button.grid(row=1, column=0, padx=(0,5))
        self.no_button = ttk.Button(
            confirm_frame, text="No", command=self.cancel_action, style="Red.TButton"
        )
        self.no_button.grid(row=1, column=1)
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")

        # 日志 Listbox
        self.log_listbox = tk.Listbox(confirm_frame, height=10, width=50)
        self.log_listbox.grid(row=2, column=0, columnspan=2, pady=(10,0))

        # -------- 密码验证区域 --------
        # 密码验证框架
        passcode_frame = ttk.Frame(confirm_frame)
        passcode_frame.grid(row=3, column=0, columnspan=2, pady=(10,0), sticky="ew")

        ttk.Label(passcode_frame, text="Passcode:").grid(row=0, column=0, sticky="w", padx=(0,5))
        self.passcode_entry = ttk.Entry(passcode_frame, show="*", width=20)
        self.passcode_entry.grid(row=0, column=1, padx=(0,5))
        self.passcode_entry.bind('<Return>', lambda e: self.login())
        
        self.login_button = ttk.Button(passcode_frame, text="Log in", command=self.login)
        self.login_button.grid(row=0, column=2)

        # -------- 隐藏的控制面板 --------
        self.hidden_frame = ttk.LabelFrame(confirm_frame, text="Advanced Controls", padding=8)
        # 初始时不显示，需要验证后才显示
        
        # 1. LFC OFF 按钮
        self.lfc_off_button = ttk.Button(
            self.hidden_frame, 
            text="LFC OFF", 
            command=lambda: self.request_action("LFC_OFF")
        )
        self.lfc_off_button.grid(row=0, column=0, columnspan=3, pady=(0,10), sticky="ew")

        # 2. Pritel amplifier current 控制
        ttk.Label(self.hidden_frame, text="Pritel amplifier current: (A)").grid(
            row=1, column=0, sticky="w", padx=(0,5)
        )
        self.current_entry = ttk.Entry(self.hidden_frame, width=10)
        self.current_entry.grid(row=1, column=1, padx=(0,5))
        self.set_current_button = ttk.Button(
            self.hidden_frame, 
            text="Set current", 
            command=self.set_current
        )
        self.set_current_button.grid(row=1, column=2)

        # 3. Hide 按钮
        self.hide_button = ttk.Button(
            self.hidden_frame, 
            text="Hide", 
            command=self.hide_advanced_controls
        )
        self.hide_button.grid(row=2, column=0, columnspan=3, pady=(10,0), sticky="ew")

        # 初始化按钮
        for btn in self.control_buttons:
            btn.config(state="disabled")

        # 周期性刷新
        self.poll_interval = 8000
        self.root.after(self.poll_interval, self.update_indicators)

    def login(self):
        """处理登录逻辑"""
        passcode = self.passcode_entry.get()
        self.passcode_entry.delete(0, tk.END)  # 清除输入框
        
        if passcode == "kecklfc":
            self.is_authenticated = True
            self.show_advanced_controls()
        else:
            # 可以添加错误提示
            pass

    def show_advanced_controls(self):
        """显示隐藏的控制面板"""
        self.hidden_frame.grid(row=4, column=0, columnspan=2, pady=(10,0), sticky="ew")

    def hide_advanced_controls(self):
        """隐藏控制面板"""
        self.hidden_frame.grid_remove()
        self.is_authenticated = False

    def set_current(self):
        """设置 Pritel amplifier current"""
        try:
            current_value = float(self.current_entry.get())
            # 禁用所有按钮
            self.disable_all_buttons()
            
            # 记录日志
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            log_msg = f"Pritel amplifier current set to {current_value}A: {timestamp}"
            self._append_log(log_msg)
            
            # 模拟执行时间
            threading.Thread(target=self._set_current_thread, daemon=True).start()
            
        except ValueError:
            # 输入无效，可以添加错误处理
            pass

    def _set_current_thread(self):
        """设置电流的后台线程"""
        time.sleep(3)  # 模拟执行时间
        self.root.after(0, self.enable_all_buttons)

    def disable_all_buttons(self):
        """禁用所有按钮"""
        for btn in self.control_buttons:
            btn.config(state="disabled")
        if self.is_authenticated:
            self.lfc_off_button.config(state="disabled")
            self.set_current_button.config(state="disabled")
            self.hide_button.config(state="disabled")
        self.login_button.config(state="disabled")
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")

    def enable_all_buttons(self):
        """启用所有按钮"""
        if not self.is_status_checking:  # 只有在不进行状态检查时才启用按钮
            for btn in self.control_buttons:
                btn.config(state="normal")
            if self.is_authenticated:
                self.lfc_off_button.config(state="normal")
                self.set_current_button.config(state="normal")
                self.hide_button.config(state="normal")
            self.login_button.config(state="normal")
            if self.pending_action is None:
                self.yes_button.config(state="disabled")
                self.no_button.config(state="disabled")

    def request_action(self, action_name: str):
        # 禁用所有按钮
        self.disable_all_buttons()
        self.pending_action = action_name
        self.confirm_label.config(text=f"Confirm {action_name}?")
        self.yes_button.config(state="normal")
        self.no_button.config(state="normal")

    def execute_action(self):
        action = self.pending_action
        # 记录开始日志
        start_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self._append_log(f"{action} function started: {start_time}")
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")
        threading.Thread(target=self._run_action_thread, args=(action,), daemon=True).start()

    def _run_action_thread(self, action_name):
        # 调用对应方法
        if action_name == "LFC_OFF":
            self.lfc.do_lfc_off()
        elif action_name == "LFC_ON":
            self.lfc.do_lfc_on()
        elif action_name == "LFC_STANDBY":
            self.lfc.do_lfc_standby()
        elif action_name == "LFC_FULL_COMB":
            self.lfc.do_lfc_full_comb()
        # 模拟延迟
        time.sleep(3)
        self.root.after(0, lambda: self._action_complete(action_name))

    def _action_complete(self, action_name):
        # 记录完成日志
        finish_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self._append_log(f"{action_name} function completed: {finish_time}")
        # 更新状态标签
        display_status = action_name.replace("_", " ")
        self.current_status_label.config(text=display_status)
        # 恢复按钮
        self.enable_all_buttons()
        self.pending_action = None

    def _append_log(self, text):
        self.log_queue.append(text)
        self.log_listbox.delete(0, tk.END)
        for line in self.log_queue:
            self.log_listbox.insert(tk.END, line)
        self.log_listbox.yview_moveto(1)

    def cancel_action(self):
        self.pending_action = None
        self.confirm_label.config(text="")
        self.enable_all_buttons()
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")

    def check_status(self):
        """检查系统状态的函数"""
        # 这里可以添加实际的状态检查逻辑
        # 目前只是模拟延迟
        time.sleep(3)

    def _check_status_thread(self):
        """状态检查的后台线程"""
        self.check_status()
        self.root.after(0, self._status_check_complete)

    def _status_check_complete(self):
        """状态检查完成后的处理"""
        self.is_status_checking = False
        self.status_check_label.config(text="")
        self.enable_all_buttons()

    def update_indicators(self):
        # 首先运行状态检查
        if not self.is_status_checking and self.pending_action is None:
            self.is_status_checking = True
            self.status_check_label.config(text="auto status check is running")
            self.disable_all_buttons()
            threading.Thread(target=self._check_status_thread, daemon=True).start()
        
        # 0) 更新 current_status
        if self.pending_action is None:
            try:
                status_str = self.lfc.check_status()
            except:
                status_str = "--"
            self.current_status_label.config(text=status_str)
        # 1) 指示灯
        for kw, _ in self.status_items:
            canvas, oval_id = self.indicator_ids[kw]
            raw = self.lfc.mkl.get(kw, "0")
            try:
                val = int(raw)
            except:
                val = None
            # 所有指示灯都是 0 = green, 非0 = red
            color = "green" if val == 0 else "red"
            canvas.itemconfig(oval_id, fill=color)
        # 2) Repetition Rate
        rr_text = f"{int(self.lfc.mkl.get('REPETITION_RATE', '--'))} GHz"
        self.rr_label.config(text=rr_text)
        # 3) Last Update
        now_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self.last_update_label.config(text=now_str)
        # 4) MiniComb Trace
        for w in self.trace_frame.winfo_children():
            w.destroy()
        try:
            osa = Agilent_86142B()
            osa.connect()
            osa.Run()
            wl, intensity = osa.get_trace('A', plot=False)
            osa.disconnect()
            fig = plt.Figure(figsize=(5,4), dpi=100)
            ax = fig.add_subplot(111)
            ax.plot(wl, intensity)
            ax.set_xlabel('Wavelength (nm)')
            ax.set_ylabel('Intensity (dBm)')
            ax.set_ylim(-75, 0)
            fig.tight_layout()
            canvas_fig = FigureCanvasTkAgg(fig, master=self.trace_frame)
            canvas_fig.get_tk_widget().pack(fill='both', expand=True)
        except Exception as e:
            ttk.Label(self.trace_frame, text="Trace unavailable").pack()
        # 首次启用按钮
        if not self.first_update_done:
            if not self.is_status_checking:  # 只有在不进行状态检查时才启用按钮
                for btn in self.control_buttons:
                    btn.config(state="normal")
            self.first_update_done = True
        self.root.after(self.poll_interval, self.update_indicators)

    def on_close(self):
        self.root.destroy()

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
root = tk.Tk()
dummy_service = DummyLfcService()
app = LfcMonitorGUI(root, dummy_service)
root.mainloop()

# %%
import tkinter as tk 
from tkinter import ttk
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import threading
import time
from collections import deque

from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# 导入真实的 Agilent_86142B 驱动
from KeckLFC.Hardware.Agilent_86142B import Agilent_86142B

# ------------------------------------------------------------
# Dummy Lfc service for testing without ICE
# ------------------------------------------------------------
class DummyLfcService:
    def __init__(self):
        # 模拟关键词的初始值
        self.mkl = {
            "LFC_TEMP_MONITOR": "1",       # 1 = Normal
            "LFC_RFOSCI_MONITOR": "0",     # 0 = normal
            "AMPLIFIER_MONITOR": "0",      # 0 = normal
            "INTERLOCK_MONITOR": "0",      # 0 = normal
            "REPETITION_RATE": "16"        # 单位 GHz，示例为 16GHz
        }
        # 维护当前状态
        self.status = "off"

    def __getitem__(self, key):
        return self.mkl.get(key, "0")

    def __setitem__(self, key, value):
        self.mkl[key] = value

    def check_status(self):
        """
        返回当前 LFC 的状态：off/on/standby/full comb。
        """
        return self.status

    def do_lfc_off(self):
        self.status = "OFF"

    def do_lfc_on(self):
        self.status = "ON"

    def do_lfc_standby(self):
        self.status = "STANDBY"

    def do_lfc_full_comb(self):
        self.status = "FULL COMB"

# ------------------------------------------------------------
# LfcMonitorGUI 类
# ------------------------------------------------------------
class LfcMonitorGUI:
    def __init__(self, root, lfc_service):
        self.root = root
        self.lfc = lfc_service
        self.pending_action = None
        self.first_update_done = False
        # 日志队列，最多保留10条
        self.log_queue = deque(maxlen=10)
        # 密码验证状态
        self.is_authenticated = False

        root.title("LFC STATUS and CONTROL (Demo)")
        root.geometry("1280x900")
        root.protocol("WM_DELETE_WINDOW", self.on_close)

        # 整体布局
        frame = ttk.Frame(root, padding=10)
        frame.grid(row=0, column=0, sticky="nsew")
        root.columnconfigure(0, weight=1)
        root.rowconfigure(0, weight=1)
        frame.columnconfigure(2, weight=1)

        # -------- 左侧：控制按钮 --------
        btn_frame = ttk.LabelFrame(frame, text="Device control", padding=8)
        btn_frame.grid(row=0, column=0, sticky="nw", padx=(0,10))
        self.control_buttons = []
        btn_texts = ["LFC ON", "LFC STANDBY", "LFC FULL COMB"]
        actions = ["LFC_ON", "LFC_STANDBY", "LFC_FULL_COMB"]
        for i, action in enumerate(actions):
            btn = ttk.Button(
                btn_frame,
                text=btn_texts[i],
                command=lambda act=action: self.request_action(act),
                state="disabled"
            )
            btn.grid(row=i, column=0, pady=(0,5), sticky="ew")
            self.control_buttons.append(btn)
        for i in range(3, 8):
            ttk.Button(btn_frame, text="", state="disabled").grid(
                row=i, column=0, pady=(0,5), sticky="ew"
            )

        # -------- 中央：状态监测 --------
        status_frame = ttk.LabelFrame(frame, text="Status monitor", padding=8)
        status_frame.grid(row=0, column=1, sticky="nsew")
        status_frame.columnconfigure(1, weight=1)

        # 当前状态
        ttk.Label(status_frame, text="Current Status：").grid(
            row=0, column=0, sticky="w", pady=(0,10)
        )
        self.current_status_label = ttk.Label(status_frame, text="--")
        self.current_status_label.grid(row=0, column=1, sticky="w", pady=(0,10))

        # 指示灯
        self.status_items = [
            ("LFC_TEMP_MONITOR", "TEMP monitor"),
            ("LFC_RFOSCI_MONITOR", "RF Oscillator"),
            ("AMPLIFIER_MONITOR", "Amplifier Monitor"),
            ("INTERLOCK_MONITOR", "Interlock Monitor"),
        ]
        self.indicator_ids = {}
        for idx, (kw, label_text) in enumerate(self.status_items, start=1):
            ttk.Label(status_frame, text=label_text + "：").grid(
                row=idx, column=0, sticky="w", pady=5
            )
            c = tk.Canvas(status_frame, width=20, height=20, highlightthickness=0)
            oval = c.create_oval(2, 2, 18, 18, fill="gray")
            c.grid(row=idx, column=1, sticky="w", padx=5)
            self.indicator_ids[kw] = (c, oval)

        # Repetition Rate
        idx = len(self.status_items) + 1
        ttk.Label(status_frame, text="Repetition Rate (GHz)：").grid(
            row=idx, column=0, sticky="w", pady=10
        )
        self.rr_label = ttk.Label(status_frame, text="-- GHz")
        self.rr_label.grid(row=idx, column=1, sticky="w", padx=5, pady=10)

        # Last Update
        idx += 1
        ttk.Label(status_frame, text="Last Update：").grid(
            row=idx, column=0, sticky="w", pady=5
        )
        self.last_update_label = tk.Label(
            status_frame, text="--:--:--", fg="red"
        )
        self.last_update_label.grid(
            row=idx, column=1, sticky="w", padx=5, pady=5
        )

        # MiniComb Trace
        idx += 1
        ttk.Label(status_frame, text="MiniComb Trace：").grid(
            row=idx, column=0, sticky="nw", pady=5
        )
        self.trace_frame = ttk.Frame(status_frame)
        self.trace_frame.grid(
            row=idx, column=1, sticky="nsew", padx=5, pady=5
        )
        status_frame.rowconfigure(idx, weight=1)
        status_frame.columnconfigure(1, weight=1)

        # -------- 右侧：确认区 & 日志 --------
        confirm_frame = ttk.LabelFrame(frame, text="Confirm & Log", padding=8)
        confirm_frame.grid(row=0, column=2, sticky="ne", padx=(10,0))

        # 确认文本
        self.confirm_label = ttk.Label(confirm_frame, text="")
        self.confirm_label.grid(row=0, column=0, columnspan=2, pady=(0,5))

        # Yes / No 按钮
        style = ttk.Style()
        style.configure("Green.TButton", foreground="green")
        style.configure("Red.TButton", foreground="red")
        self.yes_button = ttk.Button(
            confirm_frame, text="Yes", command=self.execute_action, style="Green.TButton"
        )
        self.yes_button.grid(row=1, column=0, padx=(0,5))
        self.no_button = ttk.Button(
            confirm_frame, text="No", command=self.cancel_action, style="Red.TButton"
        )
        self.no_button.grid(row=1, column=1)
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")

        # 日志 Listbox
        self.log_listbox = tk.Listbox(confirm_frame, height=10, width=50)
        self.log_listbox.grid(row=2, column=0, columnspan=2, pady=(10,0))

        # -------- 密码验证区域 --------
        # 密码验证框架
        passcode_frame = ttk.Frame(confirm_frame)
        passcode_frame.grid(row=3, column=0, columnspan=2, pady=(10,0), sticky="ew")

        ttk.Label(passcode_frame, text="Passcode:").grid(row=0, column=0, sticky="w", padx=(0,5))
        self.passcode_entry = ttk.Entry(passcode_frame, show="*", width=20)
        self.passcode_entry.grid(row=0, column=1, padx=(0,5))
        self.passcode_entry.bind('<Return>', lambda e: self.login())
        
        self.login_button = ttk.Button(passcode_frame, text="Log in", command=self.login)
        self.login_button.grid(row=0, column=2)

        # -------- 隐藏的控制面板 --------
        self.hidden_frame = ttk.LabelFrame(confirm_frame, text="Advanced Controls", padding=8)
        # 初始时不显示，需要验证后才显示
        
        # 1. LFC OFF 按钮
        self.lfc_off_button = ttk.Button(
            self.hidden_frame, 
            text="LFC OFF", 
            command=lambda: self.request_action("LFC_OFF")
        )
        self.lfc_off_button.grid(row=0, column=0, columnspan=3, pady=(0,10), sticky="ew")

        # 2. Pritel amplifier current 控制
        ttk.Label(self.hidden_frame, text="Pritel amplifier current: (A)").grid(
            row=1, column=0, sticky="w", padx=(0,5)
        )
        self.current_entry = ttk.Entry(self.hidden_frame, width=10)
        self.current_entry.grid(row=1, column=1, padx=(0,5))
        self.set_current_button = ttk.Button(
            self.hidden_frame, 
            text="Set current", 
            command=self.set_current
        )
        self.set_current_button.grid(row=1, column=2)

        # 3. Hide 按钮
        self.hide_button = ttk.Button(
            self.hidden_frame, 
            text="Hide", 
            command=self.hide_advanced_controls
        )
        self.hide_button.grid(row=2, column=0, columnspan=3, pady=(10,0), sticky="ew")

        # 初始化按钮
        for btn in self.control_buttons:
            btn.config(state="disabled")

        # 周期性刷新
        self.poll_interval = 10000
        self.root.after(self.poll_interval, self.update_indicators)

    def login(self):
        """处理登录逻辑"""
        passcode = self.passcode_entry.get()
        self.passcode_entry.delete(0, tk.END)  # 清除输入框
        
        if passcode == "kecklfc":
            self.is_authenticated = True
            self.show_advanced_controls()
        else:
            # 可以添加错误提示
            pass

    def show_advanced_controls(self):
        """显示隐藏的控制面板"""
        self.hidden_frame.grid(row=4, column=0, columnspan=2, pady=(10,0), sticky="ew")

    def hide_advanced_controls(self):
        """隐藏控制面板"""
        self.hidden_frame.grid_remove()
        self.is_authenticated = False

    def set_current(self):
        """设置 Pritel amplifier current"""
        try:
            current_value = float(self.current_entry.get())
            # 禁用所有按钮
            self.disable_all_buttons()
            
            # 记录日志
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            log_msg = f"Pritel amplifier current set to {current_value}A: {timestamp}"
            self._append_log(log_msg)
            
            # 模拟执行时间
            threading.Thread(target=self._set_current_thread, daemon=True).start()
            
        except ValueError:
            # 输入无效，可以添加错误处理
            pass

    def _set_current_thread(self):
        """设置电流的后台线程"""
        time.sleep(3)  # 模拟执行时间
        self.root.after(0, self.enable_all_buttons)

    def disable_all_buttons(self):
        """禁用所有按钮"""
        for btn in self.control_buttons:
            btn.config(state="disabled")
        if self.is_authenticated:
            self.lfc_off_button.config(state="disabled")
            self.set_current_button.config(state="disabled")
            self.hide_button.config(state="disabled")
        self.login_button.config(state="disabled")

    def enable_all_buttons(self):
        """启用所有按钮"""
        for btn in self.control_buttons:
            btn.config(state="normal")
        if self.is_authenticated:
            self.lfc_off_button.config(state="normal")
            self.set_current_button.config(state="normal")
            self.hide_button.config(state="normal")
        self.login_button.config(state="normal")

    def request_action(self, action_name: str):
        # 禁用所有按钮
        self.disable_all_buttons()
        self.pending_action = action_name
        self.confirm_label.config(text=f"Confirm {action_name}?")
        self.yes_button.config(state="normal")
        self.no_button.config(state="normal")

    def execute_action(self):
        action = self.pending_action
        # 记录开始日志
        start_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self._append_log(f"{action} function started: {start_time}")
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")
        threading.Thread(target=self._run_action_thread, args=(action,), daemon=True).start()

    def _run_action_thread(self, action_name):
        # 调用对应方法
        if action_name == "LFC_OFF":
            self.lfc.do_lfc_off()
        elif action_name == "LFC_ON":
            self.lfc.do_lfc_on()
        elif action_name == "LFC_STANDBY":
            self.lfc.do_lfc_standby()
        elif action_name == "LFC_FULL_COMB":
            self.lfc.do_lfc_full_comb()
        # 模拟延迟
        time.sleep(5)
        self.root.after(0, lambda: self._action_complete(action_name))

    def _action_complete(self, action_name):
        # 记录完成日志
        finish_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self._append_log(f"{action_name} function completed: {finish_time}")
        # 更新状态标签
        display_status = action_name.replace("_", " ")
        self.current_status_label.config(text=display_status)
        # 恢复按钮
        self.enable_all_buttons()
        self.pending_action = None

    def _append_log(self, text):
        self.log_queue.append(text)
        self.log_listbox.delete(0, tk.END)
        for line in self.log_queue:
            self.log_listbox.insert(tk.END, line)
        self.log_listbox.yview_moveto(1)

    def cancel_action(self):
        self.pending_action = None
        self.confirm_label.config(text="")
        self.enable_all_buttons()
        self.yes_button.config(state="disabled")
        self.no_button.config(state="disabled")

    def update_indicators(self):
        # 0) 更新 current_status
        if self.pending_action is None:
            try:
                status_str = self.lfc.check_status()
            except:
                status_str = "--"
            self.current_status_label.config(text=status_str)
        # 1) 指示灯
        for kw, _ in self.status_items:
            canvas, oval_id = self.indicator_ids[kw]
            raw = self.lfc.mkl.get(kw, "0")
            try:
                val = int(raw)
            except:
                val = None
            if kw == "LFC_TEMP_MONITOR":
                color = "green" if val == 1 else "red"
            else:
                color = "green" if val == 0 else "red"
            canvas.itemconfig(oval_id, fill=color)
        # 2) Repetition Rate
        rr_text = f"{int(self.lfc.mkl.get('REPETITION_RATE', '--'))} GHz"
        self.rr_label.config(text=rr_text)
        # 3) Last Update
        now_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self.last_update_label.config(text=now_str)
        # 4) MiniComb Trace
        for w in self.trace_frame.winfo_children():
            w.destroy()
        try:
            osa = Agilent_86142B()
            osa.connect()
            osa.Run()
            wl, intensity = osa.get_trace('A', plot=False)
            osa.disconnect()
            fig = plt.Figure(figsize=(5,4), dpi=100)
            ax = fig.add_subplot(111)
            ax.plot(wl, intensity)
            ax.set_xlabel('Wavelength (nm)')
            ax.set_ylabel('Intensity (dBm)')
            ax.set_ylim(-75, 0)
            fig.tight_layout()
            canvas_fig = FigureCanvasTkAgg(fig, master=self.trace_frame)
            canvas_fig.get_tk_widget().pack(fill='both', expand=True)
        except Exception as e:
            ttk.Label(self.trace_frame, text="Trace unavailable").pack()
        # 首次启用按钮
        if not self.first_update_done:
            for btn in self.control_buttons:
                btn.config(state="normal")
            self.first_update_done = True
        self.root.after(self.poll_interval, self.update_indicators)

    def on_close(self):
        self.root.destroy()

# %%
# Run the GUI for demo
root = tk.Tk()
dummy_service = DummyLfcService()
app = LfcMonitorGUI(root, dummy_service)
root.mainloop()
# Out:
# 2025-06-19 21:33:11.852 | INFO     | Agilent 86142B | Device.py:connect:88
# Agilent 86142B connected
# 2025-06-19 21:33:11.856 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-06-19 21:33:12.851 | INFO     | Agilent 86142B | Device.py:disconnect:100
# Agilent 86142B disconnected
# 2025-06-19 21:33:22.910 | INFO     | Agilent 86142B | Device.py:connect:88
# Agilent 86142B connected
# 2025-06-19 21:33:22.914 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-06-19 21:33:23.784 | INFO     | Agilent 86142B | Device.py:disconnect:100
# Agilent 86142B disconnected
# 2025-06-19 21:33:33.847 | INFO     | Agilent 86142B | Device.py:connect:88
# Agilent 86142B connected
# 2025-06-19 21:33:33.850 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-06-19 21:33:34.772 | INFO     | Agilent 86142B | Device.py:disconnect:100
# Agilent 86142B disconnected
# 2025-06-19 21:33:44.841 | INFO     | Agilent 86142B | Device.py:connect:88
# Agilent 86142B connected
# 2025-06-19 21:33:44.844 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-06-19 21:33:45.715 | INFO     | Agilent 86142B | Device.py:disconnect:100
# Agilent 86142B disconnected
# 2025-06-19 21:33:55.774 | INFO     | Agilent 86142B | Device.py:connect:88
# Agilent 86142B connected
# 2025-06-19 21:33:55.782 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-06-19 21:33:56.642 | INFO     | Agilent 86142B | Device.py:disconnect:100
# Agilent 86142B disconnected

# %%
rfoscPS_onoff
# Out:
# 'ON'

# %%
import numpy as np
import time
from KeckLFC.Hardware.PritelAmp import PritelAmp
# ptamp test
def LFC_CHECK_STATUS(value=None):
    
    
    ptamp = PritelAmp(addr=f'ASRL{7}::INSTR', name='Pritel Amp')
    ptamp.connect()
    time.sleep(0.2)
    ptact=ptamp.activation
    status_dict={'ON':1,'OFF':0}
    ptact=status_dict[ptact]
    time.sleep(0.2)
    ptamp.disconnect()
    if ptact == 1:
        ptamp_prime = 2
    else:
        ptamp_prime = 1
    print(f'Pritel prime: {ptamp_prime}')
    # EDFA23 test
    from KeckLFC.Hardware.AmonicsEDFA import AmonicsEDFA
    amonic23 = AmonicsEDFA(addr=f'ASRL{12}::INSTR', name='Amonics EDFA 23 dBm')
    amonic23.connect()
    time.sleep(0.2)
    amonic23onoff=amonic23.accCh1Status
    time.sleep(0.2)
    if ( amonic23onoff in [1, 'ON', 'on', True]):
        amonic23_input_power=amonic23.inputPowerCh1
        
        if ( amonic23_input_power > 10) or ( amonic23_input_power < 1):
            print('EDFA23 input power is not correct')
        amonic23_prime = 3
    else:
        amonic23_prime = 1
    print(f'Amonics EDFA 23 prime: {amonic23_prime}')
    time.sleep(0.2)
    amonic23.disconnect()
    # EDFA27 test
    from KeckLFC.Hardware.AmonicsEDFA import AmonicsEDFA
    amonic27 = AmonicsEDFA(addr=f'ASRL{6}::INSTR', name='Amonics EDFA 27 dBm')
    amonic27.connect()
    time.sleep(0.2)
    amonic27onoff=amonic27.accCh1Status
    time.sleep(0.2)
    if ( amonic27onoff in [1, 'ON', 'on', True]):
        amonic27_input_power=amonic27.inputPowerCh1
        
        if ( amonic27_input_power > 10) or ( amonic27_input_power < 1):
            print('EDFA27 input power is not correct')
        amonic27_prime = 5
    else:
        amonic27_prime = 1
    print(f'Amonics EDFA 27 prime: {amonic27_prime}')
    time.sleep(0.2)
    amonic27.disconnect()
    # RFOSCI test
    from KeckLFC.Hardware.InstekGPD_4303S import InstekGPD_4303S
    rfoscPS = InstekGPD_4303S(addr='ASRL13::INSTR', name='RF oscilator PS, CH2 15V, CH3 1V')
    try:
        rfoscPS.connect()
    except Exception as e:
        time.sleep(1)
        rfoscPS.connect()
    time.sleep(0.2)
    rfoscPS_onoff=rfoscPS.activation
    time.sleep(0.2)
    if ( rfoscPS_onoff in [1, 'ON', 'on', True]):
        rfoscPS_v=rfoscPS.Vout2
        time.sleep(0.2)
        rfoscPS_i=rfoscPS.Iout2
        
        if np.abs(rfoscPS_v-15) > 2 or np.abs(rfoscPS_i-0.4) > 0.1:
            print('RFOSCI voltage or current is not correct')
        rfoscPS_prime = 7
    else:
        rfoscPS_prime = 1
    print(f'RFOSCI prime: {rfoscPS_prime}')
    time.sleep(0.2)
    rfoscPS.disconnect()
    # RFAMP test
    from KeckLFC.Hardware.InstekGppDCSupply import InstekGppDCSupply

    rfamp = InstekGppDCSupply(addr=f'ASRL{24}::INSTR', name='RF amplifier PS 30V 4A')
    try:
        rfamp.connect()
    except Exception as e:
        time.sleep(1)
        rfamp.connect()
    time.sleep(0.2)
    rfamp_onoff=rfamp.activation1
    time.sleep(0.2)
    if ( rfamp_onoff in [1, 'ON', 'on', True]):
        rfamp_threshold_v=30
        rfamp_threshold_i=4.0

        if rfoscPS_onoff in [1, 'ON', 'on', True]:
            rfamp_voltage=rfamp.Vout1
            time.sleep(0.2)
            rfamp_current=rfamp.Iout1
            if (np.abs(rfamp_voltage-rfamp_threshold_v)>3) or (np.abs(rfamp_current-rfamp_threshold_i)>0.3):
                print('close is triggered')
                print('RF amplifier is off due to over voltage or over current')
            rfamp_prime = 11
        if rfoscPS_onoff in [0, 'OFF', 'off', False]:
            if (np.abs(rfamp_voltage)>0.1) or (np.abs(rfamp_current)>0.1):
                print('close is triggered')
                print('RF amplifier is off due to activation without RFOSCI')
    else:
        rfamp_prime = 1
    print(f'RFAMP prime: {rfamp_prime}')
    time.sleep(0.2)
    rfamp.disconnect()
    # Pendulem test
    from KeckLFC.Hardware.PendulumCNT90 import PendulumCNT90
    pendulem = PendulumCNT90()
    pendulem.connect()
    time.sleep(0.2)
            
    if rfoscPS_onoff in [1, 'ON', 'on', True] and rfamp_onoff in [1, 'ON', 'on', True]:
        pendulem.run()
        time.sleep(0.2)
        freq=pendulem.measFreq('c')
        time.sleep(0.2)
        if np.abs(freq-16e9)>1000:
            print('close is triggered')
            print('Pendulum frequency is not 16GHz')
        pendulem_prime = 13
    else:
        pendulem_prime = 1
    print(f'Pendulem prime: {pendulem_prime}')
    time.sleep(0.2)
    pendulem.disconnect()

    final = ptamp_prime * amonic23_prime * amonic27_prime * rfoscPS_prime * rfamp_prime * pendulem_prime

    if final == 2*3*5*7*11*13:
        acomb_status = 'FULL COMB'
    elif final == 3*5*7*11*13:
        acomb_status = 'STANDBY'
    elif final == 1:
        acomb_status = 'OFF'
    else:
        acomb_status = 'STRANGE STATE'
        print(f'LFC is in strange state. Please check the status of each device. status code: {final}')
    print(f'LFC status: {acomb_status}')
    return acomb_status
# Out:
# 2025-08-06 10:01:07.933 | INFO     | Device | Device.py:<module>:61
# logger initialized

# %%
if 1 in [1,True,'ON','on']:
    print('True')
# Out:
# True

# %%
LFC_CHECK_STATUS()
# Out:
# 2025-08-06 10:01:14.548 | INFO     | Pritel Amp | Device.py:_open_visa:139
# Pritel Amp connected
# 2025-08-06 10:01:15.381 | INFO     | Pritel Amp | Device.py:disconnect:157
# Pritel Amp disconnected
# 2025-08-06 10:01:15.406 | INFO     | Amonics EDFA 23 dBm | Device.py:_open_visa:139
# Amonics EDFA 23 dBm connected
# Pritel prime: 1
# Amonics EDFA 23 prime: 3
# 2025-08-06 10:01:41.173 | INFO     | Amonics EDFA 23 dBm | Device.py:disconnect:157
# Amonics EDFA 23 dBm disconnected
# 2025-08-06 10:01:41.201 | INFO     | Amonics EDFA 27 dBm | Device.py:_open_visa:139
# Amonics EDFA 27 dBm connected
# Amonics EDFA 27 prime: 5
# 2025-08-06 10:01:41.978 | INFO     | Amonics EDFA 27 dBm | Device.py:disconnect:157
# Amonics EDFA 27 dBm disconnected
# 2025-08-06 10:01:41.998 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:_open_visa:139
# RF oscilator PS, CH2 15V, CH3 1V connected
# RFOSCI prime: 7
# 2025-08-06 10:01:43.772 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:disconnect:157
# RF oscilator PS, CH2 15V, CH3 1V disconnected
# 2025-08-06 10:01:43.781 | INFO     | RF amplifier PS 30V 4A | Device.py:_open_visa:139
# RF amplifier PS 30V 4A connected
# 2025-08-06 10:01:44.616 | INFO     | RF amplifier PS 30V 4A | Device.py:disconnect:157
# RF amplifier PS 30V 4A disconnected
# RFAMP prime: 11
# 2025-08-06 10:01:44.779 | INFO     | Pendulum microwave counter | Device.py:_open_visa:139
# Pendulum microwave counter connected
# 2025-08-06 10:01:44.982 | INFO     | Pendulum microwave counter | PendulumCNT90.py:run:34
# Pendulum Freq Counter: Gate is turned on, measurement result is continuously updated on display.
# Pendulem prime: 13
# 2025-08-06 10:01:46.956 | INFO     | Pendulum microwave counter | Device.py:disconnect:157
# Pendulum microwave counter disconnected
# LFC status: STANDBY
# 'STANDBY'

# %%
arduino = Arduino_relay(addr="COM3")
arduino.connect()
arduino.reset_relay_latch()
arduino.printStatus()
# Out:
# 2025-06-16 11:19:46.043 | INFO     | Arduino Relay Circuit | Arduino_relay.py:connect:52
# Arduino Relay Circuit connected
# 2025-06-16 11:19:46.446 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 1, trying again
# 2025-06-16 11:19:46.649 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 2, trying again
# 2025-06-16 11:19:46.852 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 3, trying again
# 2025-06-16 11:19:47.461 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay sending  OK_to_Amplify  signal to amplifier
# |	 Relay Info: get
# |		Now voltage is 514
# |		Now voltage to judge (low) is 496
# |		Now voltage to judge (high) is 515
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay sending \x1b OK_to_Amplify \x1b signal to amplifier\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 514\r\n|\t\tNow voltage to judge (low) is 496\r\n|\t\tNow voltage to judge (high) is 515\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
arduino.disconnect()
# Out:
# 2025-06-16 11:19:59.264 | INFO     | Arduino Relay Circuit | Arduino_relay.py:disconnect:65
# Arduino Relay Circuit disconnected
# 1

# %%
LFC_SET_FULL_COMB(1)
# Out:
# 2025-06-16 12:26:06.272 | INFO     | Pritel Amp | PritelAmp.py:connect:60
# Pritel Amp connected
# 2025-06-16 12:26:06.918 | INFO     | Pritel Amp | Device.py:disconnect:100
# Pritel Amp disconnected
# 2025-06-16 12:26:06.940 | INFO     | Amonics EDFA 23 dBm | Device.py:connect:88
# Amonics EDFA 23 dBm connected
# Pritel prime: 1
# 2025-06-16 12:26:09.579 | INFO     | Amonics EDFA 23 dBm | Device.py:disconnect:100
# Amonics EDFA 23 dBm disconnected
# Amonics EDFA 23 prime: 3
# 2025-06-16 12:26:09.590 | INFO     | Amonics EDFA 27 dBm | Device.py:connect:88
# Amonics EDFA 27 dBm connected
# 2025-06-16 12:26:10.248 | INFO     | Amonics EDFA 27 dBm | Device.py:disconnect:100
# Amonics EDFA 27 dBm disconnected
# Amonics EDFA 27 prime: 5
# 2025-06-16 12:26:10.264 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:connect:88
# RF oscilator PS, CH2 15V, CH3 1V connected
# 2025-06-16 12:26:11.865 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:disconnect:100
# RF oscilator PS, CH2 15V, CH3 1V disconnected
# RFOSCI prime: 7
# 2025-06-16 12:26:11.876 | INFO     | RF amplifier PS 30V 4A | Device.py:connect:88
# RF amplifier PS 30V 4A connected
# 2025-06-16 12:26:12.709 | INFO     | RF amplifier PS 30V 4A | Device.py:disconnect:100
# RF amplifier PS 30V 4A disconnected
# RFAMP prime: 11
# 2025-06-16 12:26:12.744 | INFO     | Pendulum microwave counter | Device.py:connect:88
# Pendulum microwave counter connected
# 2025-06-16 12:26:12.949 | INFO     | Pendulum microwave counter | PendulumCNT90.py:run:34
# Pendulum Freq Counter: Gate is turned on, measurement result is continuously updated on display.
# Pendulem prime: 13
# 2025-06-16 12:26:14.794 | INFO     | Pendulum microwave counter | Device.py:disconnect:100
# Pendulum microwave counter disconnected
# 2025-06-16 12:26:14.800 | INFO     | Arduino Relay Circuit | Arduino_relay.py:connect:52
# Arduino Relay Circuit connected
# LFC status: STANDBY
# 2025-06-16 12:26:15.404 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 1, trying again
# 2025-06-16 12:26:15.609 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 2, trying again
# 2025-06-16 12:26:16.633 | INFO     | Pritel Amp | PritelAmp.py:preAmp:115
# Pritel Amp: Disable Ramping by self.ramp_pre_ma = 0, now 100 mA.
# 2025-06-16 12:26:17.452 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 000 mA, current Output 0.00 W.
# 2025-06-16 12:26:17.948 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 120 mA, current Output 0.00 W.
# 2025-06-16 12:26:18.425 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 240 mA, current Output 0.00 W.
# 2025-06-16 12:26:18.924 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 360 mA, current Output 0.00 W.
# 2025-06-16 12:26:19.421 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 480 mA, current Output 0.00 W.
# 2025-06-16 12:26:19.916 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 600 mA, current Output 0.00 W.
# 2025-06-16 12:26:20.418 | INFO     | Pritel Amp | PritelAmp.py:activation:195
# Pritel Amp: ACTIVATING LASER PUMP (OUTPUT), MAKE SURE SEED INPUT POWER IS APPROPRIATE TO AVOID DAMAGE.
# 2025-06-16 12:26:20.909 | INFO     | Pritel Amp | PritelAmp.py:activation:206
# Pritel Amp: setted Activation status as ON, finished in 0.489 seconds
# 2025-06-16 12:26:21.634 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:151
# Pritel Amp: Disable Ramping by self.ramp_pwr_ma = 0, now 50 mA.
# 2025-06-16 12:26:22.397 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.00 A, current Output 0.00 W.
# 2025-06-16 12:26:23.052 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.05 A, current Output 0.00 W.
# 2025-06-16 12:26:23.708 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.10 A, current Output 0.00 W.
# 2025-06-16 12:26:24.365 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.15 A, current Output 0.00 W.
# 2025-06-16 12:26:25.020 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.20 A, current Output 0.00 W.
# 2025-06-16 12:26:25.693 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.25 A, current Output 0.00 W.
# 2025-06-16 12:26:26.348 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.30 A, current Output 0.00 W.
# 2025-06-16 12:26:27.005 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.35 A, current Output 0.00 W.
# 2025-06-16 12:26:27.661 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.41 A, current Output 0.00 W.
# 2025-06-16 12:26:28.316 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.46 A, current Output 0.00 W.
# 2025-06-16 12:26:28.989 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.51 A, current Output 0.00 W.
# 2025-06-16 12:26:29.645 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.56 A, current Output 0.03 W.
# 2025-06-16 12:26:30.301 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.61 A, current Output 0.08 W.
# 2025-06-16 12:26:30.957 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.66 A, current Output 0.13 W.
# 2025-06-16 12:26:31.612 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.71 A, current Output 0.18 W.
# 2025-06-16 12:26:32.284 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.76 A, current Output 0.23 W.
# 2025-06-16 12:26:32.941 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.81 A, current Output 0.29 W.
# 2025-06-16 12:26:33.597 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.86 A, current Output 0.34 W.
# 2025-06-16 12:26:34.253 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.91 A, current Output 0.39 W.
# 2025-06-16 12:26:34.909 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.96 A, current Output 0.44 W.
# 2025-06-16 12:26:35.581 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.01 A, current Output 0.50 W.
# 2025-06-16 12:26:36.237 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.06 A, current Output 0.55 W.
# 2025-06-16 12:26:36.892 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.11 A, current Output 0.61 W.
# 2025-06-16 12:26:37.549 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.16 A, current Output 0.67 W.
# 2025-06-16 12:26:38.204 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.22 A, current Output 0.72 W.
# 2025-06-16 12:26:38.877 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.27 A, current Output 0.79 W.
# 2025-06-16 12:26:39.533 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.32 A, current Output 0.83 W.
# 2025-06-16 12:26:40.189 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.37 A, current Output 0.89 W.
# 2025-06-16 12:26:40.845 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.42 A, current Output 0.96 W.
# 2025-06-16 12:26:41.500 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.47 A, current Output 1.02 W.
# 2025-06-16 12:26:42.173 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.52 A, current Output 1.07 W.
# 2025-06-16 12:26:42.828 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.57 A, current Output 1.13 W.
# 2025-06-16 12:26:43.485 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.62 A, current Output 1.20 W.
# 2025-06-16 12:26:44.141 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.67 A, current Output 1.25 W.
# 2025-06-16 12:26:44.797 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.72 A, current Output 1.29 W.
# 2025-06-16 12:26:45.469 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.77 A, current Output 1.36 W.
# 2025-06-16 12:26:46.125 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.82 A, current Output 1.42 W.
# 2025-06-16 12:26:46.781 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.87 A, current Output 1.49 W.
# 2025-06-16 12:26:47.436 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.92 A, current Output 1.53 W.
# 2025-06-16 12:26:48.093 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.97 A, current Output 1.59 W.
# 2025-06-16 12:26:48.765 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.03 A, current Output 1.64 W.
# 2025-06-16 12:26:49.421 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.08 A, current Output 1.71 W.
# 2025-06-16 12:26:50.077 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.13 A, current Output 1.77 W.
# 2025-06-16 12:26:50.734 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.18 A, current Output 1.82 W.
# 2025-06-16 12:26:51.391 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.23 A, current Output 1.88 W.
# 2025-06-16 12:26:52.061 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.28 A, current Output 1.95 W.
# 2025-06-16 12:26:52.718 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.33 A, current Output 2.01 W.
# 2025-06-16 12:26:53.374 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.38 A, current Output 2.08 W.
# 2025-06-16 12:26:54.030 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.43 A, current Output 2.13 W.
# 2025-06-16 12:26:54.686 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.48 A, current Output 2.20 W.
# 2025-06-16 12:26:55.342 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.53 A, current Output 2.26 W.
# 2025-06-16 12:26:56.014 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.58 A, current Output 2.31 W.
# 2025-06-16 12:26:56.670 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.63 A, current Output 2.38 W.
# 2025-06-16 12:26:57.326 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.68 A, current Output 2.44 W.
# 2025-06-16 12:26:57.982 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.73 A, current Output 2.50 W.
# 2025-06-16 12:26:58.638 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.78 A, current Output 2.57 W.
# 2025-06-16 12:26:59.311 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.84 A, current Output 2.63 W.
# 2025-06-16 12:26:59.966 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.89 A, current Output 2.69 W.
# 2025-06-16 12:27:00.621 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.94 A, current Output 2.76 W.
# 2025-06-16 12:27:01.278 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.99 A, current Output 2.81 W.
# 2025-06-16 12:27:01.934 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.04 A, current Output 2.87 W.
# 2025-06-16 12:27:02.606 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.09 A, current Output 2.93 W.
# 2025-06-16 12:27:03.262 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.14 A, current Output 2.99 W.
# 2025-06-16 12:27:03.918 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.19 A, current Output 3.05 W.
# 2025-06-16 12:27:04.574 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.24 A, current Output 3.11 W.
# 2025-06-16 12:27:05.230 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.29 A, current Output 3.19 W.
# 2025-06-16 12:27:05.902 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.34 A, current Output 3.25 W.
# 2025-06-16 12:27:06.559 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.39 A, current Output 3.28 W.
# 2025-06-16 12:27:07.215 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.44 A, current Output 3.35 W.
# 2025-06-16 12:27:07.870 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.49 A, current Output 3.41 W.
# 2025-06-16 12:27:08.526 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.54 A, current Output 3.48 W.
# 2025-06-16 12:27:09.198 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.59 A, current Output 3.53 W.
# 2025-06-16 12:27:09.854 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.65 A, current Output 3.59 W.
# 2025-06-16 12:27:10.510 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.70 A, current Output 3.66 W.
# 2025-06-16 12:27:11.166 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.75 A, current Output 3.72 W.
# 2025-06-16 12:27:11.822 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.80 A, current Output 3.78 W.
# 2025-06-16 12:27:12.495 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.85 A, current Output 3.84 W.
# 2025-06-16 12:27:13.150 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.90 A, current Output 3.91 W.
# 2025-06-16 12:27:13.806 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.95 A, current Output 3.96 W.
# 2025-06-16 12:27:14.462 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 4.00 A, current Output 4.01 W.
# comb status: FULL COMB
# 0

# %%
LFC_SET_STANDBY(1)
# Out:
# 2025-06-16 12:35:39.714 | INFO     | Pritel Amp | PritelAmp.py:connect:60
# Pritel Amp connected
# 2025-06-16 12:35:40.355 | INFO     | Pritel Amp | Device.py:disconnect:100
# Pritel Amp disconnected
# 2025-06-16 12:35:40.374 | INFO     | Amonics EDFA 23 dBm | Device.py:connect:88
# Amonics EDFA 23 dBm connected
# Pritel prime: 2
# 2025-06-16 12:35:43.019 | INFO     | Amonics EDFA 23 dBm | Device.py:disconnect:100
# Amonics EDFA 23 dBm disconnected
# Amonics EDFA 23 prime: 3
# 2025-06-16 12:35:43.036 | INFO     | Amonics EDFA 27 dBm | Device.py:connect:88
# Amonics EDFA 27 dBm connected
# 2025-06-16 12:35:43.699 | INFO     | Amonics EDFA 27 dBm | Device.py:disconnect:100
# Amonics EDFA 27 dBm disconnected
# Amonics EDFA 27 prime: 5
# 2025-06-16 12:35:43.714 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:connect:88
# RF oscilator PS, CH2 15V, CH3 1V connected
# 2025-06-16 12:35:45.268 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:disconnect:100
# RF oscilator PS, CH2 15V, CH3 1V disconnected
# RFOSCI prime: 7
# 2025-06-16 12:35:45.280 | INFO     | RF amplifier PS 30V 4A | Device.py:connect:88
# RF amplifier PS 30V 4A connected
# 2025-06-16 12:35:46.109 | INFO     | RF amplifier PS 30V 4A | Device.py:disconnect:100
# RF amplifier PS 30V 4A disconnected
# RFAMP prime: 11
# 2025-06-16 12:35:46.143 | INFO     | Pendulum microwave counter | Device.py:connect:88
# Pendulum microwave counter connected
# 2025-06-16 12:35:46.350 | INFO     | Pendulum microwave counter | PendulumCNT90.py:run:34
# Pendulum Freq Counter: Gate is turned on, measurement result is continuously updated on display.
# Pendulem prime: 13
# 2025-06-16 12:35:48.187 | INFO     | Pendulum microwave counter | Device.py:disconnect:100
# Pendulum microwave counter disconnected
# LFC status: FULL COMB
# 2025-06-16 12:35:48.910 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:151
# Pritel Amp: Disable Ramping by self.ramp_pwr_ma = 0, now 50 mA.
# 2025-06-16 12:35:49.881 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.90 A, current Output 3.90 W.
# 2025-06-16 12:35:50.537 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.85 A, current Output 3.87 W.
# 2025-06-16 12:35:51.209 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.80 A, current Output 3.81 W.
# 2025-06-16 12:35:51.865 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.75 A, current Output 3.74 W.
# 2025-06-16 12:35:52.521 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.70 A, current Output 3.69 W.
# 2025-06-16 12:35:53.177 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.65 A, current Output 3.64 W.
# 2025-06-16 12:35:53.834 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.60 A, current Output 3.58 W.
# 2025-06-16 12:35:54.489 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.55 A, current Output 3.52 W.
# 2025-06-16 12:35:55.161 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.49 A, current Output 3.47 W.
# 2025-06-16 12:35:55.817 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.44 A, current Output 3.39 W.
# 2025-06-16 12:35:56.473 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.39 A, current Output 3.33 W.
# 2025-06-16 12:35:57.130 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.34 A, current Output 3.27 W.
# 2025-06-16 12:35:57.786 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.29 A, current Output 3.21 W.
# 2025-06-16 12:35:58.458 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.24 A, current Output 3.16 W.
# 2025-06-16 12:35:59.113 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.19 A, current Output 3.10 W.
# 2025-06-16 12:35:59.769 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.14 A, current Output 3.04 W.
# 2025-06-16 12:36:00.425 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.09 A, current Output 2.99 W.
# 2025-06-16 12:36:01.081 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 3.04 A, current Output 2.93 W.
# 2025-06-16 12:36:01.753 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.99 A, current Output 2.86 W.
# 2025-06-16 12:36:02.410 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.94 A, current Output 2.80 W.
# 2025-06-16 12:36:03.066 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.89 A, current Output 2.74 W.
# 2025-06-16 12:36:03.721 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.84 A, current Output 2.69 W.
# 2025-06-16 12:36:04.378 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.79 A, current Output 2.64 W.
# 2025-06-16 12:36:05.050 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.74 A, current Output 2.58 W.
# 2025-06-16 12:36:05.705 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.68 A, current Output 2.53 W.
# 2025-06-16 12:36:06.361 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.63 A, current Output 2.46 W.
# 2025-06-16 12:36:07.017 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.58 A, current Output 2.39 W.
# 2025-06-16 12:36:07.674 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.53 A, current Output 2.33 W.
# 2025-06-16 12:36:08.346 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.48 A, current Output 2.27 W.
# 2025-06-16 12:36:09.002 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.43 A, current Output 2.22 W.
# 2025-06-16 12:36:09.657 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.38 A, current Output 2.15 W.
# 2025-06-16 12:36:10.313 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.33 A, current Output 2.10 W.
# 2025-06-16 12:36:10.970 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.28 A, current Output 2.05 W.
# 2025-06-16 12:36:11.642 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.23 A, current Output 1.99 W.
# 2025-06-16 12:36:12.297 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.18 A, current Output 1.92 W.
# 2025-06-16 12:36:12.953 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.13 A, current Output 1.85 W.
# 2025-06-16 12:36:13.610 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.08 A, current Output 1.79 W.
# 2025-06-16 12:36:14.266 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 2.03 A, current Output 1.74 W.
# 2025-06-16 12:36:14.937 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.98 A, current Output 1.69 W.
# 2025-06-16 12:36:15.594 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.92 A, current Output 1.62 W.
# 2025-06-16 12:36:16.250 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.87 A, current Output 1.56 W.
# 2025-06-16 12:36:16.906 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.82 A, current Output 1.50 W.
# 2025-06-16 12:36:17.562 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.77 A, current Output 1.43 W.
# 2025-06-16 12:36:18.234 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.72 A, current Output 1.38 W.
# 2025-06-16 12:36:18.889 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.67 A, current Output 1.32 W.
# 2025-06-16 12:36:19.546 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.62 A, current Output 1.27 W.
# 2025-06-16 12:36:20.201 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.57 A, current Output 1.22 W.
# 2025-06-16 12:36:20.858 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.52 A, current Output 1.16 W.
# 2025-06-16 12:36:21.530 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.47 A, current Output 1.09 W.
# 2025-06-16 12:36:22.186 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.42 A, current Output 1.04 W.
# 2025-06-16 12:36:22.842 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.37 A, current Output 0.98 W.
# 2025-06-16 12:36:23.498 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.32 A, current Output 0.92 W.
# 2025-06-16 12:36:24.154 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.27 A, current Output 0.86 W.
# 2025-06-16 12:36:24.826 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.22 A, current Output 0.80 W.
# 2025-06-16 12:36:25.482 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.16 A, current Output 0.76 W.
# 2025-06-16 12:36:26.137 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.11 A, current Output 0.69 W.
# 2025-06-16 12:36:26.794 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.06 A, current Output 0.63 W.
# 2025-06-16 12:36:27.449 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 1.01 A, current Output 0.58 W.
# 2025-06-16 12:36:28.122 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.96 A, current Output 0.52 W.
# 2025-06-16 12:36:28.778 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.91 A, current Output 0.46 W.
# 2025-06-16 12:36:29.434 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.86 A, current Output 0.41 W.
# 2025-06-16 12:36:30.090 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.81 A, current Output 0.36 W.
# 2025-06-16 12:36:30.746 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.76 A, current Output 0.31 W.
# 2025-06-16 12:36:31.418 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.71 A, current Output 0.26 W.
# 2025-06-16 12:36:32.073 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.66 A, current Output 0.20 W.
# 2025-06-16 12:36:32.730 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.61 A, current Output 0.14 W.
# 2025-06-16 12:36:33.386 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.56 A, current Output 0.10 W.
# 2025-06-16 12:36:34.042 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.51 A, current Output 0.05 W.
# 2025-06-16 12:36:34.698 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.46 A, current Output 0.00 W.
# 2025-06-16 12:36:35.370 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.41 A, current Output 0.00 W.
# 2025-06-16 12:36:36.026 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.35 A, current Output 0.00 W.
# 2025-06-16 12:36:36.682 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.30 A, current Output 0.00 W.
# 2025-06-16 12:36:37.338 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.25 A, current Output 0.00 W.
# 2025-06-16 12:36:37.994 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.20 A, current Output 0.00 W.
# 2025-06-16 12:36:38.666 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.15 A, current Output 0.00 W.
# 2025-06-16 12:36:39.322 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.10 A, current Output 0.00 W.
# 2025-06-16 12:36:39.978 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.05 A, current Output 0.00 W.
# 2025-06-16 12:36:40.634 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:157
# Pritel Amp: Setting PowerAmp Current to 0.00 A, current Output 0.00 W.
# 2025-06-16 12:36:41.136 | INFO     | Pritel Amp | PritelAmp.py:preAmp:115
# Pritel Amp: Disable Ramping by self.ramp_pre_ma = 0, now 100 mA.
# 2025-06-16 12:36:41.806 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 600 mA, current Output 0.00 W.
# 2025-06-16 12:36:42.282 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 500 mA, current Output 0.00 W.
# 2025-06-16 12:36:42.778 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 400 mA, current Output 0.00 W.
# 2025-06-16 12:36:43.274 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 300 mA, current Output 0.00 W.
# 2025-06-16 12:36:43.770 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 200 mA, current Output 0.00 W.
# 2025-06-16 12:36:44.266 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 100 mA, current Output 0.00 W.
# 2025-06-16 12:36:44.762 | INFO     | Pritel Amp | PritelAmp.py:preAmp:121
# Pritel Amp: Setting PreAmp Current to 000 mA, current Output 0.00 W.
# 2025-06-16 12:36:45.738 | INFO     | Pritel Amp | PritelAmp.py:activation:206
# Pritel Amp: setted Activation status as OFF, finished in 0.474 seconds
# 0

# %%
from KeckLFC.Hardware.Arduino_relay import Arduino_relay
def LFC_PTAMP_LATCH(value=None):
    """
    LFC PTAMP latch
    """
    if value == 1:
        
        try:
            
            arduino = Arduino_relay(addr="COM3")
            arduino.connect()

            
        except Exception as e:
            print(f"Failed to connect to Arduino: {e}")

        time.sleep(0.2)
        arduino.reset_relay_latch()
def LFC_SET_FULL_COMB(value=None):
    """
    Write keyword to set LFC to FULL COMB.
    """
    if value == 1:
        acomb_status = LFC_CHECK_STATUS()  # 获取当前状态
        # 已是 FULL COMB 不动
        if acomb_status == 'FULL COMB':
            #todo with Pritel
            pass
        # STANDBY -> 打开 Pritel -> FULL COMB
        elif acomb_status == 'STANDBY':

            LFC_PTAMP_LATCH(1)  # 确保 PTAMP 已经准备好
            # 这里假设 PTAMP 已经连接好
            time.sleep(0.5)
            ptamp = PritelAmp(addr=f'ASRL{7}::INSTR', name='Pritel Amp')
            time.sleep(0.5)
            ptamp.preAmp = 600
            time.sleep(0.5)
            ptamp.activation = 1
            time.sleep(0.5)
            ptamp.pwrAmp = '4A'
            time.sleep(5)
            ptamp.disconnect()
            # to do with Pritel
            acomb_status = 'FULL COMB'
            print(f"comb status: {acomb_status}")
        # OFF -> 先做一次 minicomb setup -> Pritel -> FULL COMB
        elif acomb_status == 'OFF':
            #LFC_MINICOMB_AUTO_SETUP(1)
            print("LFC_MINICOMB_AUTO_SETUP done, now setting FULL COMB")
            time.sleep(5)  # 等待设备稳定
            # LFC_PTAMP_LATCH(1)  # 确保 PTAMP 已经准备好
            # # 这里假设 PTAMP 已经连接好
            # time.sleep(0.5)
            # ptamp = PritelAmp(addr=f'ASRL{7}::INSTR', name='Pritel Amp')
            # time.sleep(0.5)
            # ptamp.preAmp = 600
            # time.sleep(0.5)
            # ptamp.activation = 1
            # time.sleep(0.5)
            # ptamp.pwrAmp = '4A'
            # time.sleep(5)
            # ptamp.disconnect()
            # acomb_status = 'FULL COMB'
        return 0
    else:
        return acomb_status

def LFC_SET_STANDBY(value=None):
    """
    Write keyword to set LFC to STANDBY.
    """
    # 只有在 KTL write 时才处理（value != None）
    if value in [1, True]:
        acomb_status = LFC_CHECK_STATUS()  # 获取当前状态
        # 从 FULL COMB -> close Pritel -> STANDBY
        if acomb_status == 'FULL COMB':

            ptamp = PritelAmp(addr=f'ASRL{7}::INSTR', name='Pritel Amp')
            time.sleep(0.5)
            ptamp.pwrAmp = '0A'
            time.sleep(0.5)
            ptamp.preAmp = 0
            time.sleep(0.5)
            ptamp.activation = 0
            time.sleep(0.5)
            ptamp.disconnect()  
                
            acomb_status = LFC_CHECK_STATUS()
            print(f"comb status: {acomb_status}")
        # 从 OFF -> full minicomb setup -> STANDBY
        elif acomb_status == 'OFF':
            #LFC_MINICOMB_AUTO_SETUP(1)  # 你的 auto setup 脚本
            print("LFC_MINICOMB_AUTO_SETUP done")
            acomb_status = 'STANDBY'
        # 如果已经 STANDBY，则不动
        elif acomb_status == 'STANDBY':
            pass  # 什么都不做
        else:
            print(f'LFC_SET_STANDBY encountered unexpected status: {acomb_status}')
        return 0
    else:
        # KTL read: 返回当前状态
        return acomb_status

# %%
def LFC_SET_OFF(self, value=None):
    """
    Write keyword to set LFC to OFF.
    """
    if value == 1:
        status = self.LFC_CHECK_STATUS()  # 获取当前状态
        # 如果是 FULL COMB 或 STANDBY，就一路倒回去关
        if status in ('FULL COMB', 'STANDBY'):
            ptamp=self.__LFC_PTAMP_connect()
            time.sleep(0.5)
            ptamp.pwrAmp = '0A'
            time.sleep(0.5)
            ptamp.preAmp = 0
            time.sleep(0.5)
            ptamp.activation = 0
            time.sleep(0.5)
            ptamp.disconnect()
            self.LFC_CLOSE_ALL(1)  # 关闭所有设备
            # … 如有其它设备也一并关闭 …
            acomb_status = 'OFF'
        # 如果已经 OFF，什么都不做
        elif status == 'OFF':
            pass  # 什么都不做
        else:
            print(f'LFC_SET_OFF encountered unexpected status: {status}')
        return 0
    else:
        return acomb_status


def LFC_MINICOMB_AUTO_SETUP(self, value=None):#TBD
    #if test_mode: return

    if value == 1:

        #self.LFC_RFAMP_DEfAULT(1)
        rfampPS = self.__LFC_RFAMP_connect()
        
        rfampPS.connect()
        time.sleep(0.5)
        rfampPS.Vout1=30
        time.sleep(0.5)
        rfampPS.Iout1=4.2

        
        time.sleep(0.5)
        #self.LFC_RFAMP_ONOFF(1)
        rfampPS.activation1=1
        self.__sleep(0.3)
        rfampPS.disconnect()

        #self.LFC_RFOSCI_DEfAULT(1)
        rfoscPS = self.__LFC_RFOSCI_connect()
        rfoscPS.connect()
        time.sleep(0.5)
        rfoscPS.Vset2=15
        time.sleep(0.5)
        rfoscPS.Iset2=3
        time.sleep(0.5)
        #self.LFC_RFOSCI_ONOFF(1)
        rfoscPS.activation=1
        self.__sleep(0.3)
        rfoscPS.disconnect()
        
        #self.LFC_EDFA27_DEfAULT(1)
        amonic27 = self.__LFC_EDFA27_connect()
        amonic27.connect()
        time.sleep(0.5)
        
        amonic27_input_power=amonic27.inputPowerCh1
        if ( amonic27_input_power <10 ) and ( amonic27_input_power >1):
            amonic27._setChMode('apc')
            time.sleep(0.5)
            amonic27.accCh1Cur='450mw'
            time.sleep(0.5)
            amonic27.accCh1Status= 1
            time.sleep(0.5)
            amonic27.activation= 1
            time.sleep(0.5)
            amonic27.disconnect()

            #self.LFC_EDFA23_DEfAULT(1)
            amonic23 = self.__LFC_EDFA23_connect()
            amonic23.connect()
            time.sleep(0.5)
            amonic23_input_power=amonic23.inputPowerCh1
            if ( amonic23_input_power <10 ) and ( amonic23_input_power >1):
                    
                    amonic23._setChMode('acc')
                    time.sleep(0.5)
                    amonic23.accCh1Cur='80mA'
                    time.sleep(0.5)
                    amonic23.accCh1Status= 1
                    amonic23.activation= 1
                    time.sleep(0.5)
                    amonic23.disconnect()
                    time.sleep(0.5)
                    self.LFC_IM_AUTO_LOCK(1) # auto lock IM
                    


            else:
                print('EDFA23 input power is not correct')
                amonic23.disconnect()

        else:
            print('EDFA27 input power is not correct')
            amonic27.disconnect()

    return 0

# %%
def LFC_IM_AUTO_LOCK(self, value=None):#TBD big problem
        #if test_mode: return

        if value in [1,True]:
            #osa = self.__LFC_OSA_connect()
            srs = self.__LFC_servo_connect()
            
            srs.connect()
            servo_IM = self.__LFC_IM_LOCK_connect(srs)
            #osa.connect()
            servo_IM.output_mode='man'
            servo_IM.output_upperlim = 3
            servo_IM.output_lowerlim = -3
            servo_IM.prop_gain=2  #-2
            servo_IM.intg_gain=0.1   #1
            #score_best = 0

                
                #x,y=osa.get_trace()
                #score_now = self.__score_eo_comb(osa)
                # if score_now>score_best:
                #     score_best=score_now
                #     best_v=v
            v_values = np.arange(-2.0, 1.0, 0.02)
            inputs = []
            for v in v_values:
                servo_IM.manual_output = v
                self.__sleep(0.2)
                inputs.append(servo_IM.measure_input)
            inputs = np.array(inputs)

            # 找到 max/min 及其索引
            idx_max = np.argmax(inputs)
            idx_min = np.argmin(inputs)
            v_max, v_min = v_values[idx_max], v_values[idx_min]
            max_in, min_in = inputs[idx_max], inputs[idx_min]

            # 计算斜率，并正负决定 prop_gain 符号
            slope = (max_in - min_in) / (v_max - v_min)
            if slope < 0:
                servo_IM.prop_gain = -abs(servo_IM.prop_gain)

            # 计算中点，选最接近中点的 v 作为 best_v
            target = (max_in + min_in) / 2
            best_idx = int(np.argmin(np.abs(inputs - target)))
            best_v = v_values[best_idx]

            # 应用最佳电压
            servo_IM.manual_output = best_v
            set_point = servo_IM.measure_input
            servo_IM.outoffset = best_v
            servo_IM.set_setpoint(set_point)

            servo_IM.output_mode='pid'
            time.sleep(0.5)
            srs.disconnect()

            return 1
        else:
            return 0  # If value is not 1, do nothing and return 0

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
from KeckLFC.Hardware.Agilent_86142B import Agilent_86142B

osa = Agilent_86142B()
osa.connect()
# Out:
# 2025-10-28 08:15:07.917 | INFO     | Device | Device.py:<module>:61
# logger initialized
# 2025-10-28 08:15:09.559 | INFO     | Agilent 86142B | Device.py:connect:228
# Agilent 86142B connected
# 1

# %%
osa.Run()
# Out:
# 2025-09-11 11:53:47.865 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.

# %%
osa.wlstart=1553
osa.wlstop=1567
osa.reflevel=-40
osa.get_trace('a')
# Out:
# 2025-10-28 08:15:12.677 | INFO     | Agilent 86142B | Agilent_86142B.py:set_wlstart:118
# Agilent 86142B: Scan start wavelength set to 1553.00 nm.
# 2025-10-28 08:15:12.963 | INFO     | Agilent 86142B | Agilent_86142B.py:set_wlstop:127
# Agilent 86142B: Scan stop wavelength set to 1567.00 nm.
# 2025-10-28 08:15:13.199 | INFO     | Agilent 86142B | Agilent_86142B.py:set_reflevel:109
# Agilent 86142B: Reference level set to -40.0 dBm.
# 2025-10-28 08:15:14.130 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# (array([1553.   , 1553.014, 1553.028, ..., 1566.972, 1566.986, 1567.   ],
#        dtype=float32),
#  array([-79.120125, -79.120125, -73.65109 , ..., -73.55049 , -76.39243 ,
#         -75.41782 ], dtype=float32))

# %%
filedir = r'C:\Users\KeckLFC\Desktop\hispec'
filename = r'\3m_hnlf_for1550_3.63w'
filr = filedir + filename
osa.save_trace('a', filr)
# Out:
# 2025-05-17 11:15:25.950 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# 2025-05-17 11:15:25.960 | INFO     | Agilent 86142B | Agilent_86142B.py:save_trace:397
# Agilent 86142B: Trace A data is saved to C:\Users\KeckLFC\Desktop\hispec\3m_hnlf_for1550_3.63w.mat
# 2025-05-17 11:15:25.970 | INFO     | Agilent 86142B | Agilent_86142B.py:save_trace:412
# Agilent 86142B: Trace A data is saved to C:\Users\KeckLFC\Desktop\hispec\3m_hnlf_for1550_3.63w.txt

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
input_power=2
if (input_power>10) or (input_power<1):
    print('wrong')

# %%
osa.disconnect()
# Out:
# 2024-07-17 12:20:58.978 | INFO     | Agilent 86142B | Device.py:disconnect:90
# Agilent 86142B disconnected
# 1

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BC2E-EE77
#
#  Directory of c:\Users\KeckLFC\KeckLFC-main\KeckLFC\Notebooks
#
# 07/17/2024  08:30 PM    <DIR>          .
# 07/18/2024  07:02 PM    <DIR>          ..
# 11/03/2023  12:35 PM            52,871 AndoOSA_test.ipynb
# 11/03/2023  12:35 PM        11,504,127 Compression_Stage_Test.ipynb
# 05/27/2024  10:18 AM            47,665 email_test.ipynb
# 11/03/2023  12:35 PM         3,929,808 Filter-Cavity-Locking-Test.ipynb
# 03/05/2024  10:43 AM         2,418,222 July_Commission.ipynb
# 11/03/2023  12:35 PM           451,323 Jun_Commission.ipynb
# 11/03/2023  12:35 PM           434,279 KeckLFC_class_test.ipynb
# 02/07/2024  02:07 PM               258 KTL_test.py
# 11/03/2023  12:35 PM            43,815 LFI-3751_test.ipynb
# 06/23/2024  06:52 PM           660,357 Minicomb_test_Feb.ipynb
# 07/17/2024  08:30 PM           914,032 new_laptop_test.ipynb
# 11/03/2023  12:35 PM             7,469 OZvoaTest.ipynb
# 11/03/2023  12:35 PM             1,826 pendulum_test.ipynb
# 07/15/2024  08:22 AM           127,804 pulse_sim.ipynb
# 11/03/2023  12:35 PM           107,824 pyRPL_test.ipynb
# 11/03/2023  12:35 PM           164,022 Rack_Reconfigure_test.ipynb
# 11/03/2023  12:35 PM            70,605 redpitaya_test-Copy1.ipynb
# 11/03/2023  12:35 PM            70,900 redpitaya_test-Copy2.ipynb
# 11/03/2023  12:35 PM            72,956 redpitaya_test.ipynb
# 03/05/2024  10:43 AM           538,042 remote_lock.ipynb
# 11/03/2023  12:35 PM            36,110 RIO_test-Copy1.ipynb
# 11/03/2023  12:35 PM            46,336 RIO_test.ipynb
# 11/03/2023  12:35 PM            31,385 SRS_SIM900_test.ipynb
# 11/03/2023  12:35 PM        12,426,371 TDS2024C_test.ipynb
# 03/05/2024  10:43 AM           256,932 test.ipynb
# 11/03/2023  12:35 PM           298,676 Untitled.ipynb
# 11/03/2023  12:35 PM            11,016 USB2408_test.ipynb
# 11/03/2023  12:35 PM            22,067 VAmp_test.ipynb
# 11/03/2023  12:35 PM           116,621 Waveshaper_class_test.ipynb
# 04/17/2024  01:42 PM           749,706 ws.log
#               30 File(s)     35,613,425 bytes
#                2 Dir(s)  357,827,424,256 bytes free

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
cd KeckLFC-main
# Out:
# [WinError 2] The system cannot find the file specified: 'KeckLFC-main'
# c:\Users\KeckLFC\KeckLFC-main\KeckLFC\Notebooks

# %%
# osa.wlstop =1567
osa.set_resolution(0.01)
osa.set_sens(0.1)
osa.Run()
osa.get_trace('a')
# Out:
# 2025-09-28 12:02:02.501 | INFO     | Agilent 86142B | Agilent_86142B.py:set_resolution:160
# Agilent 86142B: Resolution set to 0.06 nm.
# 2025-09-28 12:02:02.761 | INFO     | Agilent 86142B | Agilent_86142B.py:set_sens:183
# Agilent 86142B: OSA sensitivity set to 0.10 dBm.
# 2025-09-28 12:02:02.761 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-09-28 12:02:03.634 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# (array([1553.   , 1553.014, 1553.028, ..., 1566.972, 1566.986, 1567.   ],
#        dtype=float32),
#  array([-75.6052  , -82.494156, -82.494156, ..., -76.78954 , -78.43746 ,
#         -77.39363 ], dtype=float32))

# %%
osa.set_reflevel(-40)
# Out:
# 2024-02-22 14:18:32.631 | INFO     | Agilent 86142B | Agilent_86142B.py:set_reflevel:109
# Agilent 86142B: Reference level set to -40.0 dBm.

# %%
osa.set_resolution(0.05)
osa.get_resolution()
# Out:
# 2024-07-17 12:23:41.140 | INFO     | Agilent 86142B | Agilent_86142B.py:set_resolution:160
# Agilent 86142B: Resolution set to 0.06 nm.
# 0.06

# %%
osa.write(f'SENS:WAV:STAR {1550:.2f}nm')
osa.get_wlcenter()
# Out:
# 1625.0

# %%
from KeckLFC.Hardware.AmonicsEDFA import AmonicsEDFA
amonic27 = AmonicsEDFA(addr=f'ASRL{6}::INSTR', name='Amonics EDFA 27 dBm')
amonic27.connect()
amonic27.printStatus()
# Out:
# 2025-10-12 07:54:43.405 | INFO     | Amonics EDFA 27 dBm | Device.py:connect:228
# Amonics EDFA 27 dBm connected
# 2025-10-12 07:54:43.731 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:printStatus:64
# -------------------------------Amonics EDFA 27 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 25.94°C
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: APC
# |		 Set Pwr: 450.0 mW
# |		 Status: ON
# |		 Input Power: 8.385251 mW
# |		 Output Power: 451.1039 mW
# |		 Internal PD Power: 326.6098 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 27 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 25.94°C\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: APC\n|\t\t Set Pwr: 450.0 mW\n|\t\t Status: \x1bON\x1b\n|\t\t Input Power: 8.385251 mW\n|\t\t Output Power: 451.1039 mW\n|\t\t Internal PD Power: 326.6098 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
amonic27._setChMode('apc')
# Out:
# 2024-07-17 12:12:49.055 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setChMode:297
# Amonics EDFA 27 dBm: CH1 mode set as apc

# %%
amonic27.accCh1Cur='450mw'
# Out:
# 2024-07-17 12:13:06.456 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setIorP:229
# Amonics EDFA 27 dBm: setted APC mode CH1 current as 450.0 mW.

# %%
amonic27.accCh1Status = 1
amonic27.activation = 1
# Out:
# 2024-11-20 12:24:27.670 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setChStatus:278
# Amonics EDFA 27 dBm: ......waiting APC CH1 status set to ON, now OFF
# 2024-11-20 12:24:27.717 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setChStatus:281
# Amonics EDFA 27 dBm: setted APC CH1 status as ON, finished in 0.091 seconds
# 2024-11-20 12:24:27.755 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:activation:185
# Amonics EDFA 27 dBm: ACTIVATING LASER OUTPUT, MAKE SURE SEED INPUT POWER IS APPROPRIATE TO AVOID DAMAGE
# 2024-11-20 12:24:27.780 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:activation:192
# Amonics EDFA 27 dBm: ......waiting Activation status set to ON, now OFF
# 2024-11-20 12:24:27.831 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:activation:195
# Amonics EDFA 27 dBm: setted Activation status as ON, finished in 0.075 seconds

# %%
amonic27.printStatus()
# Out:
# 2024-11-20 12:24:36.363 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:printStatus:49
# -------------------------------Amonics EDFA 27 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 22.56°C
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: APC
# |		 Set Pwr: 450.0 mW
# |		 Status: ON
# |		 Input Power: 5.301677 mW
# |		 Output Power: 447.3162 mW
# |		 Internal PD Power: 328.4008 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 27 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 22.56°C\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: APC\n|\t\t Set Pwr: 450.0 mW\n|\t\t Status: \x1bON\x1b\n|\t\t Input Power: 5.301677 mW\n|\t\t Output Power: 447.3162 mW\n|\t\t Internal PD Power: 328.4008 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
rfoscPS.printStatus()
# Out:
# 2024-07-17 12:13:23.962 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:printStatus:200
# -------------------------RF oscilator PS, CH2 15V, CH3 1V------------------------
# |----------------Instek DC Power Supply GPD-4303S Status Summary-----------------
# |--------------------Model: GPD-4303S, Serial No.SN:EV884423---------------------
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CH1: master, CH2: slave, mode UNRECOGNIZED?.
# |	 CHANNEL1: CC Mode.
# |		 VSET=0.000V, ISET=0.000A.
# |		 VOUT=0.000V, IOUT=0.000A.
# |		 Output power: 0.000W.
# |	 CHANNEL2: CV Mode.
# |		 VSET=15.000V, ISET=3.000A.
# |		 VOUT=14.998V, IOUT=0.431A.
# |		 Output power: 6.464W.
# |	 CHANNEL3: CV Mode.
# |		 VSET=0.100V, ISET=1.000A.
# |		 VOUT=0.099V, IOUT=0.001A.
# |		 Output power: 0.000W.
# |	 CHANNEL4: CV Mode.
# |		 VSET=0.000V, ISET=0.000A.
# |		 VOUT=0.000V, IOUT=0.000A.
# |		 Output power: 0.000W.
# --------------Instek DC Power Supply GPD-4303S Status Summary Ends--------------
# '-------------------------RF oscilator PS, CH2 15V, CH3 1V------------------------\n|----------------Instek DC Power Supply GPD-4303S Status Summary-----------------\n|--------------------Model: GPD-4303S, Serial No.SN:EV884423---------------------\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CH1: master, CH2: slave, mode UNRECOGNIZED?.\n|\t CHANNEL1: CC Mode.\n|\t\t VSET=0.000V, ISET=0.000A.\n|\t\t VOUT=0.000V, IOUT=0.000A.\n|\t\t Output power: 0.000W.\n|\t CHANNEL2: CV Mode.\n|\t\t VSET=15.000V, ISET=3.000A.\n|\t\t VOUT=14.998V, IOUT=0.431A.\n|\t\t Output power: 6.464W.\n|\t CHANNEL3: CV Mode.\n|\t\t VSET=0.100V, ISET=1.000A.\n|\t\t VOUT=0.099V, IOUT=0.001A.\n|\t\t Output power: 0.000W.\n|\t CHANNEL4: CV Mode.\n|\t\t VSET=0.000V, ISET=0.000A.\n|\t\t VOUT=0.000V, IOUT=0.000A.\n|\t\t Output power: 0.000W.\n--------------Instek DC Power Supply GPD-4303S Status Summary Ends--------------\n'

# %%
from KeckLFC.Hardware.InstekGPD_4303S import InstekGPD_4303S
rfoscPS = InstekGPD_4303S(addr='ASRL13::INSTR', name='RF oscilator PS, CH2 15V, CH3 1V')
rfoscPS.connect()
rfoscPS.printStatus()
# Out:
# 2025-10-28 08:21:31.690 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:connect:228
# RF oscilator PS, CH2 15V, CH3 1V connected
# 2025-10-28 08:21:44.676 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:printStatus:200
# -------------------------RF oscilator PS, CH2 15V, CH3 1V------------------------
# |----------------Instek DC Power Supply GPD-4303S Status Summary-----------------
# |--------------------Model: GPD-4303S, Serial No.SN:EV884423---------------------
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CH1: master, CH2: slave, mode UNRECOGNIZED?.
# |	 CHANNEL1: CC Mode.
# |		 VSET=0.000V, ISET=0.000A.
# |		 VOUT=0.000V, IOUT=0.001A.
# |		 Output power: 0.000W.
# |	 CHANNEL2: CV Mode.
# |		 VSET=15.000V, ISET=3.000A.
# |		 VOUT=14.998V, IOUT=0.386A.
# |		 Output power: 5.789W.
# |	 CHANNEL3: CV Mode.
# |		 VSET=0.800V, ISET=1.000A.
# |		 VOUT=0.800V, IOUT=0.002A.
# |		 Output power: 0.002W.
# |	 CHANNEL4: CV Mode.
# |		 VSET=0.000V, ISET=0.000A.
# |		 VOUT=0.000V, IOUT=0.001A.
# |		 Output power: 0.000W.
# --------------Instek DC Power Supply GPD-4303S Status Summary Ends--------------
# '-------------------------RF oscilator PS, CH2 15V, CH3 1V------------------------\n|----------------Instek DC Power Supply GPD-4303S Status Summary-----------------\n|--------------------Model: GPD-4303S, Serial No.SN:EV884423---------------------\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CH1: master, CH2: slave, mode UNRECOGNIZED?.\n|\t CHANNEL1: CC Mode.\n|\t\t VSET=0.000V, ISET=0.000A.\n|\t\t VOUT=0.000V, IOUT=0.001A.\n|\t\t Output power: 0.000W.\n|\t CHANNEL2: CV Mode.\n|\t\t VSET=15.000V, ISET=3.000A.\n|\t\t VOUT=14.998V, IOUT=0.386A.\n|\t\t Output power: 5.789W.\n|\t CHANNEL3: CV Mode.\n|\t\t VSET=0.800V, ISET=1.000A.\n|\t\t VOUT=0.800V, IOUT=0.002A.\n|\t\t Output power: 0.002W.\n|\t CHANNEL4: CV Mode.\n|\t\t VSET=0.000V, ISET=0.000A.\n|\t\t VOUT=0.000V, IOUT=0.001A.\n|\t\t Output power: 0.000W.\n--------------Instek DC Power Supply GPD-4303S Status Summary Ends--------------\n'

# %%
rfoscPS.disconnect()
# Out:
# 2025-09-07 18:35:03.166 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | Device.py:disconnect:157
# RF oscilator PS, CH2 15V, CH3 1V disconnected
# 1

# %%
rfoscPS.printStatus()
# Out:
# 2024-11-20 12:25:52.339 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:printStatus:200
# -------------------------RF oscilator PS, CH2 15V, CH3 1V------------------------
# |----------------Instek DC Power Supply GPD-4303S Status Summary-----------------
# |--------------------Model: GPD-4303S, Serial No.SN:EV884423---------------------
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CH1: master, CH2: slave, mode UNRECOGNIZED?.
# |	 CHANNEL1: CC Mode.
# |		 VSET=0.000V, ISET=0.000A.
# |		 VOUT=0.000V, IOUT=0.000A.
# |		 Output power: 0.000W.
# |	 CHANNEL2: CV Mode.
# |		 VSET=15.000V, ISET=3.000A.
# |		 VOUT=14.997V, IOUT=0.609A.
# |		 Output power: 9.148W.
# |	 CHANNEL3: CV Mode.
# |		 VSET=0.700V, ISET=1.000A.
# |		 VOUT=0.700V, IOUT=0.001A.
# |		 Output power: 0.001W.
# |	 CHANNEL4: CV Mode.
# |		 VSET=0.000V, ISET=0.000A.
# |		 VOUT=0.000V, IOUT=0.000A.
# |		 Output power: 0.000W.
# --------------Instek DC Power Supply GPD-4303S Status Summary Ends--------------
# '-------------------------RF oscilator PS, CH2 15V, CH3 1V------------------------\n|----------------Instek DC Power Supply GPD-4303S Status Summary-----------------\n|--------------------Model: GPD-4303S, Serial No.SN:EV884423---------------------\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CH1: master, CH2: slave, mode UNRECOGNIZED?.\n|\t CHANNEL1: CC Mode.\n|\t\t VSET=0.000V, ISET=0.000A.\n|\t\t VOUT=0.000V, IOUT=0.000A.\n|\t\t Output power: 0.000W.\n|\t CHANNEL2: CV Mode.\n|\t\t VSET=15.000V, ISET=3.000A.\n|\t\t VOUT=14.997V, IOUT=0.609A.\n|\t\t Output power: 9.148W.\n|\t CHANNEL3: CV Mode.\n|\t\t VSET=0.700V, ISET=1.000A.\n|\t\t VOUT=0.700V, IOUT=0.001A.\n|\t\t Output power: 0.001W.\n|\t CHANNEL4: CV Mode.\n|\t\t VSET=0.000V, ISET=0.000A.\n|\t\t VOUT=0.000V, IOUT=0.000A.\n|\t\t Output power: 0.000W.\n--------------Instek DC Power Supply GPD-4303S Status Summary Ends--------------\n'

# %%
rfoscPS.activation = 1
# Out:
# 2024-11-20 12:25:36.492 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:activation:44
# Instek GPD-4303S DCSupply: Output activation is turned ON.

# %%
from KeckLFC.Hardware.InstekGppDCSupply import InstekGppDCSupply

rfampPS = InstekGppDCSupply(addr=f'ASRL{24}::INSTR', name='RF amplifier PS 30V 4A')
rfampPS.connect()
rfampPS.printStatus()
# Out:
# 2025-10-12 07:55:21.177 | INFO     | RF amplifier PS 30V 4A | Device.py:connect:228
# RF amplifier PS 30V 4A connected
# 2025-10-12 07:55:21.318 | INFO     | RF amplifier PS 30V 4A | InstekGppDCSupply.py:printStatus:56
# ------------------------------RF amplifier PS 30V 4A-----------------------------
# |-------------------Instek GPP DC Power Supply Status Summary--------------------
# |--------------------Model: GPP-1326, Serial No.SN:GET842785---------------------
# |	------------Channel Summary-------------
# |	 CHANNEL1: Activation ON.
# |		 VSET=30.000V, ISET=4.200A.
# |		 VOUT=29.991V, IOUT=3.888A.
# |		 Output power: 116.593W.
# |		 ---Over Voltage/Current Protection Status:---
# |		 OVP Status: OFF	 OCP Status: OFF
# |		 OVP Level : 35.0 V	 OCP Level : 7.0 A
# -----------------Instek GPP DC Power Supply Status Summary Ends-----------------
# '------------------------------RF amplifier PS 30V 4A-----------------------------\n|-------------------Instek GPP DC Power Supply Status Summary--------------------\n|--------------------Model: GPP-1326, Serial No.SN:GET842785---------------------\n|\t------------Channel Summary-------------\n|\t CHANNEL1: Activation \x1bON\x1b.\n|\t\t VSET=30.000V, ISET=4.200A.\n|\t\t VOUT=29.991V, IOUT=3.888A.\n|\t\t Output power: 116.593W.\n|\t\t ---Over Voltage/Current Protection Status:---\n|\t\t OVP Status: OFF\t OCP Status: OFF \n|\t\t OVP Level : 35.0 V\t OCP Level : 7.0 A\n-----------------Instek GPP DC Power Supply Status Summary Ends-----------------\n'

# %%
rfampPS.Vset1=30
rfampPS.Iset1=4.2
# Out:
# 2024-07-17 12:09:11.139 | INFO     | RF amplifier PS 30V 4A | InstekGppDCSupply.py:_setVSET:284
# RF amplifier PS 30V 4A: VSET channel 1 set to 30.000V
# 2024-07-17 12:09:11.173 | INFO     | RF amplifier PS 30V 4A | InstekGppDCSupply.py:_setISET:260
# RF amplifier PS 30V 4A: ISET channel 1 set to 4.200A

# %%
rfampPS.activation1 = 1
# Out:
# 2024-11-20 12:25:24.766 | INFO     | RF amplifier PS 30V 4A | InstekGppDCSupply.py:_setOutputStatus:237
# RF amplifier PS 30V 4A: channel 1 output is turned ON

# %%
rfampPS.printStatus()
# Out:
# 2024-11-20 12:26:01.815 | INFO     | RF amplifier PS 30V 4A | InstekGppDCSupply.py:printStatus:56
# ------------------------------RF amplifier PS 30V 4A-----------------------------
# |-------------------Instek GPP DC Power Supply Status Summary--------------------
# |--------------------Model: GPP-1326, Serial No.SN:GET842785---------------------
# |	------------Channel Summary-------------
# |	 CHANNEL1: Activation ON.
# |		 VSET=30.000V, ISET=4.200A.
# |		 VOUT=29.994V, IOUT=4.026A.
# |		 Output power: 120.741W.
# |		 ---Over Voltage/Current Protection Status:---
# |		 OVP Status: OFF	 OCP Status: OFF
# |		 OVP Level : 35.0 V	 OCP Level : 7.0 A
# -----------------Instek GPP DC Power Supply Status Summary Ends-----------------
# '------------------------------RF amplifier PS 30V 4A-----------------------------\n|-------------------Instek GPP DC Power Supply Status Summary--------------------\n|--------------------Model: GPP-1326, Serial No.SN:GET842785---------------------\n|\t------------Channel Summary-------------\n|\t CHANNEL1: Activation \x1bON\x1b.\n|\t\t VSET=30.000V, ISET=4.200A.\n|\t\t VOUT=29.994V, IOUT=4.026A.\n|\t\t Output power: 120.741W.\n|\t\t ---Over Voltage/Current Protection Status:---\n|\t\t OVP Status: OFF\t OCP Status: OFF \n|\t\t OVP Level : 35.0 V\t OCP Level : 7.0 A\n-----------------Instek GPP DC Power Supply Status Summary Ends-----------------\n'

# %%
from KeckLFC.Hardware.AmonicsEDFA import AmonicsEDFA
amonic27 = AmonicsEDFA(addr=f'ASRL{6}::INSTR', name='Amonics EDFA 27 dBm')
amonic27.connect()
amonic27.printStatus()
# Out:
# 2025-06-10 18:45:18.681 | INFO     | Amonics EDFA 27 dBm | Device.py:connect:88
# Amonics EDFA 27 dBm connected
# 2025-06-10 18:45:19.021 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:printStatus:49
# -------------------------------Amonics EDFA 27 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 26.34°C
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: APC
# |		 Set Pwr: 450.0 mW
# |		 Status: ON
# |		 Input Power: 7.223991 mW
# |		 Output Power: 451.1039 mW
# |		 Internal PD Power: 325.8422 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 27 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 26.34°C\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: APC\n|\t\t Set Pwr: 450.0 mW\n|\t\t Status: \x1bON\x1b\n|\t\t Input Power: 7.223991 mW\n|\t\t Output Power: 451.1039 mW\n|\t\t Internal PD Power: 325.8422 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
amonic27.accCh1Cur = '450mA'
amonic27.accCh1Status = 1
amonic27.activation = 1
# Out:
# 2025-04-07 13:01:48.665 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setIorP:229
# Amonics EDFA 27 dBm: setted APC mode CH1 current as 450.0 mW.
# 2025-04-07 13:01:48.713 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setChStatus:278
# Amonics EDFA 27 dBm: ......waiting APC CH1 status set to ON, now OFF
# 2025-04-07 13:01:48.759 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:_setChStatus:281
# Amonics EDFA 27 dBm: setted APC CH1 status as ON, finished in 0.079 seconds
# 2025-04-07 13:01:48.784 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:activation:185
# Amonics EDFA 27 dBm: ACTIVATING LASER OUTPUT, MAKE SURE SEED INPUT POWER IS APPROPRIATE TO AVOID DAMAGE
# 2025-04-07 13:01:48.823 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:activation:192
# Amonics EDFA 27 dBm: ......waiting Activation status set to ON, now OFF
# 2025-04-07 13:01:48.873 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:activation:195
# Amonics EDFA 27 dBm: setted Activation status as ON, finished in 0.080 seconds

# %%
amonic27.printStatus()
# Out:
# 2025-04-07 12:55:24.685 | INFO     | Amonics EDFA 27 dBm | AmonicsEDFA.py:printStatus:49
# -------------------------------Amonics EDFA 27 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 28.04°C
# |	Master Activation: OFF
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: APC
# |		 Set Pwr: 450.0 mW
# |		 Status: OFF
# |		 Input Power: 6.258659 mW
# |		 Output Power: 0.0 mW
# |		 Internal PD Power: 0.0 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 27 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-27-R-FA, Serial No.21082531-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 28.04°C\n|\tMaster Activation: \x1bOFF\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: APC\n|\t\t Set Pwr: 450.0 mW\n|\t\t Status: \x1bOFF\x1b\n|\t\t Input Power: 6.258659 mW\n|\t\t Output Power: 0.0 mW\n|\t\t Internal PD Power: 0.0 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
amonic27.inputPowerCh1
# Out:
# 0.0

# %%
osa.get_trace('a')
# Out:
# 2024-12-06 07:36:23.306 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# (array([1553.   , 1553.014, 1553.028, ..., 1566.972, 1566.986, 1567.   ],
#        dtype=float32),
#  array([-76.501175, -77.26678 , -78.87862 , ..., -79.77604 , -78.86656 ,
#         -77.83223 ], dtype=float32))

# %%
import numpy as np
import time
import smtplib

import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def score_eo_comb(osa):
    
    osa.wlstart=1553
    osa.wlstop=1567
    osa.reflevel=-40
    osa.set_resolution(0.06)
    
    osa.Single()
    time.sleep(0.5)
    x,y=osa.get_trace('a')

    
    #x1=x[np.where((x>start_wl) & (x<stop_wl))] 
    y1=y[np.where((x>1553) & (x<1567))]
    
    hight_shreshold=-50
    peaks,_ = find_peaks(y1, height=hight_shreshold, distance=2, width=0.02e-9)
    num_peaks = len(peaks)

    score=np.std(y1[peaks])*-1
    return score

# %%
osa.Single()
# Out:
# 2024-07-21 14:08:37.686 | INFO     | Agilent 86142B | Agilent_86142B.py:Single:168
# Agilent 86142B: Spectrum collection SINGLE run start.

# %%
x,y=osa.get_trace('a')
# Out:
# 2024-07-22 08:41:12.327 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.

# %%
peaks,_ = find_peaks(y, height=-50, distance=2,width=0.02e-9)

# %%
plt.plot(x,y)
plt.plot(x[peaks],y[peaks],'o')

# %%
score_eo_comb(osa)
# Out:
# 2024-07-21 14:09:36.491 | INFO     | Agilent 86142B | Agilent_86142B.py:set_wlstart:118
# Agilent 86142B: Scan start wavelength set to 1553.00 nm.
# 2024-07-21 14:09:36.778 | INFO     | Agilent 86142B | Agilent_86142B.py:set_wlstop:127
# Agilent 86142B: Scan stop wavelength set to 1567.00 nm.
# 2024-07-21 14:09:37.013 | INFO     | Agilent 86142B | Agilent_86142B.py:set_reflevel:109
# Agilent 86142B: Reference level set to -40.0 dBm.
# 2024-07-21 14:09:37.264 | INFO     | Agilent 86142B | Agilent_86142B.py:set_resolution:160
# Agilent 86142B: Resolution set to 0.06 nm.
# 2024-07-21 14:09:37.268 | INFO     | Agilent 86142B | Agilent_86142B.py:Single:168
# Agilent 86142B: Spectrum collection SINGLE run start.
# 2024-07-21 14:09:38.445 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# -1.9384628534317017

# %%
import time
servo_IM.manual_output = -0.5
rfoscPS.Vset3=0.8
time.sleep(1)
osa.Run()
osa.get_trace('a')
# import time
# time.sleep(1)
# osa.get_trace('a')
# Out:
# 2025-06-10 19:16:38.760 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:666
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramping.... Disable ranp by set self.manual_output_ramp=0.
# 2025-06-10 19:16:38.970 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.400.
# 2025-06-10 19:16:39.177 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.500.
# 2025-06-10 19:16:39.185 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:681
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramp Finished. Disable ramp by set self.manual_output_ramp=0.
# 2025-06-10 19:16:39.678 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.800V
# 2025-06-10 19:16:40.690 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-06-10 19:16:41.695 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# (array([1553.   , 1553.014, 1553.028, ..., 1566.972, 1566.986, 1567.   ],
#        dtype=float32),
#  array([-79.120125, -79.120125, -79.120125, ..., -78.95348 , -75.892944,
#         -71.78564 ], dtype=float32))

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
from KeckLFC.Hardware.AmonicsEDFA import AmonicsEDFA
amonic23 = AmonicsEDFA(addr=f'ASRL{12}::INSTR', name='Amonics EDFA 23 dBm')
amonic23.connect()
amonic23.printStatus()
# Out:
# 2025-10-11 19:59:51.135 | INFO     | Device | Device.py:<module>:61
# logger initialized
# 2025-10-11 19:59:51.590 | INFO     | Amonics EDFA 23 dBm | Device.py:connect:228
# Amonics EDFA 23 dBm connected
# 2025-10-11 19:59:53.716 | WARNING  | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:295
# Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
# c:\Users\KeckLFC\KeckLFC-main\KeckLFC\Hardware\Device.py:360: UserWarning: Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
#   warnings.warn(x)
# 2025-10-11 19:59:55.937 | ERROR    | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:327
# Amonics EDFA 23 dBm I/O failed after reconnect: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
# 2025-10-11 19:59:57.940 | WARNING  | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:295
# Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
# 2025-10-11 20:00:00.149 | ERROR    | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:327
# Amonics EDFA 23 dBm I/O failed after reconnect: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
# 2025-10-11 20:00:02.199 | WARNING  | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:295
# Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
# 2025-10-11 20:00:04.413 | ERROR    | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:327
# Amonics EDFA 23 dBm I/O failed after reconnect: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
# 2025-10-11 20:00:04.533 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:printStatus:64
# -------------------------------Amonics EDFA 23 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-23-R-FA, Serial No.22020702-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 31.51°C
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: ACC
# |		 Set Cur: 80.0 mA
# |		 Status: ON
# |		 Input Power: 3.489374 mW
# |		 Output Power: 6.39128 mW
# |		 Internal PD Power: 45.25104 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 23 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-23-R-FA, Serial No.22020702-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 31.51°C\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: ACC\n|\t\t Set Cur: 80.0 mA\n|\t\t Status: \x1bON\x1b\n|\t\t Input Power: 3.489374 mW\n|\t\t Output Power: 6.39128 mW\n|\t\t Internal PD Power: 45.25104 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
amonic23.accCh1Cur = '80mA'
amonic23.accCh1Status = 1
amonic23.activation = 1
# Out:
# 2025-09-07 18:47:23.717 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:_setIorP:241
# Amonics EDFA 23 dBm: setted ACC mode CH1 current as 80.0 mA.
# 2025-09-07 18:47:25.747 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:_setChStatus:292
# Amonics EDFA 23 dBm: ......waiting ACC CH1 status set to ON, now OFF
# 2025-09-07 18:47:25.797 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:_setChStatus:295
# Amonics EDFA 23 dBm: setted ACC CH1 status as ON, finished in 0.081 seconds
# 2025-09-07 18:47:27.811 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:activation:199
# Amonics EDFA 23 dBm: ACTIVATING LASER OUTPUT, MAKE SURE SEED INPUT POWER IS APPROPRIATE TO AVOID DAMAGE
# 2025-09-07 18:47:27.845 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:activation:206
# Amonics EDFA 23 dBm: ......waiting Activation status set to ON, now OFF
# 2025-09-07 18:47:27.894 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:activation:209
# Amonics EDFA 23 dBm: setted Activation status as ON, finished in 0.081 seconds

# %%
amonic23.disconnect()
# Out:
# 2025-09-07 17:52:24.671 | INFO     | Amonics EDFA 23 dBm | Device.py:disconnect:157
# Amonics EDFA 23 dBm disconnected
# 1

# %%
#time.sleep(3)
amonic23.printStatus()
# Out:
# 2025-10-10 14:19:39.434 | WARNING  | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:292
# Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
# 2025-10-10 14:19:41.642 | ERROR    | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:313
# Amonics EDFA 23 dBm I/O failed after reconnect: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
# 2025-10-10 14:19:43.641 | WARNING  | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:292
# Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
# 2025-10-10 14:19:45.855 | ERROR    | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:313
# Amonics EDFA 23 dBm I/O failed after reconnect: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
# 2025-10-10 14:19:47.924 | WARNING  | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:292
# Amonics EDFA 23 dBm I/O failed: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.; reconnecting once...
# 2025-10-10 14:19:50.138 | ERROR    | Amonics EDFA 23 dBm | Device.py:_visa_io_with_reconnect:313
# Amonics EDFA 23 dBm I/O failed after reconnect: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
# 2025-10-10 14:19:50.260 | INFO     | Amonics EDFA 23 dBm | AmonicsEDFA.py:printStatus:63
# -------------------------------Amonics EDFA 23 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-23-R-FA, Serial No.22020702-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 31.44°C
# |	Master Activation: ON
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: ACC
# |		 Set Cur: 80.0 mA
# |		 Status: ON
# |		 Input Power: 3.50911 mW
# |		 Output Power: 6.39128 mW
# |		 Internal PD Power: 45.17109 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 23 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-23-R-FA, Serial No.22020702-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 31.44°C\n|\tMaster Activation: \x1bON\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: ACC\n|\t\t Set Cur: 80.0 mA\n|\t\t Status: \x1bON\x1b\n|\t\t Input Power: 3.50911 mW\n|\t\t Output Power: 6.39128 mW\n|\t\t Internal PD Power: 45.17109 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
from KeckLFC.Hardware.Arduino_relay import Arduino_relay
arduino = Arduino_relay(addr="COM3")
# print(f'com={i}')
arduino.connect()
arduino.printStatus()
# Out:
# 2025-10-28 08:15:56.607 | INFO     | Arduino Relay Circuit | Arduino_relay.py:connect:52
# Arduino Relay Circuit connected
# 2025-10-28 08:15:57.010 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query get, trial num 1, trying again
# 2025-10-28 08:15:57.214 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query get, trial num 2, trying again
# 2025-10-28 08:15:57.418 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query get, trial num 3, trying again
# 2025-10-28 08:15:57.821 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay is  STOPPING  amplifier, but will be  OK_to_Amplify  after reset_relay_latch.
# |	 Relay Info: get
# |		Now voltage is 560
# |		Now voltage to judge (low) is 0
# |		Now voltage to judge (high) is 1024
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay is \x1b STOPPING \x1b amplifier, but will be \x1b OK_to_Amplify \x1b after reset_relay_latch.\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 560\r\n|\t\tNow voltage to judge (low) is 0\r\n|\t\tNow voltage to judge (high) is 1024\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
arduino.printStatus()
# Out:
# 2025-06-16 13:51:37.622 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay sending  OK_to_Amplify  signal to amplifier
# |	 Relay Info: get
# |		Now voltage is 514
# |		Now voltage to judge (low) is 496
# |		Now voltage to judge (high) is 515
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay sending \x1b OK_to_Amplify \x1b signal to amplifier\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 514\r\n|\t\tNow voltage to judge (low) is 496\r\n|\t\tNow voltage to judge (high) is 515\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
arduino.reset_relay_latch()
# Out:
# 'reset\r\r\nNow voltage is reset equal to input，and the voltage is:560'

# %%
message=arduino.get_YJ_info()
            
if message in ['YJState\r\r\nYJ shutter is UP, YJ is shutted.']:
                message = 0
if message in ['YJState\r\r\nYJ shutter is DOWN, YJ is passing.']:
                message = 1

print(message)
# Out:
# 1

# %%
arduino.shut_YJ()
# Out:
# 'YJShut\r\r\nYJ shutter is UP, YJ is shutted.'

# %%
arduino.disconnect()
# Out:
# 2025-04-11 12:23:10.784 | INFO     | Arduino Relay Circuit | Arduino_relay.py:disconnect:65
# Arduino Relay Circuit disconnected
# 1

# %%
arduino.pass_YJ()

# %%
arduino.disconnect()
# Out:
# 2025-05-13 17:30:46.004 | INFO     | Arduino Relay Circuit | Arduino_relay.py:disconnect:65
# Arduino Relay Circuit disconnected
# 1

# %%
arduino.printStatus()
# Out:
# 2025-04-07 13:09:29.949 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay sending  OK_to_Amplify  signal to amplifier
# |	 Relay Info: get
# |		Now voltage is 587
# |		Now voltage to judge (low) is 566
# |		Now voltage to judge (high) is 588
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay sending \x1b OK_to_Amplify \x1b signal to amplifier\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 587\r\n|\t\tNow voltage to judge (low) is 566\r\n|\t\tNow voltage to judge (high) is 588\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
arduino.get_YJ_info()
# Out:
# 'YJState\r\r\nYJ shutter is UP, YJ is shutted.'

# %%
arduino.query("YJState")
# Out:
# 'YJState\r\r\nYJ shutter is UP, YJ is shutted.'

# %%
arduino.shut_YJ()
# Out:
# 'YJShut\r\r\nYJ shutter is UP, YJ is shutted.'

# %%
arduino.query('GET')
# Out:
# 'GET\r\r\nNow voltage is 4\r\nNow voltage to judge (low) is 0\r\nNow voltage to judge (high) is 1024\r\nLow Threshold is 317\r\nHigh Threshold is 690'

# %%
message=arduino.get_YJ_info()

if message in ['YJState\r\r\nYJ shutter is UP, YJ is shutted.']:
    message = 0
if message in ['YJState\r\r\nYJ shutter is DOWN, YJ is passing.']:
    message = 1
# fill in read functions
message
# Out:
# 0

# %%
from KeckLFC.Hardware.PendulumCNT90 import PendulumCNT90
pendulem = PendulumCNT90()
pendulem.connect()
# Out:
# 2024-07-21 13:31:18.734 | INFO     | Pendulum microwave counter | Device.py:connect:78
# Pendulum microwave counter connected
# 1

# %%
freq=pendulem.measFreq('c')
freq-16e9
# Out:
# -140.56999969482422

# %%
arduino.get_relay_status()
# Out:
# 'relay is STOPPING amplifier, because input power is too low'

# %%
arduino.reset_relay_latch()
arduino.printStatus()
# Out:
# 2025-06-17 11:26:33.630 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay sending  OK_to_Amplify  signal to amplifier
# |	 Relay Info: get
# |		Now voltage is 587
# |		Now voltage to judge (low) is 566
# |		Now voltage to judge (high) is 588
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay sending \x1b OK_to_Amplify \x1b signal to amplifier\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 587\r\n|\t\tNow voltage to judge (low) is 566\r\n|\t\tNow voltage to judge (high) is 588\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
arduino.pass_YJ()
# Out:
# 'YJPass\r\r\nYJ shutter is DOWN, YJ is passing.'

# %%
arduino.printStatus()
# Out:
# 2025-10-12 08:13:38.877 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay sending  OK_to_Amplify  signal to amplifier
# |	 Relay Info: get
# |		Now voltage is 554
# |		Now voltage to judge (low) is 535
# |		Now voltage to judge (high) is 557
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay sending \x1b OK_to_Amplify \x1b signal to amplifier\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 554\r\n|\t\tNow voltage to judge (low) is 535\r\n|\t\tNow voltage to judge (high) is 557\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
from KeckLFC.Hardware.Waveshaper import Waveshaper

wsp = Waveshaper()
wsp.connect()
# Out:
# 2025-10-28 08:27:27.770 | INFO     | Finisar Waveshaper SN201904 | Device.py:connect:228
# Finisar Waveshaper SN201904 connected
# 1

# %%
wsp.disconnect()
# Out:
# 2025-10-28 09:11:35.069 | INFO     | Finisar Waveshaper SN201904 | Device.py:disconnect:243
# Finisar Waveshaper SN201904 disconnected
# 1

# %%
wsp.set3rdDisper(d2=2.14,d3=0.,center=1559.8) #2.09 -3
wsp.setBandPass(span=5)
wsp.plotStatus()
wsp.writeProfile()
# Out:
# 2025-10-28 08:54:01.855 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=2.14 ps/nm, d3=0.0 ps/nm^2, center 192.19929349916654 THz.
# 2025-10-28 08:54:01.857 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [189.675~194.675] THz ([1580.559~1539.964] nm).
# 2025-10-28 08:54:03.083 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.

# %%
osa.get_trace('a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 osa.get_trace('a')
#
# NameError: name 'osa' is not defined

# %%
from KeckLFC.Hardware.SRS_SIM900 import SRS_SIM900, SRS_PIDcontrol_SIM960
srs = SRS_SIM900(addr='GPIB0::2::INSTR')
srs.connect()
servo_FC = SRS_PIDcontrol_SIM960(srs, 1, name='Filter Cavity PDH Lock Servo')
servo_IM = SRS_PIDcontrol_SIM960(srs, 3, name='Minicomb Intensity Lock Servo')
servo_RB = SRS_PIDcontrol_SIM960(srs, 5, name='Rio Laser Fceo Rb spectroscopy Lock Servo')
# Out:
# 2025-10-28 08:16:24.001 | INFO     | Stanford Research System SIM900 | Device.py:connect:228
# Stanford Research System SIM900 connected

# %%
servo_IM.printStatus()
# Out:
# 2025-10-28 08:16:32.743 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:printStatus:201
# --------------------------Minicomb Intensity Lock Servo--------------------------
# |--------------------SRS PID controller SIM960 Status Summary--------------------
# |----------------------------SIM960,s/n033669,ver2.17----------------------------
# |	Output mode:	PID,	Output limit: -5.000V TO 5.000V
# |	Measured input:	 3.332602V
# |	Amplified error:	 -0.013952V
# |	Instant Output voltage:	 1.239509V
# |	Manual output set:	 -2.5V
# |	================ Set Point related================
# |		Internal setpoint = 3.34 V, Ramping OFF
# |		Setpoint input mode INT, Ext setpoint input 3.338029V
# |		Setpoint RAMP speed = 0.01 V/s, action OFF
# |	============= P,I,D and Offset Status=============
# |		 P = -2.0    , 	action = ON
# |		 I = 0.1 1/s, 	action = ON
# |		 D = 1e-05   s, 	action = OFF
# |		Off = 0.2  V, 	action = ON
# -----------------SRS PID controller SIM960 Status Summary Ends------------------
# '--------------------------Minicomb Intensity Lock Servo--------------------------\n|--------------------SRS PID controller SIM960 Status Summary--------------------\n|----------------------------SIM960,s/n033669,ver2.17----------------------------\n|\tOutput mode:\t\x1bPID\x1b,\tOutput limit: -5.000V TO 5.000V\n|\tMeasured input:\t 3.332602V\n|\tAmplified error:\t -0.013952V\n|\tInstant Output voltage:\t 1.239509V\n|\tManual output set:\t -2.5V\n|\t================ Set Point related================\n|\t\tInternal setpoint = 3.34 V, Ramping \x1bOFF\x1b\n|\t\tSetpoint input mode INT, Ext setpoint input 3.338029V\n|\t\tSetpoint RAMP speed = 0.01 V/s, action \x1bOFF\x1b\n|\t============= P,I,D and Offset Status=============\n|\t\t P = -2.0    , \taction = \x1bON\x1b\n|\t\t I = 0.1 1/s, \taction = \x1bON\x1b\n|\t\t D = 1e-05   s, \taction = \x1bOFF\x1b\n|\t\tOff = 0.2  V, \taction = \x1bON\x1b\n-----------------SRS PID controller SIM960 Status Summary Ends------------------\n'

# %%
srs.disconnect()
# Out:
# 2024-02-22 14:28:40.478 | INFO     | Stanford Research System SIM900 | Device.py:disconnect:90
# Stanford Research System SIM900 disconnected
# 1

# %%
from KeckLFC.Hardware.PritelAmp import PritelAmp

for i in range(3,23):
    try:
        ptamp = PritelAmp(addr=f"ASRL{i}::INSTR")
        ptamp.connect()
        ptamp.printStatus()

        print(f'com={i} success')
        
    except:
        # ptamp.disconnect()
        print(f'com={i} failed')

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
from KeckLFC.Hardware.PritelAmp import PritelAmp
ptamp = PritelAmp(addr=f'ASRL{7}::INSTR', name='Pritel Amp')
ptamp.connect()
ptamp.printStatus()
# Out:
# 2025-10-28 08:27:45.025 | INFO     | Pritel Amp | PritelAmp.py:connect:331
# Pritel Amp connected
# 2025-10-28 08:27:46.599 | INFO     | Pritel Amp | PritelAmp.py:printStatus:309
# ------------------------------------Pritel Amp-----------------------------------
# |-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------
# |	 Pump status: OFF
# |	 InputPower = 1 mW, 	PreAmp = 0 mA
# |	 OutputPower = 0.00 W, 	PwrAmp = 0.00 A
# |	 AutoShutDown Enabled. PowerAmp pump current is disabled.
# ----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------
# '------------------------------------Pritel Amp-----------------------------------\n|-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------\n|\t Pump status: \x1bOFF\x1b\n|\t InputPower = 1 mW, \tPreAmp = 0 mA\n|\t OutputPower = 0.00 W, \tPwrAmp = 0.00 A\n|\t AutoShutDown Enabled. PowerAmp pump current is disabled.\n----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------\n'

# %%
ptamp.disconnect()
# Out:
# 2025-10-12 08:14:32.658 | INFO     | Pritel Amp | Device.py:disconnect:243
# Pritel Amp disconnected
# 1

# %%
arduino.disconnect()
# Out:
# 2025-10-28 09:11:21.276 | INFO     | Arduino Relay Circuit | Arduino_relay.py:disconnect:65
# Arduino Relay Circuit disconnected
# 1

# %%
from KeckLFC.Hardware.Arduino_relay import Arduino_relay
arduino = Arduino_relay(addr="COM3")
# print(f'com={i}')
arduino.connect()

arduino.reset_relay_latch()
arduino.printStatus()
# Out:
# 2025-10-28 09:08:10.227 | INFO     | Arduino Relay Circuit | Arduino_relay.py:connect:52
# Arduino Relay Circuit connected
# 2025-10-28 09:08:10.630 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 1, trying again
# 2025-10-28 09:08:10.834 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 2, trying again
# 2025-10-28 09:08:11.039 | INFO     | Arduino Relay Circuit | Arduino_relay.py:query:90
# Arduino Relay Circuit: Failed to query reset, trial num 3, trying again
# 2025-10-28 09:08:11.642 | INFO     | Arduino Relay Circuit | Arduino_relay.py:printStatus:43
# ----------------------Arduino Relay Module Status Summary-----------------------
# |	 Relay Status: relay sending  OK_to_Amplify  signal to amplifier
# |	 Relay Info: get
# |		Now voltage is 546
# |		Now voltage to judge (low) is 528
# |		Now voltage to judge (high) is 547
# |		Low Threshold is 317
# |		High Threshold is 690
# |	 YJ Shutter State: YJState
# |		YJ shutter is DOWN, YJ is  passing .
# --------------------Arduino Relay Module Status Summary Ends--------------------
# '----------------------Arduino Relay Module Status Summary-----------------------\n|\t Relay Status: relay sending \x1b OK_to_Amplify \x1b signal to amplifier\n|\t Relay Info: get\r\r\n|\t\tNow voltage is 546\r\n|\t\tNow voltage to judge (low) is 528\r\n|\t\tNow voltage to judge (high) is 547\r\n|\t\tLow Threshold is 317\r\n|\t\tHigh Threshold is 690\n|\t YJ Shutter State: YJState\r\r\n|\t\tYJ shutter is DOWN, YJ is \x1b passing \x1b.\n--------------------Arduino Relay Module Status Summary Ends--------------------'

# %%
ptamp.activation
# Out:
# 'OFF'

# %%
ptamp.query("FA ON")
# Out:
# 'Pump Enabled'

# %%
ptamp.printStatus()
# Out:
# 2025-10-28 08:29:41.448 | INFO     | Pritel Amp | PritelAmp.py:printStatus:309
# ------------------------------------Pritel Amp-----------------------------------
# |-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------
# |	 Pump status: OFF
# |	 InputPower = 1 mW, 	PreAmp = 0 mA
# |	 OutputPower = 0.00 W, 	PwrAmp = 0.00 A
# |	 AutoShutDown Enabled. PowerAmp pump current is disabled.
# ----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------
# '------------------------------------Pritel Amp-----------------------------------\n|-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------\n|\t Pump status: \x1bOFF\x1b\n|\t InputPower = 1 mW, \tPreAmp = 0 mA\n|\t OutputPower = 0.00 W, \tPwrAmp = 0.00 A\n|\t AutoShutDown Enabled. PowerAmp pump current is disabled.\n----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------\n'

# %%
ptamp.preAmp = 600
# Out:
# 2025-10-28 08:27:56.520 | INFO     | Pritel Amp | PritelAmp.py:preAmp:386
# Pritel Amp: Disable Ramping by self.ramp_pre_ma = 0, now 100 mA.
# 2025-10-28 08:27:57.229 | INFO     | Pritel Amp | PritelAmp.py:preAmp:392
# Pritel Amp: Setting PreAmp Current to 000 mA, current Output 0.00 W.
# 2025-10-28 08:27:57.728 | INFO     | Pritel Amp | PritelAmp.py:preAmp:392
# Pritel Amp: Setting PreAmp Current to 120 mA, current Output 0.00 W.
# 2025-10-28 08:27:58.220 | INFO     | Pritel Amp | PritelAmp.py:preAmp:392
# Pritel Amp: Setting PreAmp Current to 240 mA, current Output 0.00 W.
# 2025-10-28 08:27:58.718 | INFO     | Pritel Amp | PritelAmp.py:preAmp:392
# Pritel Amp: Setting PreAmp Current to 360 mA, current Output 0.00 W.
# 2025-10-28 08:27:59.209 | INFO     | Pritel Amp | PritelAmp.py:preAmp:392
# Pritel Amp: Setting PreAmp Current to 480 mA, current Output 0.00 W.
# 2025-10-28 08:27:59.713 | INFO     | Pritel Amp | PritelAmp.py:preAmp:392
# Pritel Amp: Setting PreAmp Current to 600 mA, current Output 0.00 W.

# %%
ptamp.activation=0
# Out:
# 2025-10-28 09:11:12.381 | INFO     | Pritel Amp | PritelAmp.py:activation:474
# Pritel Amp: ......waiting Activation status set to OFF, now ON
# 2025-10-28 09:11:13.053 | INFO     | Pritel Amp | PritelAmp.py:activation:477
# Pritel Amp: setted Activation status as OFF, finished in 1.174 seconds

# %%
ptamp.easy_turnOn()# work now

# %%
ptamp.pwrAmp = '0A'
# Out:
# 2025-10-28 09:10:17.943 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:422
# Pritel Amp: Disable Ramping by self.ramp_pwr_ma = 0, now 50 mA.
# 2025-10-28 09:10:18.811 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.70 A, current Output 3.80 W.
# 2025-10-28 09:10:19.452 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.65 A, current Output 3.68 W.
# 2025-10-28 09:10:20.107 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.60 A, current Output 3.63 W.
# 2025-10-28 09:10:20.748 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.55 A, current Output 3.57 W.
# 2025-10-28 09:10:21.399 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.50 A, current Output 3.51 W.
# 2025-10-28 09:10:22.055 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.45 A, current Output 3.45 W.
# 2025-10-28 09:10:22.726 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.40 A, current Output 3.39 W.
# 2025-10-28 09:10:23.383 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.35 A, current Output 3.33 W.
# 2025-10-28 09:10:24.039 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.29 A, current Output 3.28 W.
# 2025-10-28 09:10:24.695 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.24 A, current Output 3.22 W.
# 2025-10-28 09:10:25.351 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.19 A, current Output 3.15 W.
# 2025-10-28 09:10:26.023 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.14 A, current Output 3.09 W.
# 2025-10-28 09:10:26.679 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.09 A, current Output 3.04 W.
# 2025-10-28 09:10:27.335 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 3.04 A, current Output 2.98 W.
# 2025-10-28 09:10:27.991 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.99 A, current Output 2.92 W.
# 2025-10-28 09:10:28.647 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.94 A, current Output 2.86 W.
# 2025-10-28 09:10:29.319 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.89 A, current Output 2.79 W.
# 2025-10-28 09:10:29.975 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.84 A, current Output 2.74 W.
# 2025-10-28 09:10:30.631 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.79 A, current Output 2.68 W.
# 2025-10-28 09:10:31.287 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.74 A, current Output 2.62 W.
# 2025-10-28 09:10:31.942 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.69 A, current Output 2.56 W.
# 2025-10-28 09:10:32.615 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.64 A, current Output 2.50 W.
# 2025-10-28 09:10:33.271 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.58 A, current Output 2.43 W.
# 2025-10-28 09:10:33.927 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.53 A, current Output 2.35 W.
# 2025-10-28 09:10:34.583 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.48 A, current Output 2.29 W.
# 2025-10-28 09:10:35.239 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.43 A, current Output 2.24 W.
# 2025-10-28 09:10:35.911 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.38 A, current Output 2.18 W.
# 2025-10-28 09:10:36.567 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.33 A, current Output 2.13 W.
# 2025-10-28 09:10:37.223 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.28 A, current Output 2.08 W.
# 2025-10-28 09:10:37.879 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.23 A, current Output 2.01 W.
# 2025-10-28 09:10:38.535 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.18 A, current Output 1.94 W.
# 2025-10-28 09:10:39.191 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.13 A, current Output 1.87 W.
# 2025-10-28 09:10:39.863 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.08 A, current Output 1.81 W.
# 2025-10-28 09:10:40.519 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 2.03 A, current Output 1.76 W.
# 2025-10-28 09:10:41.175 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.98 A, current Output 1.71 W.
# 2025-10-28 09:10:41.831 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.93 A, current Output 1.65 W.
# 2025-10-28 09:10:42.487 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.88 A, current Output 1.59 W.
# 2025-10-28 09:10:43.159 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.82 A, current Output 1.52 W.
# 2025-10-28 09:10:43.815 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.77 A, current Output 1.45 W.
# 2025-10-28 09:10:44.471 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.72 A, current Output 1.40 W.
# 2025-10-28 09:10:45.127 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.67 A, current Output 1.35 W.
# 2025-10-28 09:10:45.783 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.62 A, current Output 1.28 W.
# 2025-10-28 09:10:46.455 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.57 A, current Output 1.23 W.
# 2025-10-28 09:10:47.111 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.52 A, current Output 1.17 W.
# 2025-10-28 09:10:47.768 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.47 A, current Output 1.11 W.
# 2025-10-28 09:10:48.423 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.42 A, current Output 1.05 W.
# 2025-10-28 09:10:49.079 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.37 A, current Output 1.00 W.
# 2025-10-28 09:10:49.751 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.32 A, current Output 0.94 W.
# 2025-10-28 09:10:50.407 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.27 A, current Output 0.87 W.
# 2025-10-28 09:10:51.063 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.22 A, current Output 0.81 W.
# 2025-10-28 09:10:51.720 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.17 A, current Output 0.76 W.
# 2025-10-28 09:10:52.376 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.12 A, current Output 0.71 W.
# 2025-10-28 09:10:53.047 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.06 A, current Output 0.66 W.
# 2025-10-28 09:10:53.704 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 1.01 A, current Output 0.59 W.
# 2025-10-28 09:10:54.360 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.96 A, current Output 0.53 W.
# 2025-10-28 09:10:55.015 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.91 A, current Output 0.48 W.
# 2025-10-28 09:10:55.671 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.86 A, current Output 0.41 W.
# 2025-10-28 09:10:56.343 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.81 A, current Output 0.36 W.
# 2025-10-28 09:10:57.000 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.76 A, current Output 0.32 W.
# 2025-10-28 09:10:57.656 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.71 A, current Output 0.27 W.
# 2025-10-28 09:10:58.312 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.66 A, current Output 0.21 W.
# 2025-10-28 09:10:58.967 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.61 A, current Output 0.16 W.
# 2025-10-28 09:10:59.640 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.56 A, current Output 0.10 W.
# 2025-10-28 09:11:00.295 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.51 A, current Output 0.05 W.
# 2025-10-28 09:11:00.951 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.46 A, current Output 0.01 W.
# 2025-10-28 09:11:01.607 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.41 A, current Output 0.00 W.
# 2025-10-28 09:11:02.263 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.35 A, current Output 0.00 W.
# 2025-10-28 09:11:02.935 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.30 A, current Output 0.00 W.
# 2025-10-28 09:11:03.591 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.25 A, current Output 0.00 W.
# 2025-10-28 09:11:04.247 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.20 A, current Output 0.00 W.
# 2025-10-28 09:11:04.904 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.15 A, current Output 0.00 W.
# 2025-10-28 09:11:05.560 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.10 A, current Output 0.00 W.
# 2025-10-28 09:11:06.232 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.05 A, current Output 0.00 W.
# 2025-10-28 09:11:06.887 | INFO     | Pritel Amp | PritelAmp.py:pwrAmp:428
# Pritel Amp: Setting PowerAmp Current to 0.00 A, current Output 0.00 W.

# %%
ptamp.printStatus()
# Out:
# 2025-06-16 13:50:25.210 | INFO     | Pritel Amp | PritelAmp.py:printStatus:38
# ------------------------------------Pritel Amp-----------------------------------
# |-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------
# |	 Pump status: OFF
# |	 InputPower = 0 mW, 	PreAmp = 0 mA
# |	 OutputPower = 0.00 W, 	PwrAmp = 0.00 A
# |	 AutoShutDown Enabled. PowerAmp pump current is disabled.
# ----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------
# '------------------------------------Pritel Amp-----------------------------------\n|-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------\n|\t Pump status: \x1bOFF\x1b\n|\t InputPower = 0 mW, \tPreAmp = 0 mA\n|\t OutputPower = 0.00 W, \tPwrAmp = 0.00 A\n|\t AutoShutDown Enabled. PowerAmp pump current is disabled.\n----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------\n'

# %%
ptamp.printStatus()
# Out:
# 2024-07-20 10:34:23.606 | INFO     | Pritel Amp | PritelAmp.py:printStatus:38
# ------------------------------------Pritel Amp-----------------------------------
# |-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------
# |	 Pump status: ON
# |	 InputPower = 140 mW, 	PreAmp = 603 mA
# |	 OutputPower = 0.00 W, 	PwrAmp = 0.00 A
# |	 AutoShutDown Disabled.
# ----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------
# '------------------------------------Pritel Amp-----------------------------------\n|-----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary------------------\n|\t Pump status: \x1bON\x1b\n|\t InputPower = 140 mW, \tPreAmp = 603 mA\n|\t OutputPower = 0.00 W, \tPwrAmp = 0.00 A\n|\t AutoShutDown Disabled.\n----------------Pritel OPTICAL FIBER AMPLIFIER Status Summary Ends---------------\n'

# %%
# ptamp.preAmp = '600mA'
# ptamp.pwrAmp = '0A'

ptamp.activation = 0
# Out:
# 2024-04-17 14:19:44.189 | INFO     | Pritel Amp | PritelAmp.py:activation:203
# Pritel Amp: ......waiting Activation status set to OFF, now ON
# 2024-04-17 14:19:44.861 | INFO     | Pritel Amp | PritelAmp.py:activation:206
# Pritel Amp: setted Activation status as OFF, finished in 1.123 seconds

# %%
from KeckLFC.Hardware.AmonicsEDFA import AmonicsEDFA
amonic13 = AmonicsEDFA(addr=f'ASRL{9}::INSTR', name='Amonics EDFA 13 dBm')
amonic13.connect()
amonic13.printStatus()
# Out:
# 2024-02-22 14:20:40.162 | INFO     | Amonics EDFA 13 dBm | Device.py:connect:78
# Amonics EDFA 13 dBm connected
# 2024-02-22 14:20:46.424 | INFO     | Amonics EDFA 13 dBm | AmonicsEDFA.py:printStatus:49
# -------------------------------Amonics EDFA 13 dBm-------------------------------
# |--------------------------Amonics EDFA Status Summary---------------------------
# |------------------Model: AEDFA-PM-13-R-FA, Serial No.22020701-------------------
# |	InterLock Status: UNLOCKED
# |	Case Temperature: 27.31°C
# |	Master Activation: OFF
# |	------------Channel Summary-------------
# |	 CHANNEL1:
# |		 Mode: ACC
# |		 Set Cur: 0.0 mA
# |		 Status: OFF
# |		 Input Power: 0.0 mW
# |		 Output Power: 0.0 mW
# |		 Internal PD Power: 0.0 mW
# ------------------------Amonics EDFA Status Summary Ends------------------------
# '-------------------------------Amonics EDFA 13 dBm-------------------------------\n|--------------------------Amonics EDFA Status Summary---------------------------\n|------------------Model: AEDFA-PM-13-R-FA, Serial No.22020701-------------------\n|\tInterLock Status: \x1bUNLOCKED\x1b\n|\tCase Temperature: 27.31°C\n|\tMaster Activation: \x1bOFF\x1b\n|\t------------Channel Summary-------------\n|\t CHANNEL1: \n|\t\t Mode: ACC\n|\t\t Set Cur: 0.0 mA\n|\t\t Status: \x1bOFF\x1b\n|\t\t Input Power: 0.0 mW\n|\t\t Output Power: 0.0 mW\n|\t\t Internal PD Power: 0.0 mW\n------------------------Amonics EDFA Status Summary Ends------------------------\n'

# %%
cd ..
# Out:
# c:\Users\KeckLFC\KeckLFC-main

# %%
from KeckLFC.Hardware.Agiltron_2by2_switch import AgiltronSelfAlign22
sw2 = AgiltronSelfAlign22(addr=f'COM{20}')
sw2.connect()
sw2.check_status()
# Out:
# 2025-10-12 07:56:35.919 | INFO     | Agiltron 2 by 2 switch | Device.py:connect:228
# Agiltron 2 by 2 switch connected
# 1

# %%
sw2.set_status(2)
# Out:
# 2025-05-16 11:51:24.079 | INFO     | Agiltron 2 by 2 switch | Agiltron_2by2_switch.py:set_status:113
# status set to 2

# %%
sw2.check_status()
# Out:
# 1

# %%
sw2.disconnect()
# Out:
# 2025-10-12 07:56:47.118 | INFO     | Agiltron 2 by 2 switch | Device.py:disconnect:243
# Agiltron 2 by 2 switch disconnected
# 1

# %%
################ locking all 2024-04-08

# %%
from KeckLFC.Hardware.SRS_SIM900 import SRS_SIM900, SRS_PIDcontrol_SIM960
srs = SRS_SIM900(addr='GPIB0::2::INSTR')
srs.connect()
servo_FC = SRS_PIDcontrol_SIM960(srs, 1, name='Filter Cavity PDH Lock Servo')
servo_IM = SRS_PIDcontrol_SIM960(srs, 3, name='Minicomb Intensity Lock Servo')
servo_RB = SRS_PIDcontrol_SIM960(srs, 5, name='Rio Laser Fceo Rb spectroscopy Lock Servo')

from KeckLFC.Hardware.TDS2024C import TDS2024C
osc = TDS2024C()
osc.connect()

from KeckLFC.Hardware.KeysightFG_33500 import KeysightFG_33500
fg = KeysightFG_33500(addr='USB0::0x0957::0x2807::MY59003824::INSTR', name='Keysight FG 33500')
fg.connect()
# Out:
# 2024-11-14 12:29:58.389 | INFO     | Stanford Research System SIM900 | Device.py:connect:78
# Stanford Research System SIM900 connected
# 2024-11-14 12:29:58.422 | INFO     | TDS2024C OSC | Device.py:connect:78
# TDS2024C OSC connected
# 2024-11-14 12:29:58.427 | INFO     | Keysight FG 33500 | Device.py:connect:78
# Keysight FG 33500 connected
# 1

# %%
from KeckLFC.Hardware.KeysightFG_33500 import KeysightFG_33500
fg = KeysightFG_33500(addr='USB0::0x0957::0x2807::MY59003824::INSTR', name='Keysight FG 33500')
fg.connect()

fg_pdh = KeysightFG_33500(addr='USB0::0x0957::0x2807::MY62003852::INSTR', name='Keysight FG 33500 for pdh')
fg_pdh.connect()
# Out:
# 2025-05-13 12:27:01.005 | INFO     | Keysight FG 33500 | Device.py:connect:78
# Keysight FG 33500 connected
# 2025-05-13 12:27:01.021 | INFO     | Keysight FG 33500 for pdh | Device.py:connect:78
# Keysight FG 33500 for pdh connected
# 1

# %%
fg_pdh.get_channel_parameters(1)
# Out:
# {'channel': '1',
#  'frequency': '10000000.0',
#  'Amplitude': '0.1',
#  'offset': '0.0',
#  'phase': '0.0',
#  'state': '0\n',
#  'function': 'SIN\n'}

# %%
from KeckLFC.Hardware.SRS_SIM900 import SRS_SIM900, SRS_PIDcontrol_SIM960
srs = SRS_SIM900(addr='GPIB0::2::INSTR')
srs.connect()
servo_FC = SRS_PIDcontrol_SIM960(srs, 1, name='Filter Cavity PDH Lock Servo')
servo_IM = SRS_PIDcontrol_SIM960(srs, 3, name='Minicomb Intensity Lock Servo')
servo_RB = SRS_PIDcontrol_SIM960(srs, 5, name='Rio Laser Fceo Rb spectroscopy Lock Servo')
# Out:
# 2025-10-16 10:19:21.944 | INFO     | Stanford Research System SIM900 | Device.py:connect:228
# Stanford Research System SIM900 connected

# %%
servo_IM.output_upperlim = 5
servo_IM.output_lowerlim = -5
servo_IM.printStatus()
# Out:
# 2025-10-18 17:52:13.589 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Output Upper limit in Volt to 5.0.
# 2025-10-18 17:52:13.801 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Output Lower limit in Volt to -5.0.
# 2025-10-18 17:52:18.874 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:printStatus:201
# --------------------------Minicomb Intensity Lock Servo--------------------------
# |--------------------SRS PID controller SIM960 Status Summary--------------------
# |----------------------------SIM960,s/n033669,ver2.17----------------------------
# |	Output mode:	MAN,	Output limit: -5.000V TO 5.000V
# |	Measured input:	 5.592877V
# |	Amplified error:	 3.108175V
# |	Instant Output voltage:	 2.805974V
# |	Manual output set:	 2.81V
# |	================ Set Point related================
# |		Internal setpoint = 3.12 V, Ramping OFF
# |		Setpoint input mode INT, Ext setpoint input 3.118137V
# |		Setpoint RAMP speed = 0.01 V/s, action OFF
# |	============= P,I,D and Offset Status=============
# |		 P = -2.0    , 	action = ON
# |		 I = 0.1 1/s, 	action = ON
# |		 D = 1e-05   s, 	action = OFF
# |		Off = 0.2  V, 	action = ON
# -----------------SRS PID controller SIM960 Status Summary Ends------------------
# '--------------------------Minicomb Intensity Lock Servo--------------------------\n|--------------------SRS PID controller SIM960 Status Summary--------------------\n|----------------------------SIM960,s/n033669,ver2.17----------------------------\n|\tOutput mode:\t\x1bMAN\x1b,\tOutput limit: -5.000V TO 5.000V\n|\tMeasured input:\t 5.592877V\n|\tAmplified error:\t 3.108175V\n|\tInstant Output voltage:\t 2.805974V\n|\tManual output set:\t 2.81V\n|\t================ Set Point related================\n|\t\tInternal setpoint = 3.12 V, Ramping \x1bOFF\x1b\n|\t\tSetpoint input mode INT, Ext setpoint input 3.118137V\n|\t\tSetpoint RAMP speed = 0.01 V/s, action \x1bOFF\x1b\n|\t============= P,I,D and Offset Status=============\n|\t\t P = -2.0    , \taction = \x1bON\x1b\n|\t\t I = 0.1 1/s, \taction = \x1bON\x1b\n|\t\t D = 1e-05   s, \taction = \x1bOFF\x1b\n|\t\tOff = 0.2  V, \taction = \x1bON\x1b\n-----------------SRS PID controller SIM960 Status Summary Ends------------------\n'

# %%
servo_IM.measure_input
# Out:
# 3.842416

# %%
servo_IM.output_mode = 'pid'  #'man'  or 'pid'
# Out:
# 2025-10-28 09:07:52.149 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_output_mode:534
# Minicomb Intensity Lock Servo: PID output is turned ON.

# %%
servo_IM.manual_output=1.2
time.sleep(1)
print(servo_IM.get_output_voltage() ) 
print(servo_IM.get_measure_input())
# Out:
# 2025-10-28 08:47:56.294 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:666
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramping.... Disable ranp by set self.manual_output_ramp=0.
# 2025-10-28 08:47:56.502 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.700.
# 2025-10-28 08:47:56.712 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.825.
# 2025-10-28 08:47:56.937 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.950.
# 2025-10-28 08:47:57.146 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.075.
# 2025-10-28 08:47:57.356 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.200.
# 2025-10-28 08:47:57.357 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:681
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramp Finished. Disable ramp by set self.manual_output_ramp=0.
# 1.195735
# 3.762858

# %%
servo_IM.prop_gain=-2  #-2 or 4
servo_IM.intg_gain=0.1   #1
servo_IM.outoffset=0.2
servo_IM.set_setpoint(2.78)
# Out:
# 2025-10-28 09:07:44.951 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Proportional Gain in V/V to -2.0.
# 2025-10-28 09:07:45.163 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Integral Gain in 1/seconds to 0.1.
# 2025-10-28 09:07:45.372 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Output offset in Volts to 0.2.
# 2025-10-28 09:07:45.582 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Locking set point in Volt to 2.78.

# %%
print(servo_IM.get_output_voltage() ) 
print(servo_IM.get_measure_input())
# Out:
# 1.395747
# 2.78454

# %%
import numpy as np
scan_start = -3
scan_stop =3
num_steps= 100

servo_IM.manual_output_ramp=0.1
servo_IM.manual_output = scan_start

r = servo_IM.manual_sweep(np.linspace(scan_start,scan_stop,num_steps))

servo_IM.manual_output=1.4
# Out:
# 2025-10-28 09:06:29.988 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:666
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramping.... Disable ranp by set self.manual_output_ramp=0.
# 2025-10-28 09:06:30.197 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.400.
# 2025-10-28 09:06:30.406 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.298.
# 2025-10-28 09:06:30.614 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.195.
# 2025-10-28 09:06:30.823 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.093.
# 2025-10-28 09:06:31.030 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.991.
# 2025-10-28 09:06:31.239 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.888.
# 2025-10-28 09:06:31.446 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.786.
# 2025-10-28 09:06:31.655 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.684.
# 2025-10-28 09:06:31.862 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.581.
# 2025-10-28 09:06:32.070 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.479.
# 2025-10-28 09:06:32.278 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.377.
# 2025-10-28 09:06:32.485 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.274.
# 2025-10-28 09:06:32.694 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.172.
# 2025-10-28 09:06:32.901 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 0.070.
# 2025-10-28 09:06:33.110 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.033.
# 2025-10-28 09:06:33.318 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.135.
# 2025-10-28 09:06:33.529 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.237.
# 2025-10-28 09:06:33.737 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.340.
# 2025-10-28 09:06:33.945 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.442.
# 2025-10-28 09:06:34.152 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.544.
# 2025-10-28 09:06:34.360 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.647.
# 2025-10-28 09:06:34.569 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.749.
# 2025-10-28 09:06:34.780 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.851.
# 2025-10-28 09:06:34.989 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -0.953.
# 2025-10-28 09:06:35.197 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.056.
# 2025-10-28 09:06:35.407 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.158.
# 2025-10-28 09:06:35.614 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.260.
# 2025-10-28 09:06:35.823 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.363.
# 2025-10-28 09:06:36.033 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.465.
# 2025-10-28 09:06:36.243 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.567.
# 2025-10-28 09:06:36.450 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.670.
# 2025-10-28 09:06:36.662 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.772.
# 2025-10-28 09:06:36.871 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.874.
# 2025-10-28 09:06:37.080 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -1.977.
# 2025-10-28 09:06:37.291 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.079.
# 2025-10-28 09:06:37.499 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.181.
# 2025-10-28 09:06:37.707 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.284.
# 2025-10-28 09:06:37.916 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.386.
# 2025-10-28 09:06:38.124 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.488.
# 2025-10-28 09:06:38.332 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.591.
# 2025-10-28 09:06:38.541 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.693.
# 2025-10-28 09:06:38.749 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.795.
# 2025-10-28 09:06:38.958 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -2.898.
# 2025-10-28 09:06:39.167 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to -3.000.
# 2025-10-28 09:06:39.167 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:681
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramp Finished. Disable ramp by set self.manual_output_ramp=0.
# 2025-10-28 09:06:39.375 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_output_mode:537
# Minicomb Intensity Lock Servo: PID output is turned OFF, output mode is turnd to Manual.
# 100%|██████████| 100/100 [00:13<00:00,  7.28it/s]
# 2025-10-28 09:06:53.447 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:666
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramping.... Disable ranp by set self.manual_output_ramp=0.
# 2025-10-28 09:06:53.657 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 3.000.
# 2025-10-28 09:06:53.864 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.893.
# 2025-10-28 09:06:54.072 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.787.
# 2025-10-28 09:06:54.280 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.680.
# 2025-10-28 09:06:54.489 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.573.
# 2025-10-28 09:06:54.698 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.467.
# 2025-10-28 09:06:54.908 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.360.
# 2025-10-28 09:06:55.115 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.253.
# 2025-10-28 09:06:55.324 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.147.
# 2025-10-28 09:06:55.531 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 2.040.
# 2025-10-28 09:06:55.740 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.933.
# 2025-10-28 09:06:55.948 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.827.
# 2025-10-28 09:06:56.155 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.720.
# 2025-10-28 09:06:56.362 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.613.
# 2025-10-28 09:06:56.570 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.507.
# 2025-10-28 09:06:56.778 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.400.
# 2025-10-28 09:06:56.779 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:681
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramp Finished. Disable ramp by set self.manual_output_ramp=0.

# %%
import time
import numpy as np
import matplotlib.pyplot as plt

def sweep_voltage(ps, servo,
                  v_start=0.0, v_stop=1.0, num=20,
                  settle_s=0.5,                 # 设点后等待
                  delay_between_points=0.0):    # 每点额外停顿（可为0）
    """
    扫描 ps.Vset3 从 v_start→v_stop（含端点），每点读取一次 servo.get_measure_input()。
    返回形状 (N, 3) 的数组：[设定电压, 测量值, 相对时间s]
    """
    setpoints = np.linspace(v_start, v_stop, num, dtype=float)
    data = np.empty((setpoints.size, 3), dtype=float)
    t0 = time.monotonic()

    # 记录原始设定电压，方便恢复
    try:
        original_v = float(getattr(ps, "Vset3"))
    except Exception:
        original_v = None

    try:
        for i, v in enumerate(setpoints):
            ps.Vset3 = float(v)          # 设定电压
            time.sleep(settle_s)          # 等待稳定

            y = float(servo.get_measure_input())   # 只读一次
            t_rel = time.monotonic() - t0
            data[i] = (v, y, t_rel)

            if delay_between_points > 0:
                time.sleep(delay_between_points)

    except KeyboardInterrupt:
        print("Sweep interrupted by user.")
        data = data[:i]  # 保留已采到的数据
    finally:
        if original_v is not None:
            try:
                ps.Vset3 = original_v
            except Exception:
                pass

    return data

# -------- 使用示例 --------
v_start = 0.0
v_stop  = 2.0
num     = 25
settle  = 0.5

plt_data = sweep_voltage(ps=rfoscPS, servo=servo_IM,
                         v_start=v_start, v_stop=v_stop, num=num,
                         settle_s=settle, delay_between_points=0.0)

plt.figure()
plt.plot(plt_data[:, 0], plt_data[:, 1], marker="o")
plt.xlabel("Vset3 (V)")
plt.ylabel("Measured input (arb.)")
plt.title(f"Sweep Vset3: {v_start} → {v_stop} V, N={num}")
plt.grid(True)
plt.show()
# Out:
# 2025-10-17 16:57:39.020 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.000V
# 2025-10-17 16:57:40.860 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.083V
# 2025-10-17 16:57:42.604 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.167V
# 2025-10-17 16:57:44.361 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.250V
# 2025-10-17 16:57:46.118 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.333V
# 2025-10-17 16:57:47.875 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.417V
# 2025-10-17 16:57:49.627 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.500V
# 2025-10-17 16:57:51.469 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.583V
# 2025-10-17 16:57:53.301 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.667V
# 2025-10-17 16:57:55.134 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.750V
# 2025-10-17 16:57:56.980 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.833V
# 2025-10-17 16:57:58.817 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.917V
# 2025-10-17 16:58:00.653 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.000V
# 2025-10-17 16:58:02.490 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.083V
# 2025-10-17 16:58:04.327 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.167V
# 2025-10-17 16:58:06.161 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.250V
# 2025-10-17 16:58:08.001 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.333V
# 2025-10-17 16:58:09.836 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.417V
# 2025-10-17 16:58:11.672 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.500V
# 2025-10-17 16:58:13.511 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.583V
# 2025-10-17 16:58:15.344 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.667V
# 2025-10-17 16:58:17.184 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.750V
# 2025-10-17 16:58:19.018 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.833V
# 2025-10-17 16:58:20.860 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 1.917V
# 2025-10-17 16:58:22.694 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 2.000V
# 2025-10-17 16:58:24.436 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.800V

# %%
rfoscPS.Vset3=0.25
# Out:
# 2025-10-17 17:00:06.109 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.250V

# %%
servo_IM = SRS_PIDcontrol_SIM960(srs, 3, name='Minicomb Intensity Lock Servo')

# %%
import time
servo_IM.manual_output = 1.4
rfoscPS.Vset3=0.85
time.sleep(1)
osa.Run()
time.sleep(1)
osa.get_trace('a')
# Out:
# 2025-10-28 09:06:05.604 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:666
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramping.... Disable ranp by set self.manual_output_ramp=0.
# 2025-10-28 09:06:05.812 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.300.
# 2025-10-28 09:06:06.019 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:671
# Minicomb Intensity Lock Servo: Output in Manual Mode in Volt set to 1.400.
# 2025-10-28 09:06:06.021 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_manual_output:681
# Minicomb Intensity Lock Servo: ....Manual output voltage Ramp Finished. Disable ramp by set self.manual_output_ramp=0.
# 2025-10-28 09:06:06.527 | INFO     | RF oscilator PS, CH2 15V, CH3 1V | InstekGPD_4303S.py:_setVSET:320
# Instek GPD-4303S DCSupply: VSET channel 3 set to 0.850V
# 2025-10-28 09:06:07.531 | INFO     | Agilent 86142B | Agilent_86142B.py:Run:164
# Agilent 86142B: Spectrum collection RUN (repeat) start.
# 2025-10-28 09:06:09.242 | INFO     | Agilent 86142B | Agilent_86142B.py:get_trace:327
# Agilent 86142B: Trace A data is collected and is shown in the plot.
# (array([1553.   , 1553.014, 1553.028, ..., 1566.972, 1566.986, 1567.   ],
#        dtype=float32),
#  array([-79.120125, -79.120125, -79.120125, ..., -78.95348 , -74.00617 ,
#         -74.716545], dtype=float32))

# %%
servo_IM.output_upperlim = 3
servo_IM.output_lowerlim = -3

servo_IM.prop_gain=-2  #-2 or 4
servo_IM.intg_gain=0.1   #1
servo_IM.outoffset=0.2
servo_IM.set_setpoint(3.12)
# Out:
# 2025-10-12 08:06:36.809 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Output Upper limit in Volt to 3.0.
# 2025-10-12 08:06:37.014 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Output Lower limit in Volt to -3.0.
# 2025-10-12 08:06:37.229 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Proportional Gain in V/V to -2.0.
# 2025-10-12 08:06:37.437 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Integral Gain in 1/seconds to 0.1.
# 2025-10-12 08:06:37.639 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Output offset in Volts to 0.2.
# 2025-10-12 08:06:37.854 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:__set_num_withcmd:812
# Minicomb Intensity Lock Servo: Setting Locking set point in Volt to 3.12.

# %%
servo_IM.output_mode = 'pid'  #'man'  or 'pid'
# Out:
# 2025-10-12 08:06:43.714 | INFO     | Minicomb Intensity Lock Servo | SRS_SIM900.py:set_output_mode:534
# Minicomb Intensity Lock Servo: PID output is turned ON.

# %%
servo_IM.printStatus()

# %%
# servo_IM.output_mode = 'man'  #'man'  or 'pid'
# servo_IM.output_mode = 'pid'  #'man'  or 'pid'
import time
for i in range(20):

    print(servo_IM.get_output_voltage() ) 
    print(servo_IM.get_measure_input())
    time.sleep(0.5)
# Out:
# 1.165847
# 3.754951
# 1.165181
# 3.758786
# 1.16392
# 3.762263
# 1.16261
# 3.763822
# 1.162106
# 3.766697
# 1.160845
# 3.768004
# 1.160322
# 3.770423
# 1.159308
# 3.771555
# 1.158814
# 3.773601
# 1.157869
# 3.774558
# 1.157432
# 3.776272
# 1.156591
# 3.777098
# 1.156229
# 3.778564
# 1.155539
# 3.779943
# 1.155219
# 3.780581
# 1.154753
# 3.781751
# 1.154077
# 3.78228
# 1.153749
# 3.783246
# 1.153245
# 3.783703
# 1.153008
# 3.784582

# %%
from KeckLFC.Hardware.hk_shutter import hk_shutter
hks = hk_shutter(addr='COM17')   #5,8,11,14,17
hks.connect()
# Out:
# 2025-09-07 18:57:03.653 | INFO     | hk_shutter | hk_shutter.py:connect:31
# hk_shutter connected
# 1

# %%
hks.get_status()
# Out:
# 2025-09-07 18:57:07.748 | INFO     | hk_shutter | hk_shutter.py:get_status:93
# Shutter is 1
# 1

# %%
hks.get_mode()
# Out:
# Shutter is in Manual mode
# 1

# %%
hks.set_status(0)
# Out:
# 2025-09-07 18:57:13.276 | INFO     | hk_shutter | hk_shutter.py:get_status:93
# Shutter is 1
# 2025-09-07 18:57:15.319 | INFO     | hk_shutter | hk_shutter.py:get_status:90
# Shutter is 0
# Shutter is set to 0
# 0

# %%
hks.disconnect()
# Out:
# 2025-09-07 18:55:34.871 | INFO     | hk_shutter | hk_shutter.py:disconnect:44
# hk_shutter disconnected
# 1

# %%
arduino.shut_YJ()
# Out:
# 'YJShut\r\r\nYJ shutter is UP, YJ is shutted.'

# %%
from KeckLFC.Hardware.TDS2024C import TDS2024C
osc = TDS2024C()
osc.connect()
# Out:
# 2024-11-14 12:25:50.352 | INFO     | TDS2024C OSC | Device.py:connect:78
# TDS2024C OSC connected
# 1

# %%
osc.get_trace(trace=4)

# %%
osc.query('CH1:VOL 2')

# %%
osc.write("ACQuire:STATE RUN")

# %%
osc.query('CH1:SCA?')
# Out:
# '2.0E0'

# %%
a=1
osc.write(f'CH{a}:SCA 3')

# %%
osc.query('HOR:SCA?')
# Out:
# '1.0E-1'

# %%
osc.write('HOR:POS 1')

# %%
osc.write('TRIG:MAI:EDGE:SOU EXT')

# %%
osc.query('TRIG:MAI:EDGE:SOU?')
# Out:
# 'EXT'

# %%
osc.query('TRIG:MAI:LEV?')
# Out:
# '2.0E-1'

# %%
osc.query('CH1:POS?')
# Out:
# '3.0E0'

# %%
osc.write('CH1:POS 3')

# %%
osc.query('SEL?')
# Out:
# '1;1;0;0;0;0;0;0;0'

# %%
osc.write('SEL:CH4 ON')

# %%
def set_vol_pos(self,channle,pos):

    awrite(f'CH{channle}:POS {pos}')
    print(f'CH{channle} set to '+ aquery(f'CH{channle}:POS?'))
    #return aquery(f'CH{channle}:POS?')

def set_vol_scale(self,channle,sca):

    awrite(f'CH{channle}:SCA {sca}')
    print(f'CH{channle} set to '+aquery(f'CH{channle}:SCA?'))
    #return aquery(f'CH{channle}:SCA?')

def set_time_pos(self,pos):
    awrite(f'HOR:POS {pos}')
    print(f'time pos set to '+aquery(f'HOR:POS?'))

def set_time_scale(self,sca):

    awrite(f'HOR:SCA {sca}')
    print(f'time scale set to '+aquery(f'HOR:SCA?'))

def trace_disp(self,chan,state):

    if (state == 1) or( state=='ON'):
        awrite(f'SEL:CH{chan} ON')
    if (state == 0) or(state== 'OFF'):
        awrite(f'SEL:CH{chan} OFF')
    print(f'display set to '+aquery('SEL?'))

def set_trigger_source(self,chan):

    awrite(f'TRIG:MAI:EDGE:SOU {chan}')
    print(f'trigger souce set to '+aquery(f'TRIG:MAI:EDGE:SOU?'))

def set_trigger_lev(self,lvl):
    awrite(f'TRIG:MAI:LEV {lvl}')
    print(f'trigger level set to '+aquery('TRIG:MAI:LEV?'))

# %%
set_time_pos(osc,0)
# Out:
# time pos set to 0.0E0

# %%
set_trigger_lev(osc, 2)
# Out:
# trigger level set to 2.0E0

# %%
set_trigger_source(osc,'CH4')
# Out:
# trigger souce set to CH4

# %%
set_vol_pos(osc, 1, -1.5)
# Out:
# CH1 set to -1.48E0
# '-1.48E0'

# %%
set_vol_scale(osc,2,0.01)
# Out:
# CH2 set to 1.0E-2
# '1.0E-2'

# %%
set_vol_scale(osc,1,0.03)

set_vol_scale(osc,2,0.03)

set_vol_scale(osc,3,0.03)
# Out:
# CH1 set to 3.0E-2
# CH2 set to 3.0E-2
# CH3 set to 3.0E-2
# '3.0E-2'

# %%
set_trigger_lev(osc,0.2)
# Out:
# trigger level set to 2.0E-1

# %%
set_time_scale(osc,0.05)
# Out:
# time scale set to 5.0E-2

# %%
trace_disp(self=osc,chan=3,state=1)
# chan=1
# osc.write(f'SEL:CH{chan} ON')
# Out:
# display set to 1;1;1;1;0;0;0;0;0

# %%
osc.get_trace(2)
# Out:
# 2024-11-14 12:33:38.712 | INFO     | TDS2024C OSC | TDS2024C.py:get_trace:134
# TDS2024C OSC: Trace 2 data read finished.
# {'BYT_Nr': 2,
#  'BIT_Nr': 16,
#  'ENCd': 'ASC',
#  'BN_Fmt': 'RP',
#  'BYT_Or': 'MSB',
#  'NR_Pt': 2500,
#  'WFID': '"Ch2, DC coupling, 1.0E0 V/div, 1.0E-2 s/div, 2500 points, Sample mode"',
#  'PT_FMT': 'Y',
#  'XINcr': 4e-05,
#  'PT_Off': 0.0,
#  'XZEro': -0.05,
#  'XUNit': '"s"',
#  'YMUlt': 0.00015625,
#  'YZEro': 0.0,
#  'YOFF': -11776.0,
#  'YUNit': '"Volts"',
#  'Y': array([2.52, 2.52, 2.52, ..., 2.52, 2.52, 2.56]),
#  'X': array([-0.05   , -0.04996, -0.04992, ...,  0.04988,  0.04992,  0.04996])}

# %%
from KeckLFC.Hardware import autolock
import time
import matplotlib.pyplot as plt
autolock = autolock.AutoRbLock(osc, fg, servo_RB)

# %%
fg.set_trigger_source(1)
# Out:
# trig source=CH1

# %%
servo_RB.output_voltage
# Out:
# 0.01515

# %%
fg.set_trigger_type(1, 'IMM')

# %%
fg.query("TRIG1:SOUR?")
# Out:
# 'IMM\n'

# %%
fg.get_channel_parameters(1)
# Out:
# {'channel': '1',
#  'frequency': '10.0',
#  'Amplitude': '8.0',
#  'offset': '0.0',
#  'phase': '0.0',
#  'state': '0\n',
#  'function': 'RAMP\n'}

# %%
servo_RB.printStatus()
# Out:
# 2024-04-12 13:45:21.732 | INFO     | Rio Laser Fceo Rb spectroscopy Lock Servo | SRS_SIM900.py:printStatus:201
# --------------------Rio Laser Fceo Rb spectroscopy Lock Servo--------------------
# |--------------------SRS PID controller SIM960 Status Summary--------------------
# |----------------------------SIM960,s/n033683,ver2.17----------------------------
# |	Output mode:	MAN,	Output limit: -4.000V TO 4.000V
# |	Measured input:	 0.002018V
# |	Amplified error:	 -0.007743V
# |	Instant Output voltage:	 -0.005581V
# |	Manual output set:	 0.0V
# |	================ Set Point related================
# |		Internal setpoint = -0.01 V, Ramping OFF
# |		Setpoint input mode INT, Ext setpoint input -0.009426V
# |		Setpoint RAMP speed = 0.01 V/s, action OFF
# |	============= P,I,D and Offset Status=============
# |		 P = 0.7    , 	action = ON
# |		 I = 1500.0 1/s, 	action = ON
# |		 D = 6e-05   s, 	action = OFF
# |		Off = 0.0  V, 	action = ON
# -----------------SRS PID controller SIM960 Status Summary Ends------------------
# '--------------------Rio Laser Fceo Rb spectroscopy Lock Servo--------------------\n|--------------------SRS PID controller SIM960 Status Summary--------------------\n|----------------------------SIM960,s/n033683,ver2.17----------------------------\n|\tOutput mode:\t\x1bMAN\x1b,\tOutput limit: -4.000V TO 4.000V\n|\tMeasured input:\t 0.002018V\n|\tAmplified error:\t -0.007743V\n|\tInstant Output voltage:\t -0.005581V\n|\tManual output set:\t 0.0V\n|\t================ Set Point related================\n|\t\tInternal setpoint = -0.01 V, Ramping \x1bOFF\x1b\n|\t\tSetpoint input mode INT, Ext setpoint input -0.009426V\n|\t\tSetpoint RAMP speed = 0.01 V/s, action \x1bOFF\x1b\n|\t============= P,I,D and Offset Status=============\n|\t\t P = 0.7    , \taction = \x1bON\x1b\n|\t\t I = 1500.0 1/s, \taction = \x1bON\x1b\n|\t\t D = 6e-05   s, \taction = \x1bOFF\x1b\n|\t\tOff = 0.0  V, \taction = \x1bON\x1b\n-----------------SRS PID controller SIM960 Status Summary Ends------------------\n'

# %%
#servo_RB.output_mode='man'
fg.set_channel_parameters(channel=1, freq=10, amp=8, offset=0, phase=0)
fg.set_channel_func(1, 'ramp')
fg.set_channel_state(1, 0)
# time.sleep(10)
# trace_x,trace_y=autolock.get_trace(trace = 1)
# plt.plot(trace_x,trace_y)
# Out:
# RAMP

# %%
osc.get_trace(trace=2)
# Out:
# 2024-11-18 10:28:44.669 | INFO     | TDS2024C OSC | TDS2024C.py:get_trace:134
# TDS2024C OSC: Trace 2 data read finished.
# {'BYT_Nr': 2,
#  'BIT_Nr': 16,
#  'ENCd': 'ASC',
#  'BN_Fmt': 'RP',
#  'BYT_Or': 'MSB',
#  'NR_Pt': 2500,
#  'WFID': '"Ch2, DC coupling, 1.0E0 V/div, 1.0E-2 s/div, 2500 points, Sample mode"',
#  'PT_FMT': 'Y',
#  'XINcr': 4e-05,
#  'PT_Off': 0.0,
#  'XZEro': -0.05,
#  'XUNit': '"s"',
#  'YMUlt': 0.00015625,
#  'YZEro': 0.0,
#  'YOFF': -11776.0,
#  'YUNit': '"Volts"',
#  'Y': array([2.08, 2.44, 1.96, ..., 2.32, 2.28, 2.2 ]),
#  'X': array([-0.05   , -0.04996, -0.04992, ...,  0.04988,  0.04992,  0.04996])}

# %%
from KeckLFC.Hardware.ORIONLaser import ORIONLaser
rio = ORIONLaser(addr=f'ASRL{14}::INSTR')
rio.connect()
rio.printStatus()
# Out:
# 2024-11-14 12:20:31.936 | INFO     | ORION Laser Module | Device.py:connect:78
# ORION Laser Module connected
# 0
# 1
# 0
# 2024-11-14 12:20:33.287 | INFO     | ORION Laser Module | ORIONLaser.py:printStatus:60
# -----------------------ORION Laser Module Status Summary------------------------
# -------------Product ID: RIO0175-5-01-4-AW2, Ver 0.11.7, SN: 806734-------------
# |	 Status Code: bytearray(b'\x00\x01\x00\x01\x00\x01')
# |	 Photo monitor voltage: 1.320 Volt (also mA, r=1kOhm)
# |	 Board Temp:   22.0856 °C
# |	 Thermis Temp: 25.6517 °C
# |	 Volatile Settings (reset to non-volatile after re-plug):
# |		 Diode Cur = 145.0000 mA, TEC Set = 25.902°C
# |	 Non Volatile Settings (Doesn't reset after re-plug):
# |		 Diode Cur = 145.0000 mA, TEC Set = 25.902°C
# ---------------------ORION Laser Module Status Summary Ends---------------------
# "-----------------------ORION Laser Module Status Summary------------------------\n-------------Product ID: RIO0175-5-01-4-AW2, Ver 0.11.7, SN: 806734-------------\n|\t Status Code: bytearray(b'\\x00\\x01\\x00\\x01\\x00\\x01')\n|\t Photo monitor voltage: 1.320 Volt (also mA, r=1kOhm)\n|\t Board Temp:   22.0856 °C\n|\t Thermis Temp: 25.6517 °C\n|\t Volatile Settings (reset to non-volatile after re-plug): \n|\t\t Diode Cur = 145.0000 mA, TEC Set = 25.902°C\n|\t Non Volatile Settings (Doesn't reset after re-plug): \n|\t\t Diode Cur = 145.0000 mA, TEC Set = 25.902°C\n---------------------ORION Laser Module Status Summary Ends---------------------"

# %%
rio.writeLaserdiodeCur_mA(150)
rio.writeTECsetpoint(19.181+4.1)
rio.printStatus()
osc.get_trace(trace=2)

# %%
osc.get_trace(trace=2)
# Out:
# 2024-11-14 13:31:03.822 | INFO     | TDS2024C OSC | TDS2024C.py:get_trace:134
# TDS2024C OSC: Trace 2 data read finished.
# {'BYT_Nr': 2,
#  'BIT_Nr': 16,
#  'ENCd': 'ASC',
#  'BN_Fmt': 'RP',
#  'BYT_Or': 'MSB',
#  'NR_Pt': 2500,
#  'WFID': '"Ch2, DC coupling, 1.0E0 V/div, 1.0E-2 s/div, 2500 points, Sample mode"',
#  'PT_FMT': 'Y',
#  'XINcr': 4e-05,
#  'PT_Off': 0.0,
#  'XZEro': -0.05,
#  'XUNit': '"s"',
#  'YMUlt': 0.00015625,
#  'YZEro': 0.0,
#  'YOFF': -11776.0,
#  'YUNit': '"Volts"',
#  'Y': array([2.08, 2.32, 1.88, ..., 2.32, 2.24, 2.12]),
#  'X': array([-0.05   , -0.04996, -0.04992, ...,  0.04988,  0.04992,  0.04996])}

# %%
rio.writeLaserdiodeCur_mA(150, volatile=False)
#rio.writeTECsetpoint(19.181, volatile=False)
rio.printStatus()
# Out:
# 0
# 1
# 0
# 2024-11-14 12:39:33.984 | INFO     | ORION Laser Module | ORIONLaser.py:printStatus:60
# -----------------------ORION Laser Module Status Summary------------------------
# -------------Product ID: RIO0175-5-01-4-AW2, Ver 0.11.7, SN: 806734-------------
# |	 Status Code: bytearray(b'\x00\x01\x00\x01\x00\x01')
# |	 Photo monitor voltage: 1.315 Volt (also mA, r=1kOhm)
# |	 Board Temp:   22.1827 °C
# |	 Thermis Temp: 25.7037 °C
# |	 Volatile Settings (reset to non-volatile after re-plug):
# |		 Diode Cur = 150.0000 mA, TEC Set = 25.902°C
# |	 Non Volatile Settings (Doesn't reset after re-plug):
# |		 Diode Cur = 150.0000 mA, TEC Set = 25.902°C
# ---------------------ORION Laser Module Status Summary Ends---------------------
# "-----------------------ORION Laser Module Status Summary------------------------\n-------------Product ID: RIO0175-5-01-4-AW2, Ver 0.11.7, SN: 806734-------------\n|\t Status Code: bytearray(b'\\x00\\x01\\x00\\x01\\x00\\x01')\n|\t Photo monitor voltage: 1.315 Volt (also mA, r=1kOhm)\n|\t Board Temp:   22.1827 °C\n|\t Thermis Temp: 25.7037 °C\n|\t Volatile Settings (reset to non-volatile after re-plug): \n|\t\t Diode Cur = 150.0000 mA, TEC Set = 25.902°C\n|\t Non Volatile Settings (Doesn't reset after re-plug): \n|\t\t Diode Cur = 150.0000 mA, TEC Set = 25.902°C\n---------------------ORION Laser Module Status Summary Ends---------------------"

# %%
from KeckLFC.Hardware.OZopticsVOA import OZopticsVOA
voa1550 = OZopticsVOA(addr=f'ASRL{15}::INSTR', name='1.55um VOA')
voa1550.connect()
voa1550.printStatus()
# Out:
# 2025-05-28 14:53:51.447 | INFO     | 1.55um VOA | Device.py:connect:88
# 1.55um VOA connected
# 2025-05-28 14:53:52.122 | INFO     | 1.55um VOA | OZopticsVOA.py:printStatus:44
# -----------------------------------1.55um VOA-----------------------------------
# --------------------------OZ optics VOA Status Summary--------------------------
# |	 Attenuation: 40.00 (dB)
# |	 Device Configure String:
# |		DD100MC
# |		V6.4
# |		NO:303700-01
# |		MAX ATTEN:61.00
# |		OVERSHOOT:-30
# |		CALIB:FEB-22-2022
# |		GEAR RATIO:485:1
# |		MOTOR VOLT:5V
# |		MINTERVAL(MS):0.90
# |		IL:0.00
# |		WAVELENGTH:1550
# |		I2C ADDRESS:64
# |		W0 1550
# -----------------------OZ optics VOA Status Summary Ends------------------------
# '-----------------------------------1.55um VOA-----------------------------------\n--------------------------OZ optics VOA Status Summary--------------------------\n|\t Attenuation: 40.00 (dB)\n|\t Device Configure String:\n|\t\tDD100MC \n|\t\tV6.4\n|\t\tNO:303700-01\n|\t\tMAX ATTEN:61.00\n|\t\tOVERSHOOT:-30\n|\t\tCALIB:FEB-22-2022\n|\t\tGEAR RATIO:485:1\n|\t\tMOTOR VOLT:5V\n|\t\tMINTERVAL(MS):0.90\n|\t\tIL:0.00\n|\t\tWAVELENGTH:1550\n|\t\tI2C ADDRESS:64\n|\t\tW0 1550\n-----------------------OZ optics VOA Status Summary Ends------------------------\n'

# %%
voa1550.printStatus()
# Out:
# 2024-07-25 13:08:36.169 | INFO     | 1.55um VOA | OZopticsVOA.py:printStatus:44
# -----------------------------------1.55um VOA-----------------------------------
# --------------------------OZ optics VOA Status Summary--------------------------
# |	 Attenuation: 10.00 (dB)
# |	 Device Configure String:
# |		DD100MC
# |		V6.4
# |		NO:303700-01
# |		MAX ATTEN:61.00
# |		OVERSHOOT:-30
# |		CALIB:FEB-22-2022
# |		GEAR RATIO:485:1
# |		MOTOR VOLT:5V
# |		MINTERVAL(MS):0.90
# |		IL:0.00
# |		WAVELENGTH:1550
# |		I2C ADDRESS:64
# |		W0 1550
# -----------------------OZ optics VOA Status Summary Ends------------------------
# '-----------------------------------1.55um VOA-----------------------------------\n--------------------------OZ optics VOA Status Summary--------------------------\n|\t Attenuation: 10.00 (dB)\n|\t Device Configure String:\n|\t\tDD100MC \n|\t\tV6.4\n|\t\tNO:303700-01\n|\t\tMAX ATTEN:61.00\n|\t\tOVERSHOOT:-30\n|\t\tCALIB:FEB-22-2022\n|\t\tGEAR RATIO:485:1\n|\t\tMOTOR VOLT:5V\n|\t\tMINTERVAL(MS):0.90\n|\t\tIL:0.00\n|\t\tWAVELENGTH:1550\n|\t\tI2C ADDRESS:64\n|\t\tW0 1550\n-----------------------OZ optics VOA Status Summary Ends------------------------\n'

# %%
voa1550.atten_db=0 #34
# Out:
# 2025-05-16 13:48:34.207 | INFO     | 1.55um VOA | OZopticsVOA.py:_setAttenStr:61
# 1.55um VOA: VOA attenuation setted to 0.00 dB.

# %%
voa2000.atten_db=0
# Out:
# 2025-05-16 13:48:36.457 | INFO     | 2um VOA | OZopticsVOA.py:_setAttenStr:61
# 2um VOA: VOA attenuation setted to 0.00 dB.

# %%
voa1550.disconnect()
voa1310.disconnect()
voa2000.disconnect()
# Out:
# 2024-07-26 10:44:19.425 | INFO     | 1.55um VOA | Device.py:disconnect:90
# 1.55um VOA disconnected
# 2024-07-26 10:44:19.427 | INFO     | 1um VOA | Device.py:disconnect:90
# 1um VOA disconnected
# 2024-07-26 10:44:19.430 | INFO     | 2um VOA | Device.py:disconnect:90
# 2um VOA disconnected
# 1

# %%
wsp.set3rdDisper(d2=-2.71,d3=0.)
wsp.setBandPass(span=5)
wsp.plotStatus()
wsp.writeProfile()
# Out:
# 2024-04-17 13:42:54.402 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:90
# Waveshaper Set 3rd disper with d2=-2.71 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-04-17 13:42:54.408 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:127
# Waveshaper Set atten to BandPass [189.675~194.675] THz ([1580.559~1539.964] nm).
# 2024-04-17 13:42:55.826 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:226
# Waveshaper profile write successful.

# %%
voa2000.printStatus()
# Out:
# 2024-04-10 14:27:38.528 | INFO     | 2um VOA | OZopticsVOA.py:printStatus:44
# ------------------------------------2um VOA-------------------------------------
# --------------------------OZ optics VOA Status Summary--------------------------
# |	 Attenuation: 10.00 (dB)
# |	 Device Configure String:
# |		DD100MC
# |		V6.2a
# |		NO:303699-01
# |		MAX ATTEN:55.00
# |		OVERSHOOT:-30
# |		CALIB:MAR-02-2022
# |		GEAR RATIO:485:1
# |		MINTERVAL(MS):0.90
# |		MOTOR VOLT:5
# |		IL:0.00
# |		WAVELENGTH:2000
# |		I2C ADDRESS:64
# |		W0 2000
# -----------------------OZ optics VOA Status Summary Ends------------------------
# '------------------------------------2um VOA-------------------------------------\n--------------------------OZ optics VOA Status Summary--------------------------\n|\t Attenuation: 10.00 (dB)\n|\t Device Configure String:\n|\t\tDD100MC\n|\t\tV6.2a\n|\t\tNO:303699-01\n|\t\tMAX ATTEN:55.00\n|\t\tOVERSHOOT:-30\n|\t\tCALIB:MAR-02-2022\n|\t\tGEAR RATIO:485:1\n|\t\tMINTERVAL(MS):0.90\n|\t\tMOTOR VOLT:5\n|\t\tIL:0.00\n|\t\tWAVELENGTH:2000\n|\t\tI2C ADDRESS:64\n|\t\tW0 2000\n-----------------------OZ optics VOA Status Summary Ends------------------------\n'

# %%
voa1550.atten_db
# Out:
# 60.0

# %%
voa2000.atten_db
# Out:
# 55.0

# %%
voa1310

# %%
from KeckLFC.Hardware.OZopticsVOA import OZopticsVOA
voa2000 = OZopticsVOA(addr=f'ASRL{18}::INSTR', name='2um VOA')
voa2000.connect()
voa2000.printStatus()
# Out:
# 2025-05-16 11:50:49.163 | INFO     | 2um VOA | Device.py:connect:78
# 2um VOA connected
# 2025-05-16 11:50:49.764 | INFO     | 2um VOA | OZopticsVOA.py:printStatus:44
# ------------------------------------2um VOA-------------------------------------
# --------------------------OZ optics VOA Status Summary--------------------------
# |	 Attenuation: 20.00 (dB)
# |	 Device Configure String:
# |		DD100MC
# |		V6.2a
# |		NO:303699-01
# |		MAX ATTEN:55.00
# |		OVERSHOOT:-30
# |		CALIB:MAR-02-2022
# |		GEAR RATIO:485:1
# |		MINTERVAL(MS):0.90
# |		MOTOR VOLT:5
# |		IL:0.00
# |		WAVELENGTH:2000
# |		I2C ADDRESS:64
# |		W0 2000
# -----------------------OZ optics VOA Status Summary Ends------------------------
# '------------------------------------2um VOA-------------------------------------\n--------------------------OZ optics VOA Status Summary--------------------------\n|\t Attenuation: 20.00 (dB)\n|\t Device Configure String:\n|\t\tDD100MC\n|\t\tV6.2a\n|\t\tNO:303699-01\n|\t\tMAX ATTEN:55.00\n|\t\tOVERSHOOT:-30\n|\t\tCALIB:MAR-02-2022\n|\t\tGEAR RATIO:485:1\n|\t\tMINTERVAL(MS):0.90\n|\t\tMOTOR VOLT:5\n|\t\tIL:0.00\n|\t\tWAVELENGTH:2000\n|\t\tI2C ADDRESS:64\n|\t\tW0 2000\n-----------------------OZ optics VOA Status Summary Ends------------------------\n'

# %%
voa2000.atten_db=55
# Out:
# 2024-08-22 07:25:54.545 | INFO     | 2um VOA | OZopticsVOA.py:_setAttenStr:61
# 2um VOA: VOA attenuation setted to 55.00 dB.

# %%
from KeckLFC.Hardware.OZopticsVOA import OZopticsVOA
voa1310 = OZopticsVOA(addr=f'ASRL{19}::INSTR', name='1um VOA')
voa1310.connect()
voa1310.printStatus()
# Out:
# 2025-04-15 07:44:08.197 | INFO     | 1um VOA | Device.py:connect:78
# 1um VOA connected
# 2025-04-15 07:44:08.828 | INFO     | 1um VOA | OZopticsVOA.py:printStatus:44
# ------------------------------------1um VOA-------------------------------------
# --------------------------OZ optics VOA Status Summary--------------------------
# |	 Attenuation: 55.00 (dB)
# |	 Device Configure String:
# |		DD100MC
# |		V1.1
# |		NO:311029-01
# |		MAX ATTEN:60.00
# |		OVERSHOOT:0
# |		CALIB:NOV-18-2022
# |		GEAR RATIO:485:1
# |		MOTOR VOLT:5V
# |		MINTERVAL(MS):0.90
# |		IL:0.00
# |		WAVELENGTH:1310
# |		I2C ADDRESS:64
# |		W0 0980
# |		W1 1310
# -----------------------OZ optics VOA Status Summary Ends------------------------
# '------------------------------------1um VOA-------------------------------------\n--------------------------OZ optics VOA Status Summary--------------------------\n|\t Attenuation: 55.00 (dB)\n|\t Device Configure String:\n|\t\tDD100MC \n|\t\tV1.1\n|\t\tNO:311029-01\n|\t\tMAX ATTEN:60.00\n|\t\tOVERSHOOT:0\n|\t\tCALIB:NOV-18-2022\n|\t\tGEAR RATIO:485:1\n|\t\tMOTOR VOLT:5V\n|\t\tMINTERVAL(MS):0.90\n|\t\tIL:0.00\n|\t\tWAVELENGTH:1310\n|\t\tI2C ADDRESS:64\n|\t\tW0 0980\n|\t\tW1 1310\n-----------------------OZ optics VOA Status Summary Ends------------------------\n'

# %%
voa1310.atten_db
# Out:
# 55.0

# %%
voa1310.connect()
voa1310.inst.clear()
# Out:
# 2025-04-15 08:04:17.510 | INFO     | 1um VOA | Device.py:connect:78
# 1um VOA connected

# %%
from KeckLFC.Hardware.OZopticsVOA import OZopticsVOA
import time
voa1310 = OZopticsVOA(addr=f'ASRL{19}::INSTR', name='1um VOA')

for i in range(3000):
    try:
        voa1310.connect()
        print(f"Iteration {i}: Attenuation = {voa1310.atten_db} dB")
        voa1310.disconnect()
    except Exception as e:
        print(f"Iteration {i}: Error occurred - {e}")

        
    time.sleep(1800)

# %%
from KeckLFC.Hardware.TEC_TC720 import TEC_TC720
# tec_PPLN = TEC_TC720(addr='ASRL46::INSTR')
tec_wg = TEC_TC720(addr='COM16', name='Octave Waveguide TEC (TC720)')
tec_wg.connect()
# Out:
# 2024-07-03 12:38:23.761 | INFO     | Octave Waveguide TEC (TC720) | TEC_TC720.py:connect:126
# Octave Waveguide TEC (TC720) connected
# 1

# %%
tec_wg.disconnect()
# Out:
# 2024-07-03 12:38:42.591 | INFO     | Octave Waveguide TEC (TC720) | TEC_TC720.py:disconnect:150
# Octave Waveguide TEC (TC720) disconnected
# 1

# %%
from KeckLFC.Hardware.Clarity import Clarity
ctl=Clarity(addr=f'ASRL{23}::INSTR')

# %%
ctl.get_status()
# Out:
# 3

# %%
ctl.get_frequency()
# Out:
# 192.185266

# %%
ctl.enter_password()

# %%
ctl.set_onoff(1)
# Out:
# 1

# %%
from KeckLFC.Hardware.TEC_TC720 import TEC_TC720

tec_ppln = TEC_TC720(addr=f'COM{22}', name='PPLN Doubler TEC (TC720)')
tec_ppln.connect()
#tec_ppln.get_mode()
# Out:
# 2024-07-03 12:38:45.999 | INFO     | PPLN Doubler TEC (TC720) | TEC_TC720.py:connect:126
# PPLN Doubler TEC (TC720) connected
# 1

# %%
tec_ppln.get_control_type()
# Out:
# 0

# %%
tec_ppln.get_temp()
# Out:
# 23.93

# %%
tec_ppln.set_temp(22)

# %%
import time
import numpy as np

# %%
now_temp=tec_ppln.get_temp()
set_temp=20.1

temp_gap=round(set_temp-now_temp,2)

int_p=int(temp_gap//0.5 )
mod=temp_gap % 0.5
if (int_p>0) or (int_p==0):
    int_p=int_p
else:
    int_p=np.abs(int_p)-1

for i in range(1,int_p+1):
    tec_ppln.set_temp(now_temp+i*0.5)
    time.sleep(4)
    print(tec_ppln.get_temp())

tec_ppln.set_temp(set_temp)
time.sleep(4)


print(tec_ppln.get_temp())
# Out:
# 22.46
# 22.82
# 20.18

# %%
tec_ppln.disconnect()
# Out:
# 2024-06-04 16:14:59.634 | INFO     | PPLN Doubler TEC (TC720) | TEC_TC720.py:disconnect:150
# PPLN Doubler TEC (TC720) disconnected
# 1

# %%
temp_gap
# Out:
# -2.68

# %%
int_p,mod
# Out:
# (0, 0.0)

# %%
tec_ppln.get_temp2()
# Out:
# 16.55

# %%
tec_ppln.disconnect()
# Out:
# 2024-04-11 13:28:20.620 | INFO     | PPLN Doubler TEC (TC720) | TEC_TC720.py:disconnect:150
# PPLN Doubler TEC (TC720) disconnected
# 1

# %%
from KeckLFC.Hardware.USB2408 import USB2408
daq0=USB2408(addr=0)
daq0.connect()
daq1=USB2408(addr=1)
daq1.connect()
# Out:
# Looking for Board 0 in InstaCal to be USB-2408 series...
# USB-2408 found as Board number 0.
#
# USB-2408 DAQ in Electronics Rack: set channel 0 done
# USB-2408 DAQ in Electronics Rack: set channel 1 done
# USB-2408 DAQ in Electronics Rack: set channel 2 done
# USB-2408 DAQ in Electronics Rack: set channel 3 done
# USB-2408 DAQ in Electronics Rack: set channel 4 done
# USB-2408 DAQ in Electronics Rack: set channel 5 done
# USB-2408 DAQ in Electronics Rack: set channel 6 done
# USB-2408 DAQ in Electronics Rack: set channel 7 done
# USB-2408 DAQ in Electronics Rack connected.
# Looking for Board 1 in InstaCal to be USB-2408 series...
# USB-2408 found as Board number 1.
#
# USB-2408 DAQ on Optical Table Breadboard: set channel 0 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 1 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 2 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 3 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 4 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 5 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 6 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 7 done
# USB-2408 DAQ on Optical Table Breadboard connected.
# 1

# %%
daq0.get_temp_all()
daq1.get_temp_all()
# Out:
# USB-2408 DAQ in Electronics Rack: Channel 0:  28.765 Degrees.	 Position at Rack side buffle (middle side rack).
# USB-2408 DAQ in Electronics Rack: Channel 1:  28.384 Degrees.	 Position at Waveshaper (upper rack).
# USB-2408 DAQ in Electronics Rack: Channel 2:  28.757 Degrees.	 Position at Rb clock (middle rack).
# USB-2408 DAQ in Electronics Rack: Channel 3:  27.137 Degrees.	 Position at Pritel (middle upper rack).
# USB-2408 DAQ in Electronics Rack: Channel 4:  17.537 Degrees.	 Position at Rack Glycol out.
# USB-2408 DAQ in Electronics Rack: Channel 5:  11.333 Degrees.	 Position at Rack Glycol in.
# USB-2408 DAQ in Electronics Rack: Channel 6:  27.677 Degrees.	 Position at Power Supply Shelf (bottom rack).
# Error: Error 145: Temperature input has open connection.
# cannot access local variable 'value_temperature' where it is not associated with a value
# USB-2408 DAQ on Optical Table Breadboard: Channel 0:  35.036 Degrees.	 Position at RF Oscillator.
# USB-2408 DAQ on Optical Table Breadboard: Channel 1:  40.818 Degrees.	 Position at RF amplifier.
# USB-2408 DAQ on Optical Table Breadboard: Channel 2:  28.457 Degrees.	 Position at Main Phase Modulators.
# USB-2408 DAQ on Optical Table Breadboard: Channel 3:  24.561 Degrees.	 Position at Filter Cavity.
# USB-2408 DAQ on Optical Table Breadboard: Channel 4:  11.113 Degrees.	 Position at Board Glycol out.
# USB-2408 DAQ on Optical Table Breadboard: Channel 5:  29.249 Degrees.	 Position at Board Glycol in.
# USB-2408 DAQ on Optical Table Breadboard: Channel 6:  21.099 Degrees.	 Position at Compression Stage.
# USB-2408 DAQ on Optical Table Breadboard: Channel 7:  25.968 Degrees.	 Position at Rubidium (Rb) Cell D2-210.
# [35.03647994995117,
#  40.81800079345703,
#  28.45744514465332,
#  24.561281204223633,
#  11.112570762634277,
#  29.248926162719727,
#  21.099273681640625,
#  25.967817306518555]

# %%
daq0.get_temp_all()
daq1.get_temp_all()
# Out:
# USB-2408 DAQ in Electronics Rack: Channel 0:  29.026 Degrees.	 Position at Rack side buffle (middle side rack).
# USB-2408 DAQ in Electronics Rack: Channel 1:  29.764 Degrees.	 Position at Waveshaper (upper rack).
# USB-2408 DAQ in Electronics Rack: Channel 2:  28.753 Degrees.	 Position at Rb clock (middle rack).
# USB-2408 DAQ in Electronics Rack: Channel 3:  28.101 Degrees.	 Position at Pritel (middle upper rack).
# USB-2408 DAQ in Electronics Rack: Channel 4:  17.242 Degrees.	 Position at Rack Glycol out.
# USB-2408 DAQ in Electronics Rack: Channel 5:  10.797 Degrees.	 Position at Rack Glycol in.
# USB-2408 DAQ in Electronics Rack: Channel 6:  27.536 Degrees.	 Position at Power Supply Shelf (bottom rack).
# Error: Error 145: Temperature input has open connection.
# cannot access local variable 'value_temperature' where it is not associated with a value
# USB-2408 DAQ on Optical Table Breadboard: Channel 0:  33.261 Degrees.	 Position at RF Oscillator.
# USB-2408 DAQ on Optical Table Breadboard: Channel 1:  38.928 Degrees.	 Position at RF amplifier.
# USB-2408 DAQ on Optical Table Breadboard: Channel 2:  27.078 Degrees.	 Position at Main Phase Modulators.
# USB-2408 DAQ on Optical Table Breadboard: Channel 3:  23.091 Degrees.	 Position at Filter Cavity.
# USB-2408 DAQ on Optical Table Breadboard: Channel 4:  10.271 Degrees.	 Position at Board Glycol out.
# USB-2408 DAQ on Optical Table Breadboard: Channel 5:  27.512 Degrees.	 Position at Board Glycol in.
# USB-2408 DAQ on Optical Table Breadboard: Channel 6:  21.155 Degrees.	 Position at Compression Stage.
# USB-2408 DAQ on Optical Table Breadboard: Channel 7:  25.022 Degrees.	 Position at Rubidium (Rb) Cell D2-210.
# [33.260677337646484,
#  38.92770767211914,
#  27.0778751373291,
#  23.090654373168945,
#  10.271151542663574,
#  27.51214599609375,
#  21.155078887939453,
#  25.02231216430664]

# %%
from KeckLFC.Hardware.USB2408 import USB2408
daq1=USB2408(addr=1)
daq1.connect()
# Out:
# Looking for Board 1 in InstaCal to be USB-2408 series...
# USB-2408 found as Board number 1.
#
# USB-2408 DAQ on Optical Table Breadboard: set channel 0 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 1 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 2 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 3 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 4 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 5 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 6 done
# USB-2408 DAQ on Optical Table Breadboard: set channel 7 done
# USB-2408 DAQ on Optical Table Breadboard connected.
# 1

# %%
GPIB1::1::INSTR

# %% [markdown]
# ## screen shoot

# %%
import pyautogui
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import glob


def read_file():
    file_path = r'C:\Users\KeckLFC\Desktop\hispec\data.txt'
    x = []
    y = []
    with open(file_path, 'r') as file:
        lines = file.readlines()
        # Skip the header lines
        for line in lines:
            if line.strip() and not line.startswith(('exposure time', 'average', 'Time', 'wavelength', 'nm', 'CCD counts')):
                data = line.split()
                if len(data) == 2:
                    x.append(float(data[0]))
                    y.append(float(data[1]))
    return np.array(x), np.array(y)

def save_data():
    save_data_x=209
    save_data_y=760
    save_x=1330
    save_y=828
    yes_x=1014
    yes_y=654
    arrow_x=1910
    arrow_y=573
    download_file_x=1595
    download_file_y=470
    datatxt_x=403
    datatxt_y=260
    open_x=787
    open_y=627
    time.sleep(5)

    pyautogui.click(save_data_x,save_data_y,duration=0.2)
    time.sleep(0.3)
    pyautogui.click(save_x,save_y,duration=0.2)
    time.sleep(0.3)
    pyautogui.click(yes_x,yes_y,duration=0.2)
    time.sleep(0.3)
    pyautogui.click(arrow_x,arrow_y,duration=0.2)
    time.sleep(0.3)
    pyautogui.scroll(-1500)
    pyautogui.click(download_file_x,download_file_y,duration=0.2)
    time.sleep(0.3)
    pyautogui.click(datatxt_x,datatxt_y,duration=0.2)
    time.sleep(0.3)
    pyautogui.click(open_x,open_y,duration=0.2)
    time.sleep(0.3)

    return 


def delete_all_files_in_directory():
    directory=r'C:\Users\KeckLFC\Desktop\hispec'
    files = glob.glob(os.path.join(directory, '*'))
    for file in files:
        try:
            os.remove(file)
            #print(f"Deleted file: {file}")
        except Exception as e:
            print(f"Error deleting file {file}: {e}")

#####################

def score_spectrum(wlstart,wlstop):
    
    time.sleep(0.3)
    
    save_data()
    x,y=read_file()
    ylog=np.log(y)
    #x1=x[np.where((x>start_wl) & (x<stop_wl))] 
    y1=ylog[np.where((x>wlstart) & (x<wlstop))]
    thresh=min(y1)+0.5
    y1=y1[np.where(y1>thresh) ]
    score=np.sum(y1)+len(y1)*5
    delete_all_files_in_directory()

    return score

def optimize_d2(wsp,osa,x,d2_start=-6,d2_stop=-5.4,d2_step=0.01):

    d2_values= np.arange(d2_start,d2_stop,d2_step)
    scores = np.zeros((len(d2_values), 2))
    
    for i, d2 in enumerate(d2_values):

        wsp.set3rdDisper(d2,d3=0.)
        wsp.setBandPass(center=192.174,span=4)
        wsp.writeProfile()

        score = score_spectrum(1600,2400)

        scores[i] = [d2, score]
        
        # 找到评分最高的d2
    max_index = np.argmax(scores[:, 1])
    best_d2 = scores[max_index, 0]
    best_score = scores[max_index, 1]

    return best_d2, best_score, scores

def optimize_phase_single_step(wsp,x_hz,phase_array, step_size=0.1*2*np.pi, i=0,
                     start_wl=1800,stop_wl=2200,score=0):
    best_score = score
    original_phase = phase_array[i]
    phase_array[i] = original_phase + 1 * step_size
    phase_setting(wsp,x_hz,phase_array)
    new_score = score_spectrum(start_wl,stop_wl)
    if new_score > best_score:
        best_score = new_score

    else:
        phase_array[i] = original_phase - 1 * step_size
        phase_setting(wsp,x_hz,phase_array)
        new_score = score_spectrum(start_wl,stop_wl)  
        if new_score > best_score:
            best_score = new_score
        else:
            phase_array[i] = original_phase
    print(f" Phase {i}, setp size {'%.4f' %step_size}, best score {'%.4f' %best_score},now score {'%.4f' %new_score}")
    return phase_array, best_score, i

def phase_setting(wsp,x_hz,y_phase):

    # x_nm=np.arange(1553,1567,0.06)
    # x_hz=wsp.nm2thz(x_nm)
    # #x_freq = np.linspace(192.175-2, 192.175+2, 100)
    # y_phase = ((x_hz-192.175) ** 2 * (2*np.pi) ** 2 * 1.3/2*-5.7)   #+ 0/((x_freq-192.3) ** 4 * (2*np.pi) ** 2 * 1.3/2+1)
    wsp.set_interp_phase(x_hz, y_phase)
    #wsp.setBandPass(center=192.174,span=4)
    #wsp.plotStatus()
    wsp.writeProfile(disable_beep=True)

def initial_phase_array(wsp,d2,start,stop,step):

    x_nm=np.arange(start,stop,step)
    x_hz=wsp.nm2thz(x_nm)
    #x_freq = np.linspace(192.175-2, 192.175+2, 100)
    y_phase = wsp.give_2ndDisp_phase(x_hz,d2)
    return x_hz,y_phase

# %%
for i in range(20):
    x,y=pyautogui.position()    
    print(x,y)
    time.sleep(0.15)
# Out:
# 1498 492
# 1498 492
# 1498 492
# 1498 492
# 1363 512
# 1086 541
# 1037 543
# 904 575
# 859 587
# 829 606
# 806 613
# 798 616
# 794 620
# 794 625
# 792 627
# 789 627
# 787 627
# 787 627
# 787 627
# 787 627

# %%
from KeckLFC.Hardware.Waveshaper import Waveshaper

wsp = Waveshaper()
wsp.connect()
# Out:
# 2024-07-27 07:14:17.246 | INFO     | Finisar Waveshaper SN201904 | Device.py:connect:78
# Finisar Waveshaper SN201904 connected
# 1

# %%
d2_start= -2.94
d2_stop=-2.86
d2_step=0.01
d2_values= np.arange(d2_start,d2_stop,d2_step)
scores = np.zeros((len(d2_values), 2))
wlstart=1800
wlstop=2200
delete_all_files_in_directory()
for i, d2 in enumerate(d2_values):

    wsp.set3rdDisper(d2,d3=0.)
    wsp.setBandPass(center=192.174,span=4)
    wsp.writeProfile()

    score = score_spectrum(wlstart,wlstop)

    scores[i] = [d2, score]
    print(f"i={i}, d2={'%.4f' %d2}, score={'%.4f' %score}")
    
    # 找到评分最高的d2
max_index = np.argmax(scores[:, 1])
best_d2 = scores[max_index, 0]
best_score = scores[max_index, 1]
# Out:
# 2024-07-27 13:13:42.729 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.94 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:13:42.733 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# 2024-07-27 13:13:43.745 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:13:52.294 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.93 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:13:52.295 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=0, d2=-2.9400, score=330.2979
# 2024-07-27 13:13:53.388 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:14:02.017 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.9200000000000004 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:14:02.018 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=1, d2=-2.9300, score=403.8063
# 2024-07-27 13:14:03.110 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:14:11.715 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.9100000000000006 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:14:11.716 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=2, d2=-2.9200, score=375.7537
# 2024-07-27 13:14:12.778 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:14:21.436 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.900000000000001 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:14:21.439 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=3, d2=-2.9100, score=459.1450
# 2024-07-27 13:14:22.516 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:14:31.141 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.890000000000001 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:14:31.144 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=4, d2=-2.9000, score=417.5971
# 2024-07-27 13:14:32.212 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:14:40.912 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.8800000000000012 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:14:40.915 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=5, d2=-2.8900, score=468.5361
# 2024-07-27 13:14:41.996 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:14:50.701 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.8700000000000014 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:14:50.703 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=6, d2=-2.8800, score=409.1837
# 2024-07-27 13:14:51.825 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-07-27 13:15:00.456 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set3rdDisper:99
# Waveshaper Set 3rd disper with d2=-2.8600000000000017 ps/nm, d3=0.0 ps/nm^2, center 192.17465256410256 THz.
# 2024-07-27 13:15:00.465 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [190.174~194.174] THz ([1576.411~1543.937] nm).
# i=7, d2=-2.8700, score=471.9556
# 2024-07-27 13:15:01.511 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# i=8, d2=-2.8600, score=470.3625

# %%
best_d2
# Out:
# -2.8700000000000014

# %%
d2=-2.90
x_hz,y_phase = initial_phase_array(wsp,d2,1553,1567,0.06)
wsp.setBandPass(center=192.174,span=6)
phase_setting(wsp,x_hz,y_phase)

phase_array_now= y_phase
iteration_now=0
i_now=0
# Out:
# 2024-08-18 06:38:56.825 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:setBandPass:136
# Waveshaper Set atten to BandPass [189.174~195.174] THz ([1584.745~1536.027] nm).
# 2024-08-18 06:38:56.827 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 06:38:58.009 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.

# %%
delete_all_files_in_directory()
phase_last=phase_array_now
i_start1=200

i_end1=len(phase_array_now)
i_end1=220#220

step_size=0.1*2*np.pi
wlstart=1800
wlstop=2200

phase_record=[]

phase_setting(wsp,x_hz,phase_array_now)
best_score_now = score_spectrum(wlstart,wlstop)


for i in range(i_start1,i_end1):
#try:
    old_score=best_score_now

    phase_array_now, best_score_now,i_now = optimize_phase_single_step(wsp,x_hz,phase_array=phase_array_now, step_size=step_size, i=i,
                    start_wl=wlstart,stop_wl=wlstop,score=best_score_now)
    if best_score_now>old_score:
        phase_record.append(phase_array_now.copy())

#except:
    #print('wrong')
# Out:
# 2024-08-18 08:27:31.802 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:27:31.919 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:27:41.946 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:27:42.549 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:27:52.638 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:27:53.182 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:28:03.299 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 200, setp size 0.6283, best score 508.8440,now score 508.8440
# 2024-08-18 08:28:03.914 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:28:13.955 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:28:14.569 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:28:24.671 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 201, setp size 0.6283, best score 508.8440,now score 286.1990
# 2024-08-18 08:28:25.297 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:28:35.372 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:28:35.971 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:28:46.083 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 202, setp size 0.6283, best score 508.8440,now score 365.3230
# 2024-08-18 08:28:46.676 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:28:56.740 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:28:57.348 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:29:07.433 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 203, setp size 0.6283, best score 508.8440,now score 354.8649
# 2024-08-18 08:29:08.057 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:29:18.117 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:29:18.749 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:29:28.827 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 204, setp size 0.6283, best score 508.8440,now score 296.5443
# 2024-08-18 08:29:29.427 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:29:39.483 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:29:40.108 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:29:50.165 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 205, setp size 0.6283, best score 508.8440,now score 309.9684
# 2024-08-18 08:29:50.777 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:30:00.842 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:30:01.413 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:30:11.530 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 206, setp size 0.6283, best score 508.8440,now score 389.0672
# 2024-08-18 08:30:12.151 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:30:22.232 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:30:22.849 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:30:32.941 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 207, setp size 0.6283, best score 508.8440,now score 321.3988
# 2024-08-18 08:30:33.512 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:30:43.643 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:30:44.207 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:30:54.313 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 208, setp size 0.6283, best score 508.8440,now score 294.8639
# 2024-08-18 08:30:54.909 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:31:05.028 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:31:05.645 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:31:15.723 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 209, setp size 0.6283, best score 508.8440,now score 353.0056
# 2024-08-18 08:31:16.340 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:31:26.409 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:31:27.030 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:31:37.098 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 210, setp size 0.6283, best score 508.8440,now score 298.2497
# 2024-08-18 08:31:37.706 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:31:47.771 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:31:48.366 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:31:58.452 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 211, setp size 0.6283, best score 508.8440,now score 291.7825
# 2024-08-18 08:31:59.035 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:32:09.157 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:32:09.729 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:32:19.777 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 212, setp size 0.6283, best score 508.8440,now score 312.7025
# 2024-08-18 08:32:20.505 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:32:30.603 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:32:31.223 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:32:41.287 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 213, setp size 0.6283, best score 508.8440,now score 278.9000
# 2024-08-18 08:32:41.951 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:32:52.052 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:32:52.686 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:33:02.811 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 214, setp size 0.6283, best score 508.8440,now score 303.0354
# 2024-08-18 08:33:03.437 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:33:13.568 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:33:14.204 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:33:24.323 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 215, setp size 0.6283, best score 508.8440,now score 323.9138
# 2024-08-18 08:33:24.934 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:33:34.999 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 216, setp size 0.6283, best score 519.1431,now score 519.1431
# 2024-08-18 08:33:35.642 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:33:45.673 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:33:46.323 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:33:56.421 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 217, setp size 0.6283, best score 519.1431,now score 316.2572
# 2024-08-18 08:33:57.140 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:34:07.217 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:34:07.869 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:34:17.904 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
#  Phase 218, setp size 0.6283, best score 519.1431,now score 327.1351
# 2024-08-18 08:34:18.548 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# 2024-08-18 08:34:28.703 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 08:34:29.318 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
#  Phase 219, setp size 0.6283, best score 519.1431,now score 450.3180

# %%
phase1=phase_record[-1]

# %%
plt.plot(phase_array_now)

# %%
C:\Users\KeckLFC\KeckLFC-main\KeckLFC\hispec_test\20240727_sapre_octave_waveguide_d2_m2p9_pwr_3p8.npz

# %%
delete_all_files_in_directory()

# %%
delete_all_files_in_directory()
phase_setting(wsp,x_hz,phase1)

score_spectrum(1800,2200)
# Out:
# 2024-07-27 13:55:49.337 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-07-27 13:55:49.607 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[250], line 4
#       1 delete_all_files_in_directory()
#       2 phase_setting(wsp,x_hz,phase1)
# ----> 4 score_spectrum(1800,2200)
#
# Cell In[227], line 77, in score_spectrum(wlstart, wlstop)
#      74 time.sleep(0.3)
#      76 save_data()
# ---> 77 x,y=read_file()
#      78 ylog=np.log(y)
#      79 #x1=x[np.where((x>start_wl) & (x<stop_wl))]
#
# Cell In[227], line 13, in read_file()
#      11 x = []
#      12 y = []
# ---> 13 with open(file_path, 'r') as file:
#      14     lines = file.readlines()
#      15     # Skip the header lines
#
# File c:\Users\KeckLFC\.conda\envs\lfc-env\Lib\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\KeckLFC\\Desktop\\hispec\\data.txt'

# %%
phase_array_old=np.load(r'C:\Users\KeckLFC\KeckLFC-main\KeckLFC\hispec_test\20240727_sapre_octave_waveguide_d2_m2p9_pwr_3p8_origin.npz')['phase_array']
phase_setting(wsp,x_hz,phase_array_old)
delete_all_files_in_directory()
time.sleep(5)
save_data()
x,y=read_file()
y=np.log(y)
# Out:
# 2024-08-18 09:15:15.117 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 09:15:16.305 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.

# %%
phase_setting(wsp,x_hz,phase_array_now)
delete_all_files_in_directory()
time.sleep(5)
save_data()
x,y=read_file()
y=np.log(y)
# Out:
# 2024-08-18 09:17:39.525 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:set_interp_phase:117
# Waveshaper Set interp phase with center 192.17465256410256 THz.
# 2024-08-18 09:17:40.729 | INFO     | Finisar Waveshaper SN201904 | Waveshaper.py:writeProfile:235
# Waveshaper profile write successful.

# %%
np.savez(r'C:\Users\KeckLFC\KeckLFC-main\KeckLFC\hispec_test\20240818_sapre_octave_waveguide_d2_m2p9_pwr_3p8_origin.npz',x=x,y=y,phase_array=phase_array_now)

# %%
delete_all_files_in_directory()

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)

# %% [markdown]
# ## 2025 05 16
# ## only one test with yokogawa 6377

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import time
import os

# 假设这个函数计算光谱的得分
def score_spectrum(osa,x,start_wl=1.6e-6,stop_wl=1.8e-6,hight_shreshold=None):
    time.sleep(0.03)
    osa.single()
    time.sleep(1)

    y=osa.get_Ydata('TRA')
    #x1=x[np.where((x>start_wl) & (x<stop_wl))] 
    y1=y[np.where((x>start_wl) & (x<stop_wl))]
    if hight_shreshold is None:
        hight_shreshold=-32
    peaks,_ = find_peaks(y1, height=hight_shreshold, distance=2, width=0.02e-9)
    num_peaks = len(peaks)

    score=np.sum(y1[peaks])+num_peaks*np.abs(hight_shreshold)*1.5
    return score

def optimize_d2(wsp,osa,x,d2_start=-6,d2_stop=-5.4,d2_step=0.01):

    d2_values= np.arange(d2_start,d2_stop,d2_step)
    scores = np.zeros((len(d2_values), 2))
    
    for i, d2 in enumerate(d2_values):

        wsp.set3rdDisper(d2,d3=0.)
        wsp.setBandPass(center=192.174,span=4)
        wsp.writeProfile()

        score = score_spectrum(osa,x)

        scores[i] = [d2, score]
        
        # 找到评分最高的d2
    max_index = np.argmax(scores[:, 1])
    best_d2 = scores[max_index, 0]
    best_score = scores[max_index, 1]

    return best_d2, best_score, scores


# 梯度下降算法
def optimize_phase(wsp,osa,x,x_hz,phase_array, step_size=0.1*2*np.pi, max_iterations=50, tolerance=1e-2, iterarion_start=0, i_start=0,
                   start_wl=1.6e-6,stop_wl=1.8e-6):
    
    phase_setting(wsp,x_hz,phase_array)
    
    best_score = score_spectrum(osa,x,start_wl,stop_wl)
    iteration = iterarion_start 
    i=i_start
    i_end=len(phase_array)-10
    try:
        while iteration < max_iterations:

            step_size = step_size / (1+iteration*0.6)

            while i < i_end:
                original_phase = phase_array[i]
                phase_array[i] = original_phase + 1 * step_size
                phase_setting(wsp,x_hz,phase_array)
                new_score = score_spectrum(osa,x,start_wl,stop_wl)
                if new_score > best_score:
                    best_score = new_score
                    print(f"Iteration {iteration}, Phase {i}, setp size {'%.4f' %step_size}, best score {'%.4f' %best_score},now score {'%.4f' %new_score}")
                else:
                    phase_array[i] = original_phase - 1 * step_size
                    phase_setting(wsp,x_hz,phase_array)
                    new_score = score_spectrum(osa,x,start_wl,stop_wl)  
                    if new_score > best_score:
                        best_score = new_score
                    else:
                        phase_array[i] = original_phase
                    print(f"Iteration {iteration}, Phase {i}, setp size {'%.4f' %step_size}, best score {'%.4f' %best_score},now score {'%.4f' %new_score}")
                i += 1
            i = 0
            iteration += 1
            if np.abs(new_score - best_score) < tolerance:
                break
        return phase_array, best_score, iteration, i
    
    except:
        return phase_array, best_score, iteration, i
    
def optimize_phase_single_step(wsp,osa,x,x_hz,phase_array, step_size=0.1*2*np.pi, i=0,
                     start_wl=1.6e-6,stop_wl=1.8e-6,score=0):
    best_score = score
    original_phase = phase_array[i]
    phase_array[i] = original_phase + 1 * step_size
    phase_setting(wsp,x_hz,phase_array)
    new_score = score_spectrum(osa,x,start_wl,stop_wl)
    if new_score > best_score+20:
        best_score = new_score

    else:
        phase_array[i] = original_phase - 1 * step_size
        phase_setting(wsp,x_hz,phase_array)
        new_score = score_spectrum(osa,x,start_wl,stop_wl)  
        if new_score > best_score+20:
            best_score = new_score
        else:
            phase_array[i] = original_phase
    print(f" Phase {i}, setp size {'%.4f' %step_size}, best score {'%.4f' %best_score},now score {'%.4f' %new_score}")
    return phase_array, best_score, i

    
def optimize_phase_single_move(wsp,osa,x,x_hz,phase_array, step_size=0.1*2*np.pi, i=0,
                   start_wl=1.6e-6,stop_wl=1.8e-6,score=0):
    best_score = score
    original_phase = phase_array[i]
    new_score = np.zeros(7)
    move_yes=1
    phase_list=[original_phase + 1 * step_size, 
                original_phase + 0.5 * step_size, 
                original_phase + 0.25 * step_size,
                original_phase, 
                original_phase - 0.25 * step_size,
                original_phase - 0.5 * step_size,
                original_phase - 1 * step_size]
    
    for j in range(7):
        phase_array[i] = phase_list[j]
        phase_setting(wsp,x_hz,phase_array)
        new_score[j] = score_spectrum(osa,x,start_wl,stop_wl)

    phase_array[i] = phase_list[np.argmax(new_score)]
    if np.argmax(new_score) == 3:
        move_yes=0
    new_score_max = np.max(new_score)
    # if new_score_max > best_score:
    #     best_score = new_score_max
    #     phase_array[i] = phase_list[np.argmax(new_score)]
        
    # else:
    #     phase_array[i] = original_phase
    #     # phase_array[i] = original_phase - 1 * step_size
    #     # phase_setting(wsp,x_hz,phase_array)
    #     # new_score = score_spectrum(osa,x,start_wl,stop_wl)  
    #     # if new_score > best_score+90:
    #     #     best_score = new_score
    #     # else:
    #     #     phase_array[i] = original_phase
        
    print(f"Phase {i}, setp size {'%.4f' %step_size}, best score {'%.4f' %best_score},now score {'%.4f' %new_score_max}, move yes {move_yes}") 
    return phase_array, new_score_max, i

def optimize_phase_group_move(wsp,osa,x,x_hz,phase_array, step_size=0.1*2*np.pi, i=0,
                     start_wl=1.6e-6,stop_wl=1.8e-6,score=0,gourp_num=1):
    
    best_score = score
    original_phase = np.copy(phase_array[i:i+gourp_num])
    new_score = np.zeros(7)

    move_yes=1

    phase_list=[original_phase + 1 * step_size,
                original_phase + 0.5 * step_size, 
                original_phase + 0.25 * step_size,
                original_phase, 
                original_phase - 0.25 * step_size,
                original_phase - 0.5 * step_size,
                original_phase - 1 * step_size]
    
    for j in range(7):
        phase_array[i:i+gourp_num] = phase_list[j]
        phase_setting(wsp,x_hz,phase_array)
        new_score[j] = score_spectrum(osa,x,start_wl,stop_wl)
    
    phase_array[i:i+gourp_num] = phase_list[np.argmax(new_score)]

    if np.argmax(new_score) == 3:
        move_yes=0

    new_score_max = np.max(new_score)

    print(f"Phase {i}, setp size {'%.4f' %step_size}, best score {'%.4f' %best_score},now score {'%.4f' %new_score_max}, move yes {move_yes}")
    return phase_array, new_score_max, i



def phase_setting(wsp,x_hz,y_phase):

    # x_nm=np.arange(1553,1567,0.06)
    # x_hz=wsp.nm2thz(x_nm)
    # #x_freq = np.linspace(192.175-2, 192.175+2, 100)
    # y_phase = ((x_hz-192.175) ** 2 * (2*np.pi) ** 2 * 1.3/2*-5.7)   #+ 0/((x_freq-192.3) ** 4 * (2*np.pi) ** 2 * 1.3/2+1)
    wsp.set_interp_phase(x_hz, y_phase)
    #wsp.setBandPass(center=192.174,span=4)
    #wsp.plotStatus()
    wsp.writeProfile(disable_beep=True)

def initial_phase_array(wsp,d2,start,stop,step):

    x_nm=np.arange(start,stop,step)
    x_hz=wsp.nm2thz(x_nm)
    #x_freq = np.linspace(192.175-2, 192.175+2, 100)
    y_phase = wsp.give_2ndDisp_phase(x_hz,d2)
    return x_hz,y_phase
    

def save_phase_array(phase_array, x,y,filename=r'C:\Users\KeckLFC\Desktop\hispec\osamidir\0'):

    filename=r'C:\Users\KeckLFC\Desktop\hispec\osamidir\0'

    np.savez(filename, phase_array=phase_array)

    np.savez(r'C:\Users\KeckLFC\Desktop\hispec\osamidir\0', x=x, y=y)

# 示例使用
def initial_all_parameters():
    
    
    os.chdir(r'D:\astrocomb\KeckLFC-deploy')

    from Hardware.YOKOGAWAaq6375 import YOKOGAWAaq6375
    from Hardware.Waveshaper import Waveshaper
    osa = YOKOGAWAaq6375(addr='GPIB1::1::INSTR', name='Ando OSA AQ6315E')
    wsp = Waveshaper(addr='SN200157',WSname='Waveshaper')
    osa.connect()
    wsp.connect()

    d2= -5.7

    start_wl=1.6e-6
    stop_wl=1.8e-6

    osa.set_wavelength_start(start_wl)
    osa.set_wavelength_stop(stop_wl)
    osa.set_sample_points(4000)
    osa.set_resolution(0.05)
    osa.set_sensitivity('NORM')

    osa.single()
    x=osa.get_Xdata('TRA')
    # TRA not a!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    x_hz,y_phase = initial_phase_array(wsp,d2,1553,1567,0.06)

    
    phase_setting(wsp,x_hz,y_phase)



    return wsp,osa, x,x_hz, y_phase

# %%
from KeckLFC.Hardware.YOKOGAWAaq6375 import YOKOGAWAaq6375
osa = YOKOGAWAaq6375(addr='GPIB1::1::INSTR', name='Ando OSA AQ6315E')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import time
import os
def save_osa(x,y,filename=r'C:\Users\KeckLFC\Desktop\hispec\osamidir\0'):

    np.savez(filename, x=x, y=y)

# %%
osa.disconnect()
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import time
import os
def save_osa(x,y,filename=r'C:\Users\KeckLFC\Desktop\hispec\osamidir\0'):

    np.savez(filename, x=x, y=y)

xx,yy = osa.get_trace('TRA')

plt.plot(xx,yy)

save_osa(xx,yy,filename=r'C:\Users\KeckLFC\Desktop\hispec\osamidir\2m_pm_3m_hlnf_4w')

# %%
def save_osa(x,y,filename=r'C:\Users\KeckLFC\Desktop\hispec\osamidir\0'):

    np.savez(filename, x=x, y=y)
